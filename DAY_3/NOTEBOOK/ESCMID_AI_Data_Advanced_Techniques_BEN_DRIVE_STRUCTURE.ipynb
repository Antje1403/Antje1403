# %% [markdown]
# # Welcome to the Advanced Data Techniques practical session
#
# This session is led by **Eline Meijer** and **Alejandro Guerrero-López**.
#
# In this notebook, we will work with **MALDI-TOF mass spectrometry data**, specifically the **DRIAMS B database**, which contains routine MALDI-TOF MS data from the Canton Hospital Basel-Land.
#
# Our objectives for this practical session are to:
#
# - Perform **basic preprocessing** of the MALDI-TOF MS data
# - Apply **dimensionality reduction techniques** for visualization, such as t-SNE and UMAP
# - Solve **species classification tasks** using both **MLP (Multilayer Perceptron)** models and interpretable models like **XGBoost, Random Forest, and Logistic Regression**
# - Demonstrate **model explainability** using **SHAP values**
# - Explore **interpretability** of learned representations with **t-SNE** and **UMAP** visualizations
#
# Let's get started!

# %% [markdown]
# ---
#
# ## Setup and Data Download Instructions
#
# Before we start, please download the **DRIAMS B database** from the following link:
#
# [https://datadryad.org/dataset/doi:10.5061/dryad.bzkh1899q#usage](https://datadryad.org/dataset/doi:10.5061/dryad.bzkh1899q#usage)
#
# > **Important:** Only download the **DRIAMS B** dataset, as the other datasets are very large and not needed for this session.
#
# Once downloaded, upload the `driams_b.tar.gz` file to the **same Google Drive folder** where this Colab notebook is saved.
#
# In the next code cell, we will:
#
# - Mount your Google Drive
# - Install necessary Python libraries
# - Unzip and extract the DRIAMS B dataset for use in this notebook
#
# Make sure the `driams_b.tar.gz` file is correctly placed before running the next cell.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Set-up

# %%
# !pip install maldi-nn
# Out:
# Collecting maldi-nn
#   Downloading maldi_nn-0.2.5-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from maldi-nn) (2.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from maldi-nn) (2.6.0+cu124)
# Collecting lightning (from maldi-nn)
#   Downloading lightning-2.5.1.post0-py3-none-any.whl.metadata (39 kB)
# Collecting h5torch>=0.2.5 (from maldi-nn)
#   Downloading h5torch-0.3.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting bio-attention (from maldi-nn)
#   Downloading bio_attention-0.1.15-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from maldi-nn) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from maldi-nn) (1.15.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from maldi-nn) (3.10.0)
# Collecting rdkit (from maldi-nn)
#   Downloading rdkit-2025.3.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Collecting selfies (from maldi-nn)
#   Downloading selfies-2.2.0-py3-none-any.whl.metadata (14 kB)
# Collecting deepsmiles (from maldi-nn)
#   Downloading deepsmiles-1.0.1-py2.py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from maldi-nn) (1.6.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (from maldi-nn) (2.1.4)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from maldi-nn) (2.18.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from h5torch>=0.2.5->maldi-nn) (3.13.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from bio-attention->maldi-nn) (0.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->maldi-nn) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->maldi-nn) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->maldi-nn) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->maldi-nn) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->maldi-nn) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->maldi-nn)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->maldi-nn)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->maldi-nn)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->maldi-nn)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->maldi-nn)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->maldi-nn)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->maldi-nn)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->maldi-nn)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->maldi-nn)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->maldi-nn) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->maldi-nn) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->maldi-nn) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->maldi-nn)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->maldi-nn) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->maldi-nn) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->maldi-nn) (1.3.0)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.11/dist-packages (from lightning->maldi-nn) (6.0.2)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning->maldi-nn)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.11/dist-packages (from lightning->maldi-nn) (24.2)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning->maldi-nn)
#   Downloading torchmetrics-1.7.2-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from lightning->maldi-nn) (4.67.1)
# Collecting pytorch-lightning (from lightning->maldi-nn)
#   Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->maldi-nn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->maldi-nn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->maldi-nn) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->maldi-nn) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->maldi-nn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->maldi-nn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->maldi-nn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->maldi-nn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->maldi-nn) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->maldi-nn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->maldi-nn) (3.6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->maldi-nn) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->maldi-nn) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->maldi-nn) (3.8)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard->maldi-nn) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->maldi-nn) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard->maldi-nn) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->maldi-nn) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->maldi-nn) (3.1.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning->maldi-nn) (3.11.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard->maldi-nn) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->maldi-nn) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->maldi-nn) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->maldi-nn) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->maldi-nn) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->maldi-nn) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->maldi-nn) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->maldi-nn) (1.20.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->maldi-nn) (3.10)
# Downloading maldi_nn-0.2.5-py3-none-any.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 50.7 MB/s eta 0:00:00
# Downloading h5torch-0.3.0-py3-none-any.whl (11 kB)
# Downloading bio_attention-0.1.15-py3-none-any.whl (17 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 54.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 31.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 55.3 MB/s eta 0:00:00
# Downloading deepsmiles-1.0.1-py2.py3-none-any.whl (12 kB)
# Downloading lightning-2.5.1.post0-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 32.1 MB/s eta 0:00:00
# Downloading rdkit-2025.3.2-cp311-cp311-manylinux_2_28_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 14.6 MB/s eta 0:00:00
# Downloading selfies-2.2.0-py3-none-any.whl (36 kB)
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading torchmetrics-1.7.2-py3-none-any.whl (962 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 962.5/962.5 kB 38.8 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 38.8 MB/s eta 0:00:00
# Installing collected packages: deepsmiles, selfies, rdkit, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchmetrics, h5torch, bio-attention, pytorch-lightning, lightning, maldi-nn
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bio-attention-0.1.15 deepsmiles-1.0.1 h5torch-0.3.0 lightning-2.5.1.post0 lightning-utilities-0.14.3 maldi-nn-0.2.5 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pytorch-lightning-2.5.1.post0 rdkit-2025.3.2 selfies-2.2.0 torchmetrics-1.7.2

# %%
#!tar -xzvf "/content/drive/MyDrive/ESCMID-AI-Data-Advances-Techniques/DRIAMS/DRIAMS-B/DRIAMS_B.tar.gz" -C "/content/drive/MyDrive/ESCMID-AI-Data-Advances-Techniques/DRIAMS/DRIAMS-B"
# !tar -xzvf "/content/drive/MyDrive/DRIAMS/DRIAMS-B/DRIAMS_B.tar.gz" -C "/content/drive/MyDrive/DRIAMS/DRIAMS-B"
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# DRIAMS-B/preprocessed/2018/e4a02174-7d3d-42b1-a28e-46e3b244fc5c.txt
# DRIAMS-B/preprocessed/2018/bbf1616c-7a74-4c5c-be02-0178ea2caef4.txt
# DRIAMS-B/preprocessed/2018/96b6b588-95ba-4ee1-9945-20f2b32e2e92.txt
# DRIAMS-B/preprocessed/2018/b7c916a0-3a0c-42ea-821d-1ba43f27fbab.txt
# DRIAMS-B/preprocessed/2018/e775c454-5e2b-4912-bbe2-6706da07b353.txt
# DRIAMS-B/preprocessed/2018/7d5d673b-1fa2-47e0-84dc-be6cb9023c99.txt
# DRIAMS-B/preprocessed/2018/d2655219-3127-4c55-868e-b2bb2c7da9fa.txt
# DRIAMS-B/preprocessed/2018/b72ab219-4616-4128-a56f-ca9f2fc8d751.txt
# DRIAMS-B/preprocessed/2018/470e6a22-3578-4d25-9eff-f6c51afad663.txt
# DRIAMS-B/preprocessed/2018/2ccb417a-9e7e-4116-9c4e-a65d216924cd.txt
# DRIAMS-B/preprocessed/2018/07451dc6-9d8d-4289-bf80-b4ef86ba86c7.txt
# DRIAMS-B/preprocessed/2018/9980ba02-f4f3-44f8-8189-5193f7410c53.txt
# DRIAMS-B/preprocessed/2018/e92aa968-e48f-4aa2-ae31-9418f8004dc7.txt
# DRIAMS-B/preprocessed/2018/36b44e7b-1671-4a46-bd88-0489bf24a717.txt
# DRIAMS-B/preprocessed/2018/6295fd76-799b-4b05-ad80-bf4ac0978a67.txt
# DRIAMS-B/preprocessed/2018/a2cb24d1-0d32-4598-b6b2-88c485cab614.txt
# DRIAMS-B/preprocessed/2018/538c31d2-602b-4118-b313-c8d74661ab77.txt
# DRIAMS-B/preprocessed/2018/98832cb4-d448-4929-bf57-f8f32cb319ba.txt
# DRIAMS-B/preprocessed/2018/827b2c28-9691-4867-b177-30f4c5877dc9.txt
# DRIAMS-B/preprocessed/2018/22171838-8d5e-4620-9986-8ca05a7178c8.txt
# DRIAMS-B/preprocessed/2018/9759c050-4765-4882-8bb5-904aad6ccac0.txt
# DRIAMS-B/preprocessed/2018/9e91630e-f771-4d9d-9876-da3e9b21d728.txt
# DRIAMS-B/preprocessed/2018/fad6d3d2-da65-4348-a59b-650ca9e4e7e0.txt
# DRIAMS-B/preprocessed/2018/67895510-b7c9-4710-8214-bb45ae9a311e.txt
# DRIAMS-B/preprocessed/2018/e5f24453-b4c9-447a-987d-bcd9d0f0cec7.txt
# DRIAMS-B/preprocessed/2018/2ec163a6-e507-470e-abf5-b91fedb9cfce.txt
# DRIAMS-B/preprocessed/2018/2ea24081-7fdc-40b2-96aa-8265c7b1f531.txt
# DRIAMS-B/preprocessed/2018/ec7a9b56-687a-4802-95c6-7dc0d3a0a42a.txt
# DRIAMS-B/preprocessed/2018/82ae52ff-0a8b-4725-81ae-66e933b9cc80.txt
# DRIAMS-B/preprocessed/2018/94785620-8faa-4672-8434-9ed5d84b53a1.txt
# DRIAMS-B/preprocessed/2018/138d81f9-534b-411e-ae66-ff4d7f9f6628.txt
# DRIAMS-B/preprocessed/2018/5c29db47-c9b7-47cc-a0bb-3fdd0b98226a.txt
# DRIAMS-B/preprocessed/2018/aa0271ea-9d8a-4ed3-941c-4ba25022cccd.txt
# DRIAMS-B/preprocessed/2018/185ff9cc-7110-4dfa-b9fb-bc841c67ba06.txt
# DRIAMS-B/preprocessed/2018/288d7e4a-5ac9-4f72-9e1f-fd33119bcc52.txt
# DRIAMS-B/preprocessed/2018/b051dd17-8241-4043-99d4-fa9114c0467e.txt
# DRIAMS-B/preprocessed/2018/e10d5006-b68c-4aee-bcc3-18c4e5cac669.txt
# DRIAMS-B/preprocessed/2018/4cb4845e-0141-4974-8ba0-e87b21855c83.txt
# DRIAMS-B/preprocessed/2018/da7d24c0-684c-4ee2-8511-34c089fabe04.txt
# DRIAMS-B/preprocessed/2018/0154bbc2-d6c7-487f-9b66-18526c4a97bf.txt
# DRIAMS-B/preprocessed/2018/4a8f740c-c78f-4769-8bf5-76948fbb4834.txt
# DRIAMS-B/preprocessed/2018/fab58754-90b2-41f0-8bb3-478b3b7b96c8.txt
# DRIAMS-B/preprocessed/2018/f8a04dd6-13bf-40fa-9cae-256026430d12.txt
# DRIAMS-B/preprocessed/2018/2925ff7c-a87b-446d-a8d7-210dff44739f.txt
# DRIAMS-B/preprocessed/2018/3dcc5a1a-afba-4feb-89a6-991dd12034ae.txt
# DRIAMS-B/preprocessed/2018/13bf85c1-50a7-4b95-a469-a783daeb3df3.txt
# DRIAMS-B/preprocessed/2018/4281ab63-f275-4fef-a813-9cce940f51a8.txt
# DRIAMS-B/preprocessed/2018/abfd0291-4e9e-47c1-89c0-c703ce4990b6.txt
# DRIAMS-B/preprocessed/2018/8454ce37-4f76-499b-a457-a434f07de263.txt
# DRIAMS-B/preprocessed/2018/2d042711-de3c-4618-b9af-b3861ee00b54.txt
# DRIAMS-B/preprocessed/2018/11b6adb1-7d04-4f76-9190-ea397f8b8619.txt
# DRIAMS-B/preprocessed/2018/ab045d5c-3cd1-460c-aac7-1827cb1d0be2.txt
# DRIAMS-B/preprocessed/2018/99c06927-8cb4-4f06-982b-192a70beeaed.txt
# DRIAMS-B/preprocessed/2018/f19b0239-ea84-4216-953e-2d2c7f21859e.txt
# DRIAMS-B/preprocessed/2018/ef351ba0-4b32-4e9a-ad79-b65ea487e5c0.txt
# DRIAMS-B/preprocessed/2018/9818afdf-cde7-4fb8-a461-f559d246dbe1.txt
# DRIAMS-B/preprocessed/2018/3de96efa-9f78-4472-9e07-69dd30f1addb.txt
# DRIAMS-B/preprocessed/2018/2d79073b-3000-407c-8ee2-da21fad84172.txt
# DRIAMS-B/preprocessed/2018/8e2e1413-fad9-497f-b7a7-b9b90382cf73.txt
# DRIAMS-B/preprocessed/2018/f2dea65b-8aa6-413c-9126-6eb5dea77687.txt
# DRIAMS-B/preprocessed/2018/5354414b-f224-4474-a799-b937606317d3.txt
# DRIAMS-B/preprocessed/2018/46f6e8a7-5a66-43e6-9999-8c1750a692c1.txt
# DRIAMS-B/preprocessed/2018/840fff6e-f58a-4cb5-a2a0-8f78dfd1d8f6.txt
# DRIAMS-B/preprocessed/2018/44106215-3179-4249-afa6-6a52c4db7ca2.txt
# DRIAMS-B/preprocessed/2018/7d7bc798-6c0c-4053-a6f8-2b67e9073a18.txt
# DRIAMS-B/preprocessed/2018/f7fdfe39-c430-4425-90e5-087987d2d544.txt
# DRIAMS-B/preprocessed/2018/8c3dac0d-478c-4d64-bb1e-aefd9f5bf90c.txt
# DRIAMS-B/preprocessed/2018/0514b3bc-74ab-43c8-9cc9-c8af6ad05868.txt
# DRIAMS-B/preprocessed/2018/ad97be82-e9c5-427b-95c0-330914d05891.txt
# DRIAMS-B/preprocessed/2018/a09056a5-b0f6-4f6e-b4a2-48765fef52ea.txt
# DRIAMS-B/preprocessed/2018/6828f148-9e53-452e-aaf3-35276eea5fb0.txt
# DRIAMS-B/preprocessed/2018/6edd06ab-62fd-48b6-864e-85b54373e0bb.txt
# DRIAMS-B/preprocessed/2018/3e5d5b95-9013-44ba-a844-f39f6b148ad1.txt
# DRIAMS-B/preprocessed/2018/987ba9fb-76ef-4bce-af7d-34bf7a25f9fe.txt
# DRIAMS-B/preprocessed/2018/9626d18e-9001-455c-95e6-49ab11f629ce.txt
# DRIAMS-B/preprocessed/2018/ca13b62d-748a-4489-b033-63b91f2185a5.txt
# DRIAMS-B/preprocessed/2018/b7f95f37-e0d6-4d3e-882b-8168269e9643.txt
# DRIAMS-B/preprocessed/2018/1d4778a1-47e8-4926-88ce-90bbac11ab6b.txt
# DRIAMS-B/preprocessed/2018/b4dcf939-d701-42d2-9a7c-8393d619ed60.txt
# DRIAMS-B/preprocessed/2018/db5557c2-d5e5-4556-b825-dc1860c65703.txt
# DRIAMS-B/preprocessed/2018/95e1d62f-0e62-4102-a94d-4839e1eaacd9.txt
# DRIAMS-B/preprocessed/2018/24e961d0-19ed-4b81-bd5b-6387546e173e.txt
# DRIAMS-B/preprocessed/2018/8ed1a67e-176b-4084-ac44-4a9115cfd2eb.txt
# DRIAMS-B/preprocessed/2018/d10f09d8-ed43-4637-a5ea-a417710ec229.txt
# DRIAMS-B/preprocessed/2018/26e74b05-ba14-4f91-922a-ab10c38b90b1.txt
# DRIAMS-B/preprocessed/2018/453813c6-04f2-425a-a242-e80c5fe9ef55.txt
# DRIAMS-B/preprocessed/2018/aef0473f-06db-4dec-9fa5-b37f6700de9b.txt
# DRIAMS-B/preprocessed/2018/aefdf36a-8e5f-4b6c-b9fd-b835378edb6e.txt
# DRIAMS-B/preprocessed/2018/c2d7f0b6-5cd6-4351-92be-9f646d5164b0.txt
# DRIAMS-B/preprocessed/2018/61723cef-6f20-481a-913d-4718b2493d4b.txt
# DRIAMS-B/preprocessed/2018/a59760aa-5647-4e32-b53c-ebf51074592a.txt
# DRIAMS-B/preprocessed/2018/648b5019-6284-45cb-92f3-7ff3857ee2ba.txt
# DRIAMS-B/preprocessed/2018/9de5e5c9-f84f-4d96-a87d-e82639475b01.txt
# DRIAMS-B/preprocessed/2018/9e986634-82c1-4c29-961c-391f8048beed.txt
# DRIAMS-B/preprocessed/2018/35604dc5-c0d1-4fcb-9074-c5be8c6fa6e5.txt
# DRIAMS-B/preprocessed/2018/33e1fa9c-481c-462d-9709-9e1dda4b4ec4.txt
# DRIAMS-B/preprocessed/2018/842ddabb-6485-426f-bcb6-1c0016a9f96c.txt
# DRIAMS-B/preprocessed/2018/369308c2-c59c-444c-9fe0-3b64985390d8.txt
# DRIAMS-B/preprocessed/2018/d99b4e2d-2085-4a97-ad7a-3d2bf5b12d85.txt
# DRIAMS-B/preprocessed/2018/7f8adbe8-3115-4569-a833-98525c5fcc64.txt
# DRIAMS-B/preprocessed/2018/44c8dd4c-479e-4327-b63e-07fa4aa4ed02.txt
# DRIAMS-B/preprocessed/2018/074258fe-2de2-44da-a40f-1ad1c293540e.txt
# DRIAMS-B/preprocessed/2018/48c797bf-4a58-4e6b-a191-0d86cbb3fc43.txt
# DRIAMS-B/preprocessed/2018/b94f09b0-7dc5-4f1c-95d6-a09bf0ed44a5.txt
# DRIAMS-B/preprocessed/2018/b0ef4817-c11e-4f37-8656-97180deaf897.txt
# DRIAMS-B/preprocessed/2018/bf48d0a2-47a6-443a-b9fe-08f37e52bed2.txt
# DRIAMS-B/preprocessed/2018/5cfc739f-eda7-4d2b-a60c-a9a6586683c5.txt
# DRIAMS-B/preprocessed/2018/12a69cf4-f630-42db-934c-7efeca032864.txt
# DRIAMS-B/preprocessed/2018/a7233d1d-29d9-43e3-9b13-9af20ac18118.txt
# DRIAMS-B/preprocessed/2018/155e44e2-ee44-4eb3-9396-3df91c9e251a.txt
# DRIAMS-B/preprocessed/2018/d48cea4e-d9d2-4767-84a6-b6976baa1ab4.txt
# DRIAMS-B/preprocessed/2018/0fa73307-a04a-4d55-8dde-064aa071ca3b.txt
# DRIAMS-B/preprocessed/2018/53554555-7fae-49c8-9c2b-a1285e6c9e63.txt
# DRIAMS-B/preprocessed/2018/a83f5f70-6551-4abc-b47f-9e6e2887cbcd.txt
# DRIAMS-B/preprocessed/2018/c07c009e-10b5-49a9-a57d-564fe6852d67.txt
# DRIAMS-B/preprocessed/2018/7e924f70-dbd1-4ce7-b44f-b4720bbb89a2.txt
# DRIAMS-B/preprocessed/2018/64f12178-9ca9-433b-8954-67e490679836.txt
# DRIAMS-B/preprocessed/2018/25e7a369-a4e3-4b3e-8204-8cace7690b70.txt
# DRIAMS-B/preprocessed/2018/1f47be1e-a125-474f-b497-f39443978403.txt
# DRIAMS-B/preprocessed/2018/90051c0b-6a85-426b-91ac-4e338f87ca72.txt
# DRIAMS-B/preprocessed/2018/bc6436a4-26e5-454d-abf0-e1f951592036.txt
# DRIAMS-B/preprocessed/2018/c43cae31-e380-4456-a85d-f3abe4983c4c.txt
# DRIAMS-B/preprocessed/2018/f35dbbe2-7aaf-4079-918b-d6e8f80b83a3.txt
# DRIAMS-B/preprocessed/2018/6b04ae5f-06d6-4ca7-9935-366fd886e3a1.txt
# DRIAMS-B/preprocessed/2018/3ce4f3e9-3d53-4206-9aab-c7d5edfad6c0.txt
# DRIAMS-B/preprocessed/2018/85f11faf-2b3e-4c6c-a369-97d517f4b8a6.txt
# DRIAMS-B/preprocessed/2018/c1f48f85-d2ca-43d7-8f2f-2ced119b5b98.txt
# DRIAMS-B/preprocessed/2018/5b052ca7-593c-4a0e-9646-fe7773e011a7.txt
# DRIAMS-B/preprocessed/2018/e96ad605-ffb8-4758-910d-88c3e87cffd6.txt
# DRIAMS-B/preprocessed/2018/f9965765-fce6-46c4-9908-97a7af93f73d.txt
# DRIAMS-B/preprocessed/2018/f98162ec-de26-4bf5-bd6d-59d3e2fde1b1.txt
# DRIAMS-B/preprocessed/2018/26bd75e1-3bd7-42c3-a7ad-7eeca7b75a58.txt
# DRIAMS-B/preprocessed/2018/7bd728fa-e591-4c42-aa41-aa6a7b16b873.txt
# DRIAMS-B/preprocessed/2018/36385833-3dbd-4e9e-ab53-761083889e68.txt
# DRIAMS-B/preprocessed/2018/d57ac679-b6e7-4d5a-a562-a8c87f746224.txt
# DRIAMS-B/preprocessed/2018/5a7f2161-ce30-4f73-a482-6eb1ce3dc870.txt
# DRIAMS-B/preprocessed/2018/e36f2979-b99e-432b-9616-d0dfb888a922.txt
# DRIAMS-B/preprocessed/2018/614cc21e-693c-4516-82ff-d0a0555ef2ad.txt
# DRIAMS-B/preprocessed/2018/e48a544c-4eed-475c-b1c7-c93a718ab7ca.txt
# DRIAMS-B/preprocessed/2018/208f4010-2d01-4933-8564-fab380183125.txt
# DRIAMS-B/preprocessed/2018/ca7b5079-91da-415e-8c3f-82bd2b1572b9.txt
# DRIAMS-B/preprocessed/2018/98daaa11-b3d0-41d7-8d94-904fcc2a35e3.txt
# DRIAMS-B/preprocessed/2018/15ef34fe-81b8-47b0-9e48-4fa1ea6200af.txt
# DRIAMS-B/preprocessed/2018/0f555b3d-b543-4168-a955-787cd5a2d0a9.txt
# DRIAMS-B/preprocessed/2018/6d7dc311-c7d7-4809-968a-ad70199c783b.txt
# DRIAMS-B/preprocessed/2018/8b2a4afe-a687-4858-a673-5ad4f830014c.txt
# DRIAMS-B/preprocessed/2018/9bf1c80b-8057-4549-8a59-281be91d0aac.txt
# DRIAMS-B/preprocessed/2018/d195e2a8-096e-40bd-89df-1941f011cbb7.txt
# DRIAMS-B/preprocessed/2018/00c6e866-f9af-4960-831c-91290e13070f.txt
# DRIAMS-B/preprocessed/2018/50cb3973-8f91-46b6-9e4e-792e506ac076.txt
# DRIAMS-B/preprocessed/2018/bc2abe92-fb12-4cec-a324-496caa596169.txt
# DRIAMS-B/preprocessed/2018/776c9461-73d8-40ee-8576-5ae07377ddd2.txt
# DRIAMS-B/preprocessed/2018/74edf9de-7f78-44af-b13f-1e922a0a85bd.txt
# DRIAMS-B/preprocessed/2018/83282467-6657-44f2-af7a-7de694fa4503.txt
# DRIAMS-B/preprocessed/2018/d4cc8595-baef-40df-9c9c-a304a120bad9.txt
# DRIAMS-B/preprocessed/2018/41530fb2-0f42-43eb-b4d1-c961cfd59d62.txt
# DRIAMS-B/preprocessed/2018/33007110-006f-431a-a17f-09d89704463f.txt
# DRIAMS-B/preprocessed/2018/7ceec524-cbea-4ede-a287-34e10200955d.txt
# DRIAMS-B/preprocessed/2018/a07a252d-cbb9-476b-854e-0146f647dc9d.txt
# DRIAMS-B/preprocessed/2018/ab3b1f86-98ce-41d8-8c56-8e36964a1e2d.txt
# DRIAMS-B/preprocessed/2018/f38c3628-8c31-47e7-8d03-866277848c2a.txt
# DRIAMS-B/preprocessed/2018/2cbdf639-023b-450e-b142-c9d78addf026.txt
# DRIAMS-B/preprocessed/2018/414d0992-3418-4fc5-9801-a95061f73a33.txt
# DRIAMS-B/preprocessed/2018/6bac2fcc-8f18-4ddc-99bb-6a516233504f.txt
# DRIAMS-B/preprocessed/2018/e7c49478-8b01-4312-ab97-6020b6da9124.txt
# DRIAMS-B/preprocessed/2018/237a9d08-17f4-4aa8-9e5d-19fc40211e4b.txt
# DRIAMS-B/preprocessed/2018/72d3527d-4e1f-4e53-b698-f029512d7a1d.txt
# DRIAMS-B/preprocessed/2018/421d8113-b8e0-4eb2-8169-a3b44360da2b.txt
# DRIAMS-B/preprocessed/2018/1b42a94a-0f68-4d86-bd7d-84c524b944e8.txt
# DRIAMS-B/preprocessed/2018/7cb60377-69ce-46bd-9fc6-8b8a7b253973.txt
# DRIAMS-B/preprocessed/2018/71a06dd6-ef6e-4433-8cc0-7d090f61c38f.txt
# DRIAMS-B/preprocessed/2018/75882485-6e6b-400b-8374-0d358bcccbe5.txt
# DRIAMS-B/preprocessed/2018/3b4a1cfa-d372-4482-b1aa-87832aaf5a6c.txt
# DRIAMS-B/preprocessed/2018/85133d85-5dda-4814-92d4-a06b2954097d.txt
# DRIAMS-B/preprocessed/2018/50dbd80f-7ce2-4435-9717-b2ec2ae30054.txt
# DRIAMS-B/preprocessed/2018/3ad67d1a-ecee-4dac-99b0-d91fd4bdb57a.txt
# DRIAMS-B/preprocessed/2018/f9ae8c1c-4991-4763-9767-17de0fd960a4.txt
# DRIAMS-B/preprocessed/2018/ef80cd8f-f110-4348-a4e3-497f69cc5b8f.txt
# DRIAMS-B/preprocessed/2018/0e415828-f954-4892-aba4-0c453bd56234.txt
# DRIAMS-B/preprocessed/2018/9b38e05e-6594-4ae4-8480-60336bd76d16.txt
# DRIAMS-B/preprocessed/2018/821936c4-3a6a-4edd-9bca-52eefbeaade3.txt
# DRIAMS-B/preprocessed/2018/4e343fb1-b7c7-4e8b-b56d-7babb4abd2de.txt
# DRIAMS-B/preprocessed/2018/3f8cad92-c7a6-4ccf-988d-592f4c6f3151.txt
# DRIAMS-B/preprocessed/2018/26175386-ba27-4061-b0ce-bf6048edb99d.txt
# DRIAMS-B/preprocessed/2018/983b6f7a-1c41-46d5-89aa-4641f0b25319.txt
# DRIAMS-B/preprocessed/2018/59050bbd-5309-42c5-b221-d3ac9425e58f.txt
# DRIAMS-B/preprocessed/2018/aa02dcfc-c75e-4a68-822b-d2568731bdf8.txt
# DRIAMS-B/preprocessed/2018/5fd49887-17fd-45e9-be6c-dec8d54e60d6.txt
# DRIAMS-B/preprocessed/2018/a621869f-8865-48d4-b1ea-3e7d00f91321.txt
# DRIAMS-B/preprocessed/2018/a5607490-07b1-43f3-8126-d4e2eb006549.txt
# DRIAMS-B/preprocessed/2018/fe4bb663-33f1-4b28-b146-6f2e6ea46fba.txt
# DRIAMS-B/preprocessed/2018/c0dd13be-d4b3-4133-be61-85b1b1431ac7.txt
# DRIAMS-B/preprocessed/2018/5deef9bf-2840-4995-9e6f-98795a5451c5.txt
# DRIAMS-B/preprocessed/2018/4d7dac11-1e74-4cee-b176-5f07ee96cea0.txt
# DRIAMS-B/preprocessed/2018/67664538-e869-44dd-b0bf-507e1740ec9d.txt
# DRIAMS-B/preprocessed/2018/4a74e3a6-d309-4b8d-b1e3-359a2f038437.txt
# DRIAMS-B/preprocessed/2018/c1dfe296-4f54-425c-add1-8828bca2139a.txt
# DRIAMS-B/preprocessed/2018/a436fc21-b3eb-4e25-b81d-edf9c5be58cf.txt
# DRIAMS-B/preprocessed/2018/b33e0574-828c-42d9-9117-4580bbfda7d7.txt
# DRIAMS-B/preprocessed/2018/a8b7403c-c726-40d4-bc44-29987ce8089e.txt
# DRIAMS-B/preprocessed/2018/3199926b-c926-4fd0-917c-f2a17df19c51.txt
# DRIAMS-B/preprocessed/2018/74757bae-a001-4e28-99a6-3b0eec9dda10.txt
# DRIAMS-B/preprocessed/2018/d75b3336-f106-4296-8e34-9442a8549c8e.txt
# DRIAMS-B/preprocessed/2018/57ff5562-c1da-474e-93fb-66d41c0bbdea.txt
# DRIAMS-B/preprocessed/2018/af97d46d-d183-4b0f-9efc-7ce3eb28d67f.txt
# DRIAMS-B/preprocessed/2018/aaaea3ba-ea33-4cdf-a31f-06d04b17a2a4.txt
# DRIAMS-B/preprocessed/2018/0d0ca134-5804-404c-bbd6-636d4f1443ce.txt
# DRIAMS-B/preprocessed/2018/6b7e9b7f-aeba-415b-ab72-09d0d58cb442.txt
# DRIAMS-B/preprocessed/2018/d034f3bf-16d8-41c3-b72b-3d897132a114.txt
# DRIAMS-B/preprocessed/2018/388e6c59-ebe2-45ab-97c1-a9e9bab808c2.txt
# DRIAMS-B/preprocessed/2018/e1e46069-be81-48bf-b657-dfff44a37593.txt
# DRIAMS-B/preprocessed/2018/0e8d6f27-8e7a-4a4c-a881-543339b2f7a5.txt
# DRIAMS-B/preprocessed/2018/50122aa9-b4c1-4b00-96bc-af35e6e3c347.txt
# DRIAMS-B/preprocessed/2018/642921d6-8155-40d0-a48a-117edfb374b7.txt
# DRIAMS-B/preprocessed/2018/8dd3a0b4-ae07-404d-a42b-6a51eeaee63e.txt
# DRIAMS-B/preprocessed/2018/92f8d347-a849-40df-a31e-c0495fe90ec5.txt
# DRIAMS-B/preprocessed/2018/6d7e94fc-c0b3-4664-99d3-adb38aa43507.txt
# DRIAMS-B/preprocessed/2018/9a1f11cd-86bb-4cbf-bede-7e35136666fe.txt
# DRIAMS-B/preprocessed/2018/2a08a125-5adb-4c1b-8e9f-dccdcaf73822.txt
# DRIAMS-B/preprocessed/2018/c6da3dac-0355-4863-8a0e-755042e3b7ea.txt
# DRIAMS-B/preprocessed/2018/2a1f4033-93f9-4403-8d07-c65238e3ccbf.txt
# DRIAMS-B/preprocessed/2018/473e2685-1cdf-4327-8120-d3e2ef654078.txt
# DRIAMS-B/preprocessed/2018/e305937f-404c-4e0b-a5fc-d97087cc9003.txt
# DRIAMS-B/preprocessed/2018/abab71e6-4865-4c5e-95b4-71638c4fb579.txt
# DRIAMS-B/preprocessed/2018/feae7bbd-4765-4762-b8d4-2f00c3946f06.txt
# DRIAMS-B/preprocessed/2018/ba737322-505a-46f0-bd8b-029c193dcd9d.txt
# DRIAMS-B/preprocessed/2018/aa3e2fc0-0687-41e3-b8e1-96cdaec181f1.txt
# DRIAMS-B/preprocessed/2018/f78cf747-24b0-4dbc-beac-3b3cff52f578.txt
# DRIAMS-B/preprocessed/2018/866234e1-e169-4eb6-83df-e3812ce8f100.txt
# DRIAMS-B/preprocessed/2018/337fc732-3eb7-486b-af4d-9f3261d799db.txt
# DRIAMS-B/preprocessed/2018/751e1217-0714-47ec-963f-8653667bcdd1.txt
# DRIAMS-B/preprocessed/2018/0462e04a-8cbb-4937-838e-82cc4b18a4ee.txt
# DRIAMS-B/preprocessed/2018/f7d8d76a-f061-40af-abf7-db8ccb159ab1.txt
# DRIAMS-B/preprocessed/2018/b9bafa20-2787-468f-ba24-4a1fd2a5adbf.txt
# DRIAMS-B/preprocessed/2018/ed89f96e-cdeb-42b1-9de3-69fabcb0a3b3.txt
# DRIAMS-B/preprocessed/2018/5e4a67c3-4909-49ba-a050-da81ca25b287.txt
# DRIAMS-B/preprocessed/2018/8dbfe181-0597-4118-ac79-bfd0d1dd0150.txt
# DRIAMS-B/preprocessed/2018/7c144863-6e63-478d-a4c1-dfea232974d6.txt
# DRIAMS-B/preprocessed/2018/52cff906-b381-4368-a8bb-c27857df28e7.txt
# DRIAMS-B/preprocessed/2018/5440956a-7695-4df9-8012-598c4c147869.txt
# DRIAMS-B/preprocessed/2018/c52e14da-6dfe-45cd-a5e9-e90c177e3dc8.txt
# DRIAMS-B/preprocessed/2018/8a4ad843-8465-4e81-b0e6-d760f8a9dd56.txt
# DRIAMS-B/preprocessed/2018/1619d90c-287e-41fb-81d8-8050cae34777.txt
# DRIAMS-B/preprocessed/2018/e4134b24-ceb4-42dd-833a-85f732f0c80e.txt
# DRIAMS-B/preprocessed/2018/26119339-cc84-43b7-bccb-b22305cc9e5c.txt
# DRIAMS-B/preprocessed/2018/914e2b3b-7f3d-4c56-b59c-68cfdc57fd0d.txt
# DRIAMS-B/preprocessed/2018/d4609c2f-706c-4582-83c4-7830cfe005be.txt
# DRIAMS-B/preprocessed/2018/989c7faf-ef4d-46d4-b383-b7fea59d3c8f.txt
# DRIAMS-B/preprocessed/2018/e052d806-ba35-472f-b97d-c47ff3a5d947.txt
# DRIAMS-B/preprocessed/2018/5bf8c7fb-0fc6-4445-b858-a9649798c81a.txt
# DRIAMS-B/preprocessed/2018/101c01d9-d6d8-4fec-9d17-9100162e71c5.txt
# DRIAMS-B/preprocessed/2018/53e7e57c-f001-4024-ac36-c1f149390ed2.txt
# DRIAMS-B/preprocessed/2018/ce762881-df47-4d47-8d97-eda0510d052c.txt
# DRIAMS-B/preprocessed/2018/5c28bbd2-c9dc-45cc-a35f-6776f88c1f28.txt
# DRIAMS-B/preprocessed/2018/4395b5c9-7abb-49ae-8c4e-572b537ee964.txt
# DRIAMS-B/preprocessed/2018/3893e677-cdd0-4a8d-8d9b-297266b6248b.txt
# DRIAMS-B/preprocessed/2018/3ef7ff8b-a46a-4c12-b84e-dc94bd5dec06.txt
# DRIAMS-B/preprocessed/2018/39a685ae-a4fb-408a-a35a-05e299302ee5.txt
# DRIAMS-B/preprocessed/2018/52721586-5ad3-45db-a5eb-06f8b95dd2a0.txt
# DRIAMS-B/preprocessed/2018/f1a09745-dbfd-46b5-a2f9-4772bc0f2255.txt
# DRIAMS-B/preprocessed/2018/c1649e43-65bb-45af-8ffc-1f9b1454a63b.txt
# DRIAMS-B/preprocessed/2018/115af664-7a18-4114-a1d7-7515b42e742f.txt
# DRIAMS-B/preprocessed/2018/50fbac1b-da0a-4440-b27a-c4af78591cf3.txt
# DRIAMS-B/preprocessed/2018/0a9bc1cd-21cc-43ed-b03b-c5620cb5ee49.txt
# DRIAMS-B/preprocessed/2018/00c968d0-6d2f-410b-ad54-8db9f734fc5e.txt
# DRIAMS-B/preprocessed/2018/6d030faa-54c3-4eb4-9e7c-5241b74a8b0e.txt
# DRIAMS-B/preprocessed/2018/925a078e-698e-4632-a09b-f59bcf6fcafd.txt
# DRIAMS-B/preprocessed/2018/6a26c5a2-5ac7-4638-83df-ed3a60285e27.txt
# DRIAMS-B/preprocessed/2018/5ec110fe-ef8b-4bff-85a4-445e7d0a902a.txt
# DRIAMS-B/preprocessed/2018/efd13418-7b26-4b40-bd65-7b3710317bb4.txt
# DRIAMS-B/preprocessed/2018/43043e20-759c-4980-8541-dfdb6d319529.txt
# DRIAMS-B/preprocessed/2018/fe425d54-3ef6-44cb-8efc-68df7a5f88c2.txt
# DRIAMS-B/preprocessed/2018/d6398262-218e-4f8c-a6d9-66d3761eb5cc.txt
# DRIAMS-B/preprocessed/2018/cc7ae91b-778f-4827-8e40-8af8954ea263.txt
# DRIAMS-B/preprocessed/2018/72fa8679-62aa-4bdf-a3b1-37a10518a7a5.txt
# DRIAMS-B/preprocessed/2018/42451ba4-2979-49ac-b3fc-dcd00d386752.txt
# DRIAMS-B/preprocessed/2018/304a88a9-4489-4a40-9da8-edba240a6dff.txt
# DRIAMS-B/preprocessed/2018/fc80a656-1742-4546-9dbe-37a44a63c12c.txt
# DRIAMS-B/preprocessed/2018/5bcea5cb-a906-4a20-8103-d41b4bc730cf.txt
# DRIAMS-B/preprocessed/2018/660cd801-cf99-4176-a4f6-59d79a4e0f3c.txt
# DRIAMS-B/preprocessed/2018/5e6d44cb-b0cd-4a2a-90ca-a15f108ddb9c.txt
# DRIAMS-B/preprocessed/2018/a5f4c686-d8a4-4024-a6ef-4fda0df6c7c9.txt
# DRIAMS-B/preprocessed/2018/cbb8992e-037c-477f-8f6a-ed1e178e5ef0.txt
# DRIAMS-B/preprocessed/2018/6d22afc8-f910-4ac2-a0ba-0949fe980905.txt
# DRIAMS-B/preprocessed/2018/0af71b3e-1d76-4524-9e1e-aed81e57179a.txt
# DRIAMS-B/preprocessed/2018/65766076-93cd-49b0-a539-5342640d4fee.txt
# DRIAMS-B/preprocessed/2018/8c8adc70-307b-40d2-9846-ba75ff04c098.txt
# DRIAMS-B/preprocessed/2018/c521d3d9-7e26-4bf2-a90b-f804b01db5bb.txt
# DRIAMS-B/preprocessed/2018/868646ba-de33-4f06-b5c8-5cc0054d0ee4.txt
# DRIAMS-B/preprocessed/2018/0dab2faf-39b6-4a43-82d7-6247f757ecef.txt
# DRIAMS-B/preprocessed/2018/4c1c4385-b1a4-417e-a0a3-cf613d81e5ab.txt
# DRIAMS-B/preprocessed/2018/6fec548d-5dac-46c5-911d-d2f420004785.txt
# DRIAMS-B/preprocessed/2018/05340d2a-55e8-4bcc-adc0-02670b9ec61b.txt
# DRIAMS-B/preprocessed/2018/8d02884b-61cc-4432-b75a-c2aae0848f6c.txt
# DRIAMS-B/preprocessed/2018/2c849379-9a54-4302-846e-fd522f712fdf.txt
# DRIAMS-B/preprocessed/2018/022d9432-2d70-423d-9657-80584020fdc2.txt
# DRIAMS-B/preprocessed/2018/0eb65fa9-1ce3-4245-b86b-25c9d5f4e805.txt
# DRIAMS-B/preprocessed/2018/f3129edd-1123-4e0e-8b39-f70f56c869de.txt
# DRIAMS-B/preprocessed/2018/d3efc386-0b31-4d45-b5bf-cb584b72f5fd.txt
# DRIAMS-B/preprocessed/2018/2ca1e698-8b1a-4c2a-8fe8-3783c1cfea23.txt
# DRIAMS-B/preprocessed/2018/5ade3337-0763-41bd-a5c8-34e7ba0ccaad.txt
# DRIAMS-B/preprocessed/2018/863cee8d-fa38-426b-9fd4-15360c8efc88.txt
# DRIAMS-B/preprocessed/2018/744f94df-2815-4d79-935e-6a951d03ea1a.txt
# DRIAMS-B/preprocessed/2018/e1eb608c-cbb9-414d-ba2f-f019199db6af.txt
# DRIAMS-B/preprocessed/2018/699bb779-cf01-419b-a45d-7ae29d473cf1.txt
# DRIAMS-B/preprocessed/2018/0a88568c-e9e7-4270-9e06-bb350453dce8.txt
# DRIAMS-B/preprocessed/2018/15440d10-7af5-49da-b34d-b378bdc75b4a.txt
# DRIAMS-B/preprocessed/2018/9f73c86b-9e74-4991-ba78-6b3b7206f96d.txt
# DRIAMS-B/preprocessed/2018/6b0deea9-9585-429b-b32e-46a7ad3716cb.txt
# DRIAMS-B/preprocessed/2018/51135566-a710-4697-affd-f8e99a91dca7.txt
# DRIAMS-B/preprocessed/2018/6a22cc66-5478-4296-b319-e16249f89e38.txt
# DRIAMS-B/preprocessed/2018/b96edea9-e6ab-48f4-b187-105976ea5bd7.txt
# DRIAMS-B/preprocessed/2018/b83a6f29-0274-4a16-be2e-879ae057a26d.txt
# DRIAMS-B/preprocessed/2018/c32d8db7-fdbc-4602-a948-a1ad23df6868.txt
# DRIAMS-B/preprocessed/2018/cca6c320-0bf6-4ed0-90a0-2428f37bf704.txt
# DRIAMS-B/preprocessed/2018/ecd8ecdf-e36f-46c4-ad2d-af0e0a9a49be.txt
# DRIAMS-B/preprocessed/2018/acaf3755-5285-44b4-ae03-0cfca10d6fa1.txt
# DRIAMS-B/preprocessed/2018/61e09320-dab2-4ca2-981b-27fea97f939c.txt
# DRIAMS-B/preprocessed/2018/194f5669-cec4-4776-a81b-913ca7ef3e29.txt
# DRIAMS-B/preprocessed/2018/73549c46-8d17-40fb-947d-f2e09668dffb.txt
# DRIAMS-B/preprocessed/2018/2c0c48ca-defb-446f-a1a1-ab1f8ede77fe.txt
# DRIAMS-B/preprocessed/2018/f1455240-b201-44fe-9dcc-f639d6767eab.txt
# DRIAMS-B/preprocessed/2018/498c9b1f-d99c-40da-bce9-88291b3437fb.txt
# DRIAMS-B/preprocessed/2018/4cdb5706-7780-4791-a9e8-69edf9065e5b.txt
# DRIAMS-B/preprocessed/2018/c64c5b9a-8731-4db6-8c1d-e0bc74f95c83.txt
# DRIAMS-B/preprocessed/2018/11159a0b-fd51-4151-90a0-022decdca3d5.txt
# DRIAMS-B/preprocessed/2018/51ae5653-b285-408c-a144-e9b88a3a6bbc.txt
# DRIAMS-B/preprocessed/2018/a9ee04c0-2cb9-4884-885f-29b145854227.txt
# DRIAMS-B/preprocessed/2018/0351cca3-6944-4a32-af38-ea46f27a5be2.txt
# DRIAMS-B/preprocessed/2018/dd664b11-4220-4c93-8177-421b98dd55e0.txt
# DRIAMS-B/preprocessed/2018/5733302a-c047-4184-8305-c16002c0f1c1.txt
# DRIAMS-B/preprocessed/2018/78b610bd-8a80-4943-82b1-307095332f62.txt
# DRIAMS-B/preprocessed/2018/381af6f0-3629-4843-b31a-6019170aebd6.txt
# DRIAMS-B/preprocessed/2018/901f8a39-906f-4db5-a0c1-df9b6ac1ff63.txt
# DRIAMS-B/preprocessed/2018/fd9ff9bf-d106-4399-aeb9-2070d54ae37b.txt
# DRIAMS-B/preprocessed/2018/59f436f9-50da-4f13-a1fc-4f935d9b35d4.txt
# DRIAMS-B/preprocessed/2018/c2c85bcd-0085-4d70-85e6-c9b03b625f44.txt
# DRIAMS-B/preprocessed/2018/8c1540e0-2aeb-4f37-b1d5-1ca044dca32b.txt
# DRIAMS-B/preprocessed/2018/f5816120-995c-4779-a759-3fe52dfee36a.txt
# DRIAMS-B/preprocessed/2018/ecc75ca2-a1c6-4125-9d5a-4f5621580950.txt
# DRIAMS-B/preprocessed/2018/da6bd9d6-b40f-4059-9779-856618751c86.txt
# DRIAMS-B/preprocessed/2018/c69d3568-3428-4cb5-ae34-60e496f6d88c.txt
# DRIAMS-B/preprocessed/2018/1b36eece-8e6b-4c5d-b20a-74507d18dad5.txt
# DRIAMS-B/preprocessed/2018/1172ab25-902c-405f-81e6-197480f54dd3.txt
# DRIAMS-B/preprocessed/2018/f420eae1-62ae-4b13-98de-50615c78aa90.txt
# DRIAMS-B/preprocessed/2018/1bac0299-bf35-4f06-b0f8-6e1d946ed463.txt
# DRIAMS-B/preprocessed/2018/851bff06-4de6-4c8e-b971-d9036c94f748.txt
# DRIAMS-B/preprocessed/2018/a83e2204-ebff-492e-a54c-fa5d1a1582d4.txt
# DRIAMS-B/preprocessed/2018/df6fe61e-eebb-4c05-9215-e0d8f225651c.txt
# DRIAMS-B/preprocessed/2018/5809942b-1f11-4650-9da2-76e9cb145e77.txt
# DRIAMS-B/preprocessed/2018/16817c8b-e4ba-4e94-9e38-b71b78464411.txt
# DRIAMS-B/preprocessed/2018/9f9fd831-3457-4ea4-8615-d02b2d757e7f.txt
# DRIAMS-B/preprocessed/2018/1a6a267b-2e97-48ed-95dc-a8a90fa93242.txt
# DRIAMS-B/preprocessed/2018/99bfd4cd-9d4d-4c69-bf76-a09574423b8a.txt
# DRIAMS-B/preprocessed/2018/eb916f29-b076-4c0f-9112-11aa5bcdf3bd.txt
# DRIAMS-B/preprocessed/2018/a8dcebba-217e-44b8-a887-45341a234290.txt
# DRIAMS-B/preprocessed/2018/28f69314-8279-4b91-852a-b7e8c47da7d3.txt
# DRIAMS-B/preprocessed/2018/9a7c7afb-b233-4c09-b2b2-712bec971834.txt
# DRIAMS-B/preprocessed/2018/e0c4ddaa-01d3-4e5c-ac69-964af4bf6869.txt
# DRIAMS-B/preprocessed/2018/48984633-ffe7-43c8-812c-7c4be3a7ea39.txt
# DRIAMS-B/preprocessed/2018/7d3708ac-083c-415a-b6a7-ad035bcec2a5.txt
# DRIAMS-B/preprocessed/2018/7c108090-c5b4-4e12-8e87-bfc4ebca471a.txt
# DRIAMS-B/preprocessed/2018/d098d658-abdc-44c6-aa04-08fa63847f09.txt
# DRIAMS-B/preprocessed/2018/7debd86f-0a38-4cf1-925d-e13fab9456d4.txt
# DRIAMS-B/preprocessed/2018/88e1e11f-352a-4d6a-ac6e-a19100c8cb91.txt
# DRIAMS-B/preprocessed/2018/a2aec51d-7024-4b2b-b965-e9957ffe5379.txt
# DRIAMS-B/preprocessed/2018/e4ca6ded-87fe-4e62-b82f-f7823cf85601.txt
# DRIAMS-B/preprocessed/2018/419f6204-e4a3-4de2-91d8-3539045f96ac.txt
# DRIAMS-B/preprocessed/2018/7d333244-baac-4394-9d01-3ad6ecea2fea.txt
# DRIAMS-B/preprocessed/2018/ece30d2d-86be-430c-bf78-f477d7083697.txt
# DRIAMS-B/preprocessed/2018/4e6dba4f-e3f4-44d1-ae95-4bd73eec713a.txt
# DRIAMS-B/preprocessed/2018/185cffdf-cc26-42f4-bd97-91d81f5b3901.txt
# DRIAMS-B/preprocessed/2018/834fbd7e-c3fe-4423-90cb-d4c14e43ded4.txt
# DRIAMS-B/preprocessed/2018/584976ce-08cb-4e6e-ae85-e0992b47e6e5.txt
# DRIAMS-B/preprocessed/2018/d6ac7060-d04d-4aba-aab1-110c8eef9fea.txt
# DRIAMS-B/preprocessed/2018/e803b9cb-d0bb-47b7-a48a-b2ee837fdc2d.txt
# DRIAMS-B/preprocessed/2018/ec2661a7-345c-413a-9bad-b0875fd529e3.txt
# DRIAMS-B/preprocessed/2018/04fd527b-834c-4db1-9683-91ef6b9cd4fa.txt
# DRIAMS-B/preprocessed/2018/95f8fb1f-a60e-4a15-9069-b880fa6f169d.txt
# DRIAMS-B/preprocessed/2018/47ed4340-57eb-42f6-8af5-65ca452c757d.txt
# DRIAMS-B/preprocessed/2018/0dc2fd20-0c7e-4965-bb99-c2dba84207ac.txt
# DRIAMS-B/preprocessed/2018/1b5c8ad7-fccb-4082-a832-b6d1e7dbe29c.txt
# DRIAMS-B/preprocessed/2018/0edf29a5-eb6e-414f-9c0f-4be341b55c81.txt
# DRIAMS-B/preprocessed/2018/f044f91d-a300-402a-a533-fd2e0d6a350e.txt
# DRIAMS-B/preprocessed/2018/832bfc90-da59-4000-9f88-b6c1dd9b0965.txt
# DRIAMS-B/preprocessed/2018/ea650752-6d21-4b9d-a2dc-1694caab90d6.txt
# DRIAMS-B/preprocessed/2018/1fe2dad2-9ea8-4a75-939b-514f5524313e.txt
# DRIAMS-B/preprocessed/2018/60baa0ab-392b-4061-942a-4b82c8a8bcd9.txt
# DRIAMS-B/preprocessed/2018/b4708fdd-92a1-4c21-a34b-cb19bee0e475.txt
# DRIAMS-B/preprocessed/2018/eed8032e-feec-4ebc-9759-85adbaba1e71.txt
# DRIAMS-B/preprocessed/2018/bf39f9b5-3757-4aac-a0dc-607d95008f87.txt
# DRIAMS-B/preprocessed/2018/5533ed9e-52cd-4614-a05a-a42877df5660.txt
# DRIAMS-B/preprocessed/2018/79998809-9402-48a1-9ae9-ee128de63d2b.txt
# DRIAMS-B/preprocessed/2018/c9e83657-10e0-4e57-98a8-16d04c990b2d.txt
# DRIAMS-B/preprocessed/2018/83dcceb9-d2be-4338-b3bd-409abe39b78e.txt
# DRIAMS-B/preprocessed/2018/2adede4f-565a-4bf9-8db8-ca995462469e.txt
# DRIAMS-B/preprocessed/2018/7540f434-1fc3-4219-afef-aa335de00371.txt
# DRIAMS-B/preprocessed/2018/8c7df5ff-196c-4d49-9a9b-0b8568f3b7ac.txt
# DRIAMS-B/preprocessed/2018/77ac911b-0636-4011-9cd1-e8f9a7558ea7.txt
# DRIAMS-B/preprocessed/2018/3f834917-0e19-4852-9598-fe3b274f2b72.txt
# DRIAMS-B/preprocessed/2018/74425020-6951-4ccb-b88e-217d079b6719.txt
# DRIAMS-B/preprocessed/2018/073c6789-9956-4de3-b35d-3bd480bc4a78.txt
# DRIAMS-B/preprocessed/2018/d5bb4389-5053-4107-9c05-bfed9e9159c9.txt
# DRIAMS-B/preprocessed/2018/214918fb-67ff-4a93-944e-dd9d1126db80.txt
# DRIAMS-B/preprocessed/2018/28154236-93a9-425a-8a0a-790b647000bc.txt
# DRIAMS-B/preprocessed/2018/f7b63f59-5e11-41b8-b047-003aaf6e3215.txt
# DRIAMS-B/preprocessed/2018/592e5cab-2d09-4e9c-9d37-de8c15859646.txt
# DRIAMS-B/preprocessed/2018/f9a4d93f-f7a9-4c5c-8049-83d7456e9d1c.txt
# DRIAMS-B/preprocessed/2018/72312e47-5689-48a6-b847-74f55aa2226f.txt
# DRIAMS-B/preprocessed/2018/6d1ea066-1c3d-4bfc-8fbf-490949d8b06f.txt
# DRIAMS-B/preprocessed/2018/2f1f20b0-0131-445e-94aa-77ae7ac81694.txt
# DRIAMS-B/preprocessed/2018/89682f40-53d8-49b4-8471-52e7c6646b67.txt
# DRIAMS-B/preprocessed/2018/80ab0ed7-008d-4910-a930-3367ae18ca5f.txt
# DRIAMS-B/preprocessed/2018/d81ad2e6-dcb8-41b3-bc1c-16753e8f58a8.txt
# DRIAMS-B/preprocessed/2018/f0dd5c7c-0b7e-46d8-b2f3-37512d72a440.txt
# DRIAMS-B/preprocessed/2018/22348e96-fcf9-4e0e-8dc1-74cc58d977f5.txt
# DRIAMS-B/preprocessed/2018/87fb901a-080d-4238-bd8a-37b002397347.txt
# DRIAMS-B/preprocessed/2018/cf9a36a5-97f5-41d3-8777-dead135c5150.txt
# DRIAMS-B/preprocessed/2018/31ecfab1-b6b6-435b-95e0-77c2eab87cf1.txt
# DRIAMS-B/preprocessed/2018/0c181662-e947-442e-93e7-eaf4865468d7.txt
# DRIAMS-B/preprocessed/2018/cb2002fb-46ff-4214-b32d-c5d34081ec1e.txt
# DRIAMS-B/preprocessed/2018/b1af07b8-567f-49ff-a8d4-90b517f30c62.txt
# DRIAMS-B/preprocessed/2018/8f4befa3-cfdf-4d50-bc7d-a8f1e79795c8.txt
# DRIAMS-B/preprocessed/2018/81f0bfac-ec5d-4f1c-8c08-712c94d2edf7.txt
# DRIAMS-B/preprocessed/2018/8342fe0e-528f-4b11-bd46-7c6ade2ab658.txt
# DRIAMS-B/preprocessed/2018/202d21bf-89a3-4c45-9401-6286656eade3.txt
# DRIAMS-B/preprocessed/2018/e225a1b9-20c9-4533-9b8e-ed6278f2b199.txt
# DRIAMS-B/preprocessed/2018/050db8bd-82c1-449d-b5ca-d63ed6885281.txt
# DRIAMS-B/preprocessed/2018/9b21ea7e-eb6a-475c-9a56-e0332a3528a1.txt
# DRIAMS-B/preprocessed/2018/2b657a1b-cc28-4af7-af38-26278b984add.txt
# DRIAMS-B/preprocessed/2018/ef8dfa20-6e30-4694-ac7c-16b3bed811b7.txt
# DRIAMS-B/preprocessed/2018/928b8f0c-fcc9-4345-83c8-3856626d1a37.txt
# DRIAMS-B/preprocessed/2018/0ca7c83a-d90e-4d7d-b584-456788615ce0.txt
# DRIAMS-B/preprocessed/2018/00766733-6235-441b-befe-70a16fc62276.txt
# DRIAMS-B/preprocessed/2018/e116fecf-2c1e-44e3-b65d-d4826bc4c5bf.txt
# DRIAMS-B/preprocessed/2018/a9c644f1-5966-4316-847a-8c5acf75cb34.txt
# DRIAMS-B/preprocessed/2018/284099ec-c2d0-434d-a671-c0c1958fcd72.txt
# DRIAMS-B/preprocessed/2018/6919aa03-5cd6-4bf1-b6af-6973edbca2b3.txt
# DRIAMS-B/preprocessed/2018/3a1d4dea-2d76-4b0d-9268-3d3aefad1b5c.txt
# DRIAMS-B/preprocessed/2018/d74f42ac-21e4-429d-85c6-92eeb988c40f.txt
# DRIAMS-B/preprocessed/2018/bb800f05-d785-4d23-bef7-6800c3f87d93.txt
# DRIAMS-B/preprocessed/2018/cec50fa0-c863-4560-96a3-4a47a1ec8e98.txt
# DRIAMS-B/preprocessed/2018/c897ece2-4d36-4e61-90c4-1875a1d08c82.txt
# DRIAMS-B/preprocessed/2018/f0d478ae-63ea-4908-bb10-9e6da6d7ac85.txt
# DRIAMS-B/preprocessed/2018/4b26d0e2-fc05-4f9e-a571-e74e18977114.txt
# DRIAMS-B/preprocessed/2018/bfe01e8d-af7d-431c-a015-27783712c382.txt
# DRIAMS-B/preprocessed/2018/9f02c3fe-1bc9-418d-8cd6-06cb8fc9455b.txt
# DRIAMS-B/preprocessed/2018/47882204-0a8f-4bb8-a2c1-7d535c20a7ff.txt
# DRIAMS-B/preprocessed/2018/c2edf594-c975-4f50-ab1f-de671306e37a.txt
# DRIAMS-B/preprocessed/2018/b1ba4529-3175-43c7-8030-05f010c0a6bb.txt
# DRIAMS-B/preprocessed/2018/e910ba54-12ad-4db6-a6d0-d7dd47c492f1.txt
# DRIAMS-B/preprocessed/2018/33082c2c-eacf-41dc-a6a4-7a677be708f3.txt
# DRIAMS-B/preprocessed/2018/a4df3c8a-0c7e-4f11-b8fd-13b12ded478b.txt
# DRIAMS-B/preprocessed/2018/65f71dd7-607f-4ce0-b7a5-86dce42862ae.txt
# DRIAMS-B/preprocessed/2018/7ac1ca33-50cb-4134-91fc-a3077094b41e.txt
# DRIAMS-B/preprocessed/2018/602d9bc2-62d0-4047-901f-c7d22a284c5b.txt
# DRIAMS-B/preprocessed/2018/b91b1acb-f4f6-4dbe-823a-541c7e0d32c2.txt
# DRIAMS-B/preprocessed/2018/58a75e66-6069-4996-a843-11d246d0f992.txt
# DRIAMS-B/preprocessed/2018/8b8bb3ee-1b52-4206-a318-bc086f7a9933.txt
# DRIAMS-B/preprocessed/2018/d8ce89d2-bfbb-4179-9023-fb73c35b4fa5.txt
# DRIAMS-B/preprocessed/2018/15c9ebff-8bc7-4172-b4a4-c95c54309396.txt
# DRIAMS-B/preprocessed/2018/45fcc2c3-0424-4bab-9e8e-1b0b9c7938af.txt
# DRIAMS-B/preprocessed/2018/8de87ce0-bc2b-4d07-aae6-1442d6b7762b.txt
# DRIAMS-B/preprocessed/2018/6072c8a4-51ab-4389-8f0b-4f63a9d840fd.txt
# DRIAMS-B/preprocessed/2018/e8db43df-a34d-40fa-a354-a28748e2c5f5.txt
# DRIAMS-B/preprocessed/2018/7ca1cfba-0918-40ba-8c14-62062bc7cab9.txt
# DRIAMS-B/preprocessed/2018/f0efaf69-1f2f-4b4c-9e64-9f28732fd09d.txt
# DRIAMS-B/preprocessed/2018/4c5bf6bb-fc58-4fad-929c-7d9cfafddc8c.txt
# DRIAMS-B/preprocessed/2018/58b7e72d-34eb-44d6-9dca-92f2a7fdb6b1.txt
# DRIAMS-B/preprocessed/2018/f82147e1-1a84-4316-b018-8479fdefb30c.txt
# DRIAMS-B/preprocessed/2018/35601add-a607-4185-9b99-ed8866b907e8.txt
# DRIAMS-B/preprocessed/2018/aae24df7-87f7-409d-8e08-9d05a65d9c42.txt
# DRIAMS-B/preprocessed/2018/548812db-9043-457a-8c7b-7aaea7daad03.txt
# DRIAMS-B/preprocessed/2018/284c9a23-88ef-477a-886b-13cab1cd08f1.txt
# DRIAMS-B/preprocessed/2018/96ef5538-3aa2-4907-ab32-8076fe049b16.txt
# DRIAMS-B/preprocessed/2018/141fae40-66a3-4600-b791-9ed6b2816bf4.txt
# DRIAMS-B/preprocessed/2018/a00374ad-9de7-4777-ab7c-f888361f1aa3.txt
# DRIAMS-B/preprocessed/2018/c900cc1e-cff1-4d48-9549-ab26d3244bba.txt
# DRIAMS-B/preprocessed/2018/8574cc79-0582-4350-a5c8-3bd86e45839c.txt
# DRIAMS-B/preprocessed/2018/09b63e4b-deff-400b-8a6d-65a8eb1d4db2.txt
# DRIAMS-B/preprocessed/2018/e6ef6bcc-5831-4eff-a748-a291f544baea.txt
# DRIAMS-B/preprocessed/2018/7313833b-4b26-446c-9b1c-049d21c1e1e9.txt
# DRIAMS-B/preprocessed/2018/11c04712-760f-4081-844a-d2a8f7de4088.txt
# DRIAMS-B/preprocessed/2018/37d615f1-a009-43b1-8190-5625c8771928.txt
# DRIAMS-B/preprocessed/2018/dd3f1b7f-241c-4c6f-8b6e-7339a3bdd8c7.txt
# DRIAMS-B/preprocessed/2018/a691a071-3eab-4855-8af6-928ac8cad57b.txt
# DRIAMS-B/preprocessed/2018/ddf8c461-f07e-4853-9040-9407d7dbc7a7.txt
# DRIAMS-B/preprocessed/2018/29a5ecab-4e63-4e66-920c-cecc4b638b7a.txt
# DRIAMS-B/preprocessed/2018/70ff5a11-5600-446d-95e9-b60144f67611.txt
# DRIAMS-B/preprocessed/2018/5a048b37-7281-4eb6-a09d-bb051167a7fd.txt
# DRIAMS-B/preprocessed/2018/69387ebd-caba-420f-9bcb-79c30ffcc92e.txt
# DRIAMS-B/preprocessed/2018/9751137f-f782-4355-90ef-3d782cf05a99.txt
# DRIAMS-B/preprocessed/2018/33e79ac1-2cd2-4af2-950b-24b29a4a93ed.txt
# DRIAMS-B/preprocessed/2018/d24e25e2-4524-455a-91e5-f913d29107f4.txt
# DRIAMS-B/preprocessed/2018/08839814-b105-4c1b-8468-74d18bb16511.txt
# DRIAMS-B/preprocessed/2018/ff89d32c-345f-4b45-85a2-10af3d52f0b3.txt
# DRIAMS-B/preprocessed/2018/a07165b4-43eb-4ade-aa5d-4f6c37acc881.txt
# DRIAMS-B/preprocessed/2018/76e38d24-86c7-4eee-bcf3-146491f68ddf.txt
# DRIAMS-B/preprocessed/2018/ff3751e9-a2c0-4902-9d8d-43dd5f7b26a6.txt
# DRIAMS-B/preprocessed/2018/e6d1a6fd-d535-4a92-b420-9aed99f9a054.txt
# DRIAMS-B/preprocessed/2018/23ae2ac7-59cf-4f03-a8d0-601ebdc77941.txt
# DRIAMS-B/preprocessed/2018/6080ab2d-6f45-48f0-a1de-980a68e2ef55.txt
# DRIAMS-B/preprocessed/2018/ae3e5dbb-7346-4690-ab6e-f7cdb9d8caa3.txt
# DRIAMS-B/preprocessed/2018/c78a5566-390c-46d5-a626-d0ab09db2895.txt
# DRIAMS-B/preprocessed/2018/c7c94a02-9ae5-4b09-9b7d-af48ec42eece.txt
# DRIAMS-B/preprocessed/2018/59f50f13-933a-4efb-82f5-bcb91b30363d.txt
# DRIAMS-B/preprocessed/2018/eac8f144-17dc-4892-b217-dcbd11faa20a.txt
# DRIAMS-B/preprocessed/2018/b4349058-b4ec-46c7-ba00-891e2d0e0654.txt
# DRIAMS-B/preprocessed/2018/9da21332-a1ae-48bd-a00a-e37780b106a9.txt
# DRIAMS-B/preprocessed/2018/e7824a3d-350a-4e16-9ada-8bf30e8630b4.txt
# DRIAMS-B/preprocessed/2018/727c91e7-2f3d-4e10-beca-426c53bea94f.txt
# DRIAMS-B/preprocessed/2018/778e62fb-b3e7-416a-87ce-b8d6e31e54a8.txt
# DRIAMS-B/preprocessed/2018/ac8d92f4-d330-4f2a-9909-ba5019d3bffa.txt
# DRIAMS-B/preprocessed/2018/a6da54a4-d6df-422a-9043-cc01afc25600.txt
# DRIAMS-B/preprocessed/2018/b42b9695-2b44-4ef8-955c-c434a195328a.txt
# DRIAMS-B/preprocessed/2018/0725bd0c-4dd3-4856-9032-a309d54127ca.txt
# DRIAMS-B/preprocessed/2018/38bc1188-540e-43d5-a1dc-24d3038552b3.txt
# DRIAMS-B/preprocessed/2018/509cce18-5655-4087-b286-99bb07f322b8.txt
# DRIAMS-B/preprocessed/2018/5ec40853-2263-441c-807b-9789f21d5713.txt
# DRIAMS-B/preprocessed/2018/2b03f053-541b-40fa-addf-98cb277e08e4.txt
# DRIAMS-B/preprocessed/2018/aac1e3dc-8fdb-46c9-a3d0-d58559914e97.txt
# DRIAMS-B/preprocessed/2018/87ecfd8d-fa8e-478b-8fc0-3ee4b621008c.txt
# DRIAMS-B/preprocessed/2018/49418180-7675-47f2-8861-c022b4a4cf6e.txt
# DRIAMS-B/preprocessed/2018/7fa72a3c-5029-4700-ab2c-7d1a5511dca9.txt
# DRIAMS-B/preprocessed/2018/56c6e2aa-13fe-416a-86ec-0de57dfa1d60.txt
# DRIAMS-B/preprocessed/2018/ad923a70-4d4e-43dd-afd8-b7c312b36202.txt
# DRIAMS-B/preprocessed/2018/36392633-3c03-4ded-a740-704e2d1e1a63.txt
# DRIAMS-B/preprocessed/2018/996945df-ba6c-4b1e-a2f9-29d709e406ac.txt
# DRIAMS-B/preprocessed/2018/257d2c17-296f-49b1-be96-fd688574710a.txt
# DRIAMS-B/preprocessed/2018/c617b314-5516-49ba-abec-70d442a91e48.txt
# DRIAMS-B/preprocessed/2018/1ab34ba0-90bc-4c8a-986a-ed31fc923079.txt
# DRIAMS-B/preprocessed/2018/acbbde07-13e6-4bcb-a96f-96598f5f9dd0.txt
# DRIAMS-B/preprocessed/2018/7d397b8a-9159-47c9-bbc7-de87faba2d21.txt
# DRIAMS-B/preprocessed/2018/b4182e47-8b71-4ac4-9d85-4f29b4e4a63e.txt
# DRIAMS-B/preprocessed/2018/3c896dca-a67d-49de-a612-1a06ec0cb1cf.txt
# DRIAMS-B/preprocessed/2018/be6081e2-aa9c-488f-917d-7f6e153797b8.txt
# DRIAMS-B/preprocessed/2018/3d38259a-78da-4287-9595-def6d37b7c55.txt
# DRIAMS-B/preprocessed/2018/41ca22c3-3e76-4672-8b86-9e2c3e1fe93b.txt
# DRIAMS-B/preprocessed/2018/faee5d4e-0007-4103-970b-1791ccd07d33.txt
# DRIAMS-B/preprocessed/2018/a2fd746d-51fa-4cc1-a7e5-a1a12eca5fb7.txt
# DRIAMS-B/preprocessed/2018/660bce93-3bfc-41b6-a0f6-68ef53500a53.txt
# DRIAMS-B/preprocessed/2018/634a1c97-6237-412d-8786-00af8abcadaf.txt
# DRIAMS-B/preprocessed/2018/6d262457-dd3c-4206-b06b-290bdccbc8e1.txt
# DRIAMS-B/preprocessed/2018/93715360-8cca-4a35-b396-4860d408fa44.txt
# DRIAMS-B/preprocessed/2018/8d5f4164-f0bd-4818-a2e6-655cbdf35db2.txt
# DRIAMS-B/preprocessed/2018/68e2da12-c555-4ca1-97e5-679adb498520.txt
# DRIAMS-B/preprocessed/2018/3845e13a-ac7e-47c2-84c3-b1bbbd1c4f16.txt
# DRIAMS-B/preprocessed/2018/b583f237-78ef-43b9-8c10-0501468476b5.txt
# DRIAMS-B/preprocessed/2018/eb3c73e9-3883-49d5-9ee6-7b8c52cd4b8d.txt
# DRIAMS-B/preprocessed/2018/8be5c228-850a-4b33-b0a8-a761f2ba26e9.txt
# DRIAMS-B/preprocessed/2018/8855c41d-3f40-4052-8ee5-a8387cf87052.txt
# DRIAMS-B/preprocessed/2018/45b07aa4-3a34-45c0-b747-49b9032d2b98.txt
# DRIAMS-B/preprocessed/2018/99eab27d-c88e-4b97-8605-605f9f7a93ce.txt
# DRIAMS-B/preprocessed/2018/40d20be0-61b3-4ff6-9c6f-fd0e98eaa346.txt
# DRIAMS-B/preprocessed/2018/587d64f2-a5ef-4353-8609-a06bf13feaf7.txt
# DRIAMS-B/preprocessed/2018/8fcec632-331f-4006-b898-e1fd3dd49a4c.txt
# DRIAMS-B/preprocessed/2018/cae5f55d-f07c-49f3-a3a7-22e435af156f.txt
# DRIAMS-B/preprocessed/2018/2ca9670e-3890-40c7-a559-bb247513d1e3.txt
# DRIAMS-B/preprocessed/2018/3b8f95d7-3a83-43ea-b400-99c33f92cb72.txt
# DRIAMS-B/preprocessed/2018/f1ab67c0-71b9-4465-aea0-ee6e898dec33.txt
# DRIAMS-B/preprocessed/2018/7103811a-5f09-4035-b37b-85e6f2bf9102.txt
# DRIAMS-B/preprocessed/2018/467e2a11-cc0f-42db-9228-b962a483bc30.txt
# DRIAMS-B/preprocessed/2018/d6dfbb4f-7be0-4e6b-97bf-0a6b976a42a9.txt
# DRIAMS-B/preprocessed/2018/36c01403-4ad3-4e22-a8d4-369b66387cc6.txt
# DRIAMS-B/preprocessed/2018/300b4be4-d076-49b9-9e79-d03bf28bd038.txt
# DRIAMS-B/preprocessed/2018/33f716cb-80d3-41a4-b69e-9ccb3076a2b0.txt
# DRIAMS-B/preprocessed/2018/845be54c-7e45-4ae8-ad05-1b1efd6d6226.txt
# DRIAMS-B/preprocessed/2018/8bd4dd78-8a98-427a-aee4-ea3ae453e6f8.txt
# DRIAMS-B/preprocessed/2018/93a78d52-45c0-48a5-8094-d760d695d6f8.txt
# DRIAMS-B/preprocessed/2018/9e248310-6f3d-4519-900f-c6fb4f822501.txt
# DRIAMS-B/preprocessed/2018/ca26a535-b4bf-462d-992f-99c998453792.txt
# DRIAMS-B/preprocessed/2018/7a63290b-dfce-48a7-9e92-e3070ae07294.txt
# DRIAMS-B/preprocessed/2018/2f6b0458-eba3-4982-8428-8b666f4b5bbb.txt
# DRIAMS-B/preprocessed/2018/b3ec8c2c-3c6d-446c-ad6b-03319bea586d.txt
# DRIAMS-B/preprocessed/2018/03f22188-4202-4d5f-b43b-c3f6da79fb86.txt
# DRIAMS-B/preprocessed/2018/90512516-43c0-48a2-a226-b8e6a4c97b02.txt
# DRIAMS-B/preprocessed/2018/19946915-bc70-4152-a463-1feb2cad9516.txt
# DRIAMS-B/preprocessed/2018/f214d6bc-c6a2-4e0a-a0a4-5dfd019157e7.txt
# DRIAMS-B/preprocessed/2018/e1570ef5-89f1-4e6b-9a73-dbaebe15519c.txt
# DRIAMS-B/preprocessed/2018/e81f1ece-e3b9-4d83-9bf9-0e98c6b5465f.txt
# DRIAMS-B/preprocessed/2018/f24d2a2e-bf36-4d61-b72c-ae2fed5372f3.txt
# DRIAMS-B/preprocessed/2018/84c769eb-cbfe-4138-adc8-f38bcf91ec08.txt
# DRIAMS-B/preprocessed/2018/65559786-f437-47ec-9c4f-671309f6888d.txt
# DRIAMS-B/preprocessed/2018/38ba43ae-a18b-4776-b330-39ae99bb11fd.txt
# DRIAMS-B/preprocessed/2018/651d4b43-3fdd-48d4-ad59-505a0fd12855.txt
# DRIAMS-B/preprocessed/2018/e910e8b8-47df-4f01-93ad-926f224a13a6.txt
# DRIAMS-B/preprocessed/2018/756c1c6a-0928-4cfe-8477-ecf9587fa866.txt
# DRIAMS-B/preprocessed/2018/9bf36d73-8f48-4cfb-b17f-c81303897a73.txt
# DRIAMS-B/preprocessed/2018/59004b13-b9f5-4733-ac69-e89001c7eaf4.txt
# DRIAMS-B/preprocessed/2018/41dc3688-d611-4f2b-9aef-649c8f8fe96b.txt
# DRIAMS-B/preprocessed/2018/58510af9-3e12-4b68-99fe-dd4de32a83ab.txt
# DRIAMS-B/preprocessed/2018/59212a28-d655-4d13-b8b9-465f9548e13c.txt
# DRIAMS-B/preprocessed/2018/621a7bc6-b25d-4d0b-8b8f-7681eeb7e247.txt
# DRIAMS-B/preprocessed/2018/b792fcd3-fab9-4776-b311-9e026f00346f.txt
# DRIAMS-B/preprocessed/2018/3913e9fe-b349-4e64-93f3-9b289525912f.txt
# DRIAMS-B/preprocessed/2018/6c5f04f8-3967-4860-9b57-de079e1bb65e.txt
# DRIAMS-B/preprocessed/2018/1b2f4728-cf1b-4b94-9e2a-c399ff9a717c.txt
# DRIAMS-B/preprocessed/2018/da569f0d-e21d-4eff-ae23-422bf5c0ce66.txt
# DRIAMS-B/preprocessed/2018/9a3958fc-43b1-4e10-a268-58fde33369f1.txt
# DRIAMS-B/preprocessed/2018/187d2e78-3660-4bbb-901b-dab6e13efdf9.txt
# DRIAMS-B/preprocessed/2018/ea902242-d72c-49e0-a831-0ae2c338c7d3.txt
# DRIAMS-B/preprocessed/2018/f2be3313-cf96-41d0-bd6c-4c7d69bc1fba.txt
# DRIAMS-B/preprocessed/2018/401cc23f-8afa-4c64-8072-f39c6966eaf3.txt
# DRIAMS-B/preprocessed/2018/0b11a853-8592-4b9c-ac2e-6a2886384ffa.txt
# DRIAMS-B/preprocessed/2018/18b05b94-00c7-4be9-b3b1-5d1709d1a7c0.txt
# DRIAMS-B/preprocessed/2018/c6214394-e823-4c73-b500-6823e842502e.txt
# DRIAMS-B/preprocessed/2018/8c72c28e-e790-445c-b856-2fbc6ed6f2c0.txt
# DRIAMS-B/preprocessed/2018/c2fb71d1-344c-440a-959d-e2316b6615cf.txt
# DRIAMS-B/preprocessed/2018/c5b7d60a-1a47-4f47-9d0f-6d5970356a07.txt
# DRIAMS-B/preprocessed/2018/8da6a3d2-6a92-4019-a046-e1e754e77e6c.txt
# DRIAMS-B/preprocessed/2018/487b5e8e-23f4-4d97-97dc-97aeb811d716.txt
# DRIAMS-B/preprocessed/2018/4334d010-c010-4ca5-9535-d60cccb8fd61.txt
# DRIAMS-B/preprocessed/2018/90367cf5-07db-4445-abb4-9f2786b4f5d0.txt
# DRIAMS-B/preprocessed/2018/1b82bb42-b923-491b-b57e-33034efcfc16.txt
# DRIAMS-B/preprocessed/2018/485cef5c-a5c8-4c1e-a356-69cf6431a65f.txt
# DRIAMS-B/preprocessed/2018/a6f48e05-c359-4437-8e44-bc2c10c2e1b2.txt
# DRIAMS-B/preprocessed/2018/b7eef740-9557-40f6-a176-3303baf533e5.txt
# DRIAMS-B/preprocessed/2018/81a72416-ac1c-4a98-8ea3-ed3de3f057dd.txt
# DRIAMS-B/preprocessed/2018/b9a16da9-1f44-4175-801e-bef6e06e8391.txt
# DRIAMS-B/preprocessed/2018/bcc2fb34-e7ff-4236-8964-51360bc46917.txt
# DRIAMS-B/preprocessed/2018/7e664a86-2dc9-469e-a099-5342f93eb259.txt
# DRIAMS-B/preprocessed/2018/522a9666-4545-43d8-bb05-3e7c0b66e15e.txt
# DRIAMS-B/preprocessed/2018/2f2d9b74-320a-4649-922f-0088c3750f38.txt
# DRIAMS-B/preprocessed/2018/aa8646cb-8d26-412c-be94-9aad3984bbe0.txt
# DRIAMS-B/preprocessed/2018/0fb79584-4fb7-4e4d-94d8-1ab0beb90e18.txt
# DRIAMS-B/preprocessed/2018/f7dde417-de3d-4bc5-b63a-6bb77ac96b66.txt
# DRIAMS-B/preprocessed/2018/28e2771b-b465-4a12-8ef9-dd32708acce4.txt
# DRIAMS-B/preprocessed/2018/7cdadea2-1469-4929-bc92-54f1d43f3db3.txt
# DRIAMS-B/preprocessed/2018/190c1912-b3da-40b0-a347-2c12a47776d4.txt
# DRIAMS-B/preprocessed/2018/a64d2959-108a-4f5f-ae45-12ec4d3b331a.txt
# DRIAMS-B/preprocessed/2018/21da7736-18f4-4ef0-af45-d25b615739e7.txt
# DRIAMS-B/preprocessed/2018/49c2dc53-52f4-4a5c-a238-c1eeec58d766.txt
# DRIAMS-B/preprocessed/2018/8fb1ec71-03cf-41f0-8874-6199a589d233.txt
# DRIAMS-B/preprocessed/2018/a67d24b5-a39b-48b9-9adf-79d717434789.txt
# DRIAMS-B/preprocessed/2018/55196024-7d03-44fb-9316-c87d658a89ac.txt
# DRIAMS-B/preprocessed/2018/7aa7b013-205d-4070-8009-97bd44a4b423.txt
# DRIAMS-B/preprocessed/2018/1197ac6f-fe17-4021-8e44-ea19f3e3689a.txt
# DRIAMS-B/preprocessed/2018/5a342907-333e-47ae-b91e-2476e6aa3c03.txt
# DRIAMS-B/preprocessed/2018/73b69488-235c-4865-b648-7e6f19020975.txt
# DRIAMS-B/preprocessed/2018/881e4ead-215c-4432-91ff-d5d7ca4b1890.txt
# DRIAMS-B/preprocessed/2018/a464c3c4-d51f-494d-a2e7-ed735a0412d6.txt
# DRIAMS-B/preprocessed/2018/1167be57-222c-4e77-959f-0ffa11f7b5a3.txt
# DRIAMS-B/preprocessed/2018/9c6eb35d-6324-44d8-9bb6-567034e1d3e1.txt
# DRIAMS-B/preprocessed/2018/802aa8a3-04a6-4852-ade2-69dd0d7deac2.txt
# DRIAMS-B/preprocessed/2018/d434cd85-f1f9-442f-b9e8-b802a608398d.txt
# DRIAMS-B/preprocessed/2018/eea04013-7051-4c9e-9035-a469a57ce569.txt
# DRIAMS-B/preprocessed/2018/919b1aeb-99c0-48c0-aec4-eccf8d2e61f3.txt
# DRIAMS-B/preprocessed/2018/6d91b997-68a5-4526-a18c-f6c8b0b10d63.txt
# DRIAMS-B/preprocessed/2018/3c3ead3d-9c6d-401f-b37d-e8935d18b010.txt
# DRIAMS-B/preprocessed/2018/660b9306-b4a5-424e-a017-c291cc72b069.txt
# DRIAMS-B/preprocessed/2018/e5883ae2-9fe2-43f8-8d00-a36eec75bad8.txt
# DRIAMS-B/preprocessed/2018/9e6f008f-c2e0-42a1-a6c0-f28b0cb4d768.txt
# DRIAMS-B/preprocessed/2018/a7225c84-5bd5-4968-adfd-8abf53fba943.txt
# DRIAMS-B/preprocessed/2018/6a32c115-5ceb-4e26-bf10-7c22015eed29.txt
# DRIAMS-B/preprocessed/2018/5c220056-33b3-4b13-9ca0-6d675d855e5b.txt
# DRIAMS-B/preprocessed/2018/dd592176-0628-4d15-9c43-e4b81a6144b7.txt
# DRIAMS-B/preprocessed/2018/04f2eff8-f731-480d-86be-d96e0879bbfb.txt
# DRIAMS-B/preprocessed/2018/9135b65f-ff90-4e0d-aa26-662c50256001.txt
# DRIAMS-B/preprocessed/2018/b8eb58cf-9f30-4841-b3b0-dd8abb6ea7dd.txt
# DRIAMS-B/preprocessed/2018/130adc3f-021b-44c9-9526-ac4f6f3ced0b.txt
# DRIAMS-B/preprocessed/2018/288c7ead-fed4-487a-8235-585315cbd7a2.txt
# DRIAMS-B/preprocessed/2018/938ad80c-6a1b-45e0-9a8a-3097562d6a0b.txt
# DRIAMS-B/preprocessed/2018/94e2cfd5-af6b-47cd-afd2-9b25a57e1c9c.txt
# DRIAMS-B/preprocessed/2018/bdaf2903-516d-4e49-9b9d-894e00bf1264.txt
# DRIAMS-B/preprocessed/2018/16708ab4-d657-489f-8e81-070a848cd606.txt
# DRIAMS-B/preprocessed/2018/30d0195e-d366-4a13-bf44-279ae8cd64da.txt
# DRIAMS-B/preprocessed/2018/59798d04-5dd1-4cd8-a887-8a80fa1724e4.txt
# DRIAMS-B/preprocessed/2018/0c155f67-5cc0-4344-b3b6-6b014734cd64.txt
# DRIAMS-B/preprocessed/2018/50160fcb-5bb3-45d6-ad57-3aad07b06bd4.txt
# DRIAMS-B/preprocessed/2018/2e852c62-9136-42b2-b59c-32fb68d12eab.txt
# DRIAMS-B/preprocessed/2018/1315e40c-a3a2-46d5-a586-bdc86ae3e739.txt
# DRIAMS-B/preprocessed/2018/11d5722f-1659-46bb-b712-99b712131847.txt
# DRIAMS-B/preprocessed/2018/d69f1a75-9609-492f-a963-bbe633ed486d.txt
# DRIAMS-B/preprocessed/2018/b1b1bc10-566b-4c78-a9a0-0868714ff3f4.txt
# DRIAMS-B/preprocessed/2018/6ae2ffbd-333d-4760-9381-23848dc8902b.txt
# DRIAMS-B/preprocessed/2018/28a8b38a-78f4-4fdf-bfae-2692ba08c0e0.txt
# DRIAMS-B/preprocessed/2018/95781079-1107-4882-a85d-2a2baabc8d66.txt
# DRIAMS-B/preprocessed/2018/c9a39dbc-8007-41a6-8cf0-d4b3e8f7fc98.txt
# DRIAMS-B/preprocessed/2018/a5221682-6474-4b77-804b-1960763d4057.txt
# DRIAMS-B/preprocessed/2018/6dda3b8a-ae0c-4caf-89fb-4b4fe48d2863.txt
# DRIAMS-B/preprocessed/2018/1ecdc769-9e20-48b1-8429-4ad57119e2e4.txt
# DRIAMS-B/preprocessed/2018/aa417d57-d676-4338-b194-6a9e0eb0ac4d.txt
# DRIAMS-B/preprocessed/2018/b9a0757e-0915-40b5-b7e2-908173968c73.txt
# DRIAMS-B/preprocessed/2018/32a67210-5717-47d6-8966-a993eddba8f8.txt
# DRIAMS-B/preprocessed/2018/e9cbb4dd-2cdb-4c6e-98c3-76c7ddf1f529.txt
# DRIAMS-B/preprocessed/2018/c1c16914-1d50-49b7-9f1a-d5ee5ceaa670.txt
# DRIAMS-B/preprocessed/2018/9bab33ab-0f75-47f9-b25f-fe24fb868568.txt
# DRIAMS-B/preprocessed/2018/20fb2dba-600a-458c-92fc-7641b3c78ee4.txt
# DRIAMS-B/preprocessed/2018/e2f4b193-170e-4ea5-94fb-7e9b9cbf0caf.txt
# DRIAMS-B/preprocessed/2018/2583d5bf-d11e-4e75-adf7-4d6d13cdc166.txt
# DRIAMS-B/preprocessed/2018/95e3636d-f5e2-424c-ac94-e38c7cc66b22.txt
# DRIAMS-B/preprocessed/2018/856218aa-c83f-4a66-8fe3-2eaa7e961032.txt
# DRIAMS-B/preprocessed/2018/c5ecfbbe-3a62-4a41-ac64-f7c0916f8f01.txt
# DRIAMS-B/preprocessed/2018/5ffd4a35-5786-4a0c-8e6e-1748f21a03a6.txt
# DRIAMS-B/preprocessed/2018/46fb2f6a-3de2-4e31-8a62-a872bf26553c.txt
# DRIAMS-B/preprocessed/2018/9e04bb01-1c7d-4b46-a527-8b6e2b4f3346.txt
# DRIAMS-B/preprocessed/2018/b15c8a39-02bb-4df7-821c-fc6860cb2289.txt
# DRIAMS-B/preprocessed/2018/61248784-8ca0-4016-956c-bbf0fe11f56c.txt
# DRIAMS-B/preprocessed/2018/fd015231-0045-43b3-a915-eb3054f71c1f.txt
# DRIAMS-B/preprocessed/2018/f0945182-1b1d-474c-afb2-dea8a6ed48fd.txt
# DRIAMS-B/preprocessed/2018/16056e46-fb32-40df-93d7-37bde16d96c3.txt
# DRIAMS-B/preprocessed/2018/6dfe29eb-27a1-4c31-a7e2-422e194942a4.txt
# DRIAMS-B/preprocessed/2018/7ffd1e3f-3546-4f25-bd54-14a4eee0396e.txt
# DRIAMS-B/preprocessed/2018/8c4c7eea-bad6-44d5-ac95-b6d42b677103.txt
# ...
# DRIAMS-B/preprocessed/2018/cdd12cd5-f7a0-4690-a702-953f43baf58f.txt
# DRIAMS-B/preprocessed/2018/673fbd96-2421-4358-9245-fc1edbba0f20.txt
# DRIAMS-B/preprocessed/2018/00a481af-5b89-4987-8be4-041d19bee175.txt
# DRIAMS-B/preprocessed/2018/0b8e99fd-b613-4ba8-bba6-a2a99b37268f.txt
# DRIAMS-B/preprocessed/2018/d176c138-8a94-4ef9-9c3f-4ccc6e7e88b3.txt
# DRIAMS-B/preprocessed/2018/4c13dc54-0e74-486a-b190-b18a99634ab5.txt
# DRIAMS-B/preprocessed/2018/6c60b22f-f782-41ec-8bc2-e75d992e156d.txt
# DRIAMS-B/preprocessed/2018/cc1dfe71-771a-4565-9fc0-461cbd907460.txt
# DRIAMS-B/preprocessed/2018/958de8ff-5c9b-415e-802a-0d26005ba8ff.txt
# DRIAMS-B/preprocessed/2018/e01d7b95-8c07-4898-aba3-b9a5e1cf7875.txt
# DRIAMS-B/preprocessed/2018/db85ebba-769c-47fb-b076-8b4f99ad48e1.txt
# DRIAMS-B/preprocessed/2018/76385222-2715-4b2d-b79d-87bae3d8ac32.txt
# DRIAMS-B/preprocessed/2018/75130764-7593-4492-afa1-7e5f8cce73d1.txt
# DRIAMS-B/preprocessed/2018/deed36f3-7bd1-4595-b0fd-3cff5d6f669a.txt
# DRIAMS-B/preprocessed/2018/dfb84d04-21e7-4e8a-a9cc-facef2efce12.txt
# DRIAMS-B/preprocessed/2018/7bff40d2-8d61-45ac-9842-e6d59cde1232.txt
# DRIAMS-B/preprocessed/2018/cb4488ff-f5f7-418c-bd43-b29461cd8e6f.txt
# DRIAMS-B/preprocessed/2018/4c6c3d3a-46e0-441f-8ec3-4273828ad3ff.txt
# DRIAMS-B/preprocessed/2018/b022028e-8a7b-41a0-b496-fde584b70e44.txt
# DRIAMS-B/preprocessed/2018/7fd395a4-83d0-4abe-9e01-c1e98891d649.txt
# DRIAMS-B/preprocessed/2018/413feee3-c042-4796-91ee-f5486ebe6c72.txt
# DRIAMS-B/preprocessed/2018/523df9d7-3482-41bf-906c-a335ced91229.txt
# DRIAMS-B/preprocessed/2018/2e7fd2de-12db-4b63-9229-b2c6663127d8.txt
# DRIAMS-B/preprocessed/2018/c978bb1b-a1c7-45af-88e9-fee2db36f22d.txt
# DRIAMS-B/preprocessed/2018/57021680-8d71-4a9e-9646-b56784b7ac6b.txt
# DRIAMS-B/preprocessed/2018/b9c525fa-4a3e-42f7-a07d-59366dcd3d59.txt
# DRIAMS-B/preprocessed/2018/0f376b9a-f863-418c-b1c9-121d17ddb851.txt
# DRIAMS-B/preprocessed/2018/6cc58497-e98b-4409-822a-1f888194c539.txt
# DRIAMS-B/preprocessed/2018/70926e47-b946-4bb6-ba72-a2cd7cbcfd2a.txt
# DRIAMS-B/preprocessed/2018/f11a8050-ac43-4f3f-b8a4-deda45e6422e.txt
# DRIAMS-B/preprocessed/2018/6922dfcc-d458-4230-a353-aca0e24f2110.txt
# DRIAMS-B/preprocessed/2018/0f0a72ca-9d0c-46d7-9a55-12415dfe0ec3.txt
# DRIAMS-B/preprocessed/2018/f6a0a49f-0304-4cc1-a41e-1e4b2af7df2c.txt
# DRIAMS-B/preprocessed/2018/68f5c31d-1eae-4bcf-a1fc-a3dd25987117.txt
# DRIAMS-B/preprocessed/2018/f92b15a2-6855-4531-afc5-f10201bde917.txt
# DRIAMS-B/preprocessed/2018/d6b531b3-ee46-49e2-81b0-16154b453cb5.txt
# DRIAMS-B/preprocessed/2018/a2326083-6624-4e8e-a4b4-3d64c1fe34fe.txt
# DRIAMS-B/preprocessed/2018/a4b92d26-dbed-4785-bf1e-a68e6d9a8003.txt
# DRIAMS-B/preprocessed/2018/68b3a2e2-12a0-495a-aff2-bb003c4e1fba.txt
# DRIAMS-B/preprocessed/2018/a2d34906-4da8-4799-814d-40cc1ceffab1.txt
# DRIAMS-B/preprocessed/2018/077d35e2-c061-4b5a-bd19-863a71ddf816.txt
# DRIAMS-B/preprocessed/2018/7705d35e-aed0-4fbc-8077-b482f9cc2f3f.txt
# DRIAMS-B/preprocessed/2018/ed56b495-00a1-465e-99f9-b734cc885b04.txt
# DRIAMS-B/preprocessed/2018/14aefe21-b8b8-4559-b213-5881eb4917b6.txt
# DRIAMS-B/preprocessed/2018/0ed39ced-b692-4d7d-a951-c1a158180370.txt
# DRIAMS-B/preprocessed/2018/ed83e882-a2ca-492d-81ad-7daf7e1f2d16.txt
# DRIAMS-B/preprocessed/2018/2a873fee-8523-4749-b2c9-82c99b80b727.txt
# DRIAMS-B/preprocessed/2018/efd44c8c-1d51-45bd-bbb8-3e823be0403b.txt
# DRIAMS-B/preprocessed/2018/5eb5d5f4-6c1c-4402-92b9-205edebe3aab.txt
# DRIAMS-B/preprocessed/2018/3514ed33-8c81-4290-9cc8-051aafcd4b81.txt
# DRIAMS-B/preprocessed/2018/c5a5df97-780a-48a1-ae20-4fa16efe36c2.txt
# DRIAMS-B/preprocessed/2018/d78c9b70-157d-485b-a1cd-f07e6f46b50c.txt
# DRIAMS-B/preprocessed/2018/aad33e1b-e73f-46d8-a1f4-b597208b01f7.txt
# DRIAMS-B/preprocessed/2018/d9313749-0668-47fd-8a7e-a6b880463943.txt
# DRIAMS-B/preprocessed/2018/da6c0ffd-7f91-4405-a011-ce917cff7b82.txt
# DRIAMS-B/preprocessed/2018/6be6d59e-4a65-46d1-8ea5-9d5f33b04abb.txt
# DRIAMS-B/preprocessed/2018/1fd9e513-930b-4b88-95c1-5d78d60ad393.txt
# DRIAMS-B/preprocessed/2018/d1c50dda-390b-456d-b743-2f16cb75c5db.txt
# DRIAMS-B/preprocessed/2018/0cf71242-6454-4e14-b7cb-bedc6f7a485f.txt
# DRIAMS-B/preprocessed/2018/fe1080c9-276d-4117-bcfc-5511a0df38f1.txt
# DRIAMS-B/preprocessed/2018/ad959fa7-a051-49c0-8bff-f473296ab2ff.txt
# DRIAMS-B/preprocessed/2018/50558f82-1e24-49d6-837b-dcaff8c71a93.txt
# DRIAMS-B/preprocessed/2018/2c229706-8704-49f0-83c9-a2016d8bfbbd.txt
# DRIAMS-B/preprocessed/2018/b4b3bcec-fd79-47fb-81ce-ecf45fb23797.txt
# DRIAMS-B/preprocessed/2018/82c956ef-c7a7-4ad0-9160-87653923efa3.txt
# DRIAMS-B/preprocessed/2018/2ef6ed31-62ef-4119-b436-c5d596c396d0.txt
# DRIAMS-B/preprocessed/2018/1c363140-36aa-409d-b2b4-3bb9565713cc.txt
# DRIAMS-B/preprocessed/2018/0c2af903-e08e-4d5d-a805-8145a04da8a2.txt
# DRIAMS-B/preprocessed/2018/b24903ae-79fa-4c7e-908e-399c22c07070.txt
# DRIAMS-B/preprocessed/2018/238d5e94-8e1f-458a-b510-b1200638e1ba.txt
# DRIAMS-B/preprocessed/2018/20da426a-ccf7-44b8-9535-ee6d44e7da42.txt
# DRIAMS-B/preprocessed/2018/25004e98-9b66-4e7b-a562-9e09d3c7a178.txt
# DRIAMS-B/preprocessed/2018/441a9e5c-dcfb-406c-966e-95db4ee14970.txt
# DRIAMS-B/preprocessed/2018/9db18d87-758a-487c-be7d-352fa9a0b482.txt
# DRIAMS-B/preprocessed/2018/0ea575e1-a5f0-4595-9e78-c71a0248090c.txt
# DRIAMS-B/preprocessed/2018/f64649fd-a2b8-4a2b-998d-34cf8061feca.txt
# DRIAMS-B/preprocessed/2018/ffd5d5f5-8814-4f4c-9d3d-e3f79bd27406.txt
# DRIAMS-B/preprocessed/2018/ac44b25d-3386-457c-b39f-45efafd9f9e9.txt
# DRIAMS-B/preprocessed/2018/95858976-71b3-40b9-9554-65e9c70155bd.txt
# DRIAMS-B/preprocessed/2018/c8d1a133-6ae5-4254-9383-34506cbfd592.txt
# DRIAMS-B/preprocessed/2018/2453308f-7be2-48b1-b8db-8e1a7cd7c15c.txt
# DRIAMS-B/preprocessed/2018/c4e471e7-7637-406e-828f-ffa2122cefa9.txt
# DRIAMS-B/preprocessed/2018/580d630d-9ea7-4696-94b8-0ee468a24fbe.txt
# DRIAMS-B/preprocessed/2018/22ed8f83-0ee6-4e47-8f68-8a4528a4560e.txt
# DRIAMS-B/preprocessed/2018/6b4fff3e-97e5-4386-b954-b39b51f1f41d.txt
# DRIAMS-B/preprocessed/2018/f48d3203-eea1-4990-abdf-070a1e3eef27.txt
# DRIAMS-B/preprocessed/2018/8092c715-80b0-4f6b-b7df-2a335de15903.txt
# DRIAMS-B/preprocessed/2018/e3d1ee08-4e03-4359-a277-6a798b7363fe.txt
# DRIAMS-B/preprocessed/2018/e2a2e103-530d-4888-a6d8-bc1abf37ba33.txt
# DRIAMS-B/preprocessed/2018/9f98b666-c4e0-4df3-a4a0-f042a13a90a9.txt
# DRIAMS-B/preprocessed/2018/37074c22-fff1-4cf2-8d3a-99c841ffc7e9.txt
# DRIAMS-B/preprocessed/2018/df89a429-bdff-4efb-9830-2e093e4ebb80.txt
# DRIAMS-B/preprocessed/2018/cbd54a29-f47f-488f-9acd-2287b04ab61f.txt
# DRIAMS-B/preprocessed/2018/14733cf8-0cce-4a3a-beff-688155a71bab.txt
# DRIAMS-B/preprocessed/2018/2b9e4252-b042-4d51-83f8-23514169c237.txt
# DRIAMS-B/preprocessed/2018/46987e44-d7b7-4b74-94be-244409dd03a9.txt
# DRIAMS-B/preprocessed/2018/2f902a38-7dbe-4b44-b2b1-ce0050baccdb.txt
# DRIAMS-B/preprocessed/2018/e3304b04-aa0f-4947-82ab-5f0aee011c66.txt
# DRIAMS-B/preprocessed/2018/c1773cd8-c6b8-4a1d-8cb6-9f310c2230db.txt
# DRIAMS-B/preprocessed/2018/0e293194-4e84-4e97-b79a-1670616c2e49.txt
# DRIAMS-B/preprocessed/2018/4a24d2f5-ff97-4024-baab-c40eb6c94703.txt
# DRIAMS-B/preprocessed/2018/d6862438-ddd3-4c63-8f35-047cafbd0868.txt
# DRIAMS-B/preprocessed/2018/43f1ee17-4383-4c9c-8521-0b115df8081f.txt
# DRIAMS-B/preprocessed/2018/a97ad428-fd04-469c-9bb6-117f4396bd04.txt
# DRIAMS-B/preprocessed/2018/d7f39d75-7b51-44d6-bb12-609e9e954c68.txt
# DRIAMS-B/preprocessed/2018/fec55306-cb9d-4ba2-8ff8-a1480ecb4c39.txt
# DRIAMS-B/preprocessed/2018/c60d9297-caca-4572-890e-bf3ef37b6c2b.txt
# DRIAMS-B/preprocessed/2018/3441fd76-49d0-419a-8f0e-03b6a97d3589.txt
# DRIAMS-B/preprocessed/2018/2dffae12-048f-47a2-a9ae-edeef82fcb26.txt
# DRIAMS-B/preprocessed/2018/a291fe83-06cb-45f9-b459-22cee2cfc95a.txt
# DRIAMS-B/preprocessed/2018/5abd8673-4790-4da3-8a25-76141f324b97.txt
# DRIAMS-B/preprocessed/2018/1c26c379-e096-4c7e-b901-5a1720afd96e.txt
# DRIAMS-B/preprocessed/2018/035e7271-3c55-488e-abcb-796c4930a539.txt
# DRIAMS-B/preprocessed/2018/d2d07814-3111-4dd2-aed6-f4582c7e1f3d.txt
# DRIAMS-B/preprocessed/2018/024c7739-c283-4778-93ec-517c77153d0f.txt
# DRIAMS-B/preprocessed/2018/d6401856-7466-40eb-b620-e02c9ce3ec79.txt
# DRIAMS-B/preprocessed/2018/c79387c9-36cf-435f-8b31-d642695fd65b.txt
# DRIAMS-B/preprocessed/2018/2489c9d3-941b-4a19-b90d-7b4e903e46bb.txt
# DRIAMS-B/preprocessed/2018/a4a4b5d3-01a1-4b47-a56e-f838da56880f.txt
# DRIAMS-B/preprocessed/2018/9de3eee1-e6fc-4c26-9cbf-8a75f3f9f22f.txt
# DRIAMS-B/preprocessed/2018/9e5dba83-7e58-4b24-b3ad-02e555b1c990.txt
# DRIAMS-B/preprocessed/2018/26f68e2b-af39-45d8-9ed6-87ad89316a85.txt
# DRIAMS-B/preprocessed/2018/e6da887e-b729-410a-b539-038c9c405d56.txt
# DRIAMS-B/preprocessed/2018/bd9c0662-6133-4890-b9a3-dc95acbd18f3.txt
# DRIAMS-B/preprocessed/2018/0c832adc-7cf9-461e-9a31-0e61f0c0f0fc.txt
# DRIAMS-B/preprocessed/2018/73f0efd5-c171-4cf1-9e9c-165b4bd0e85a.txt
# DRIAMS-B/preprocessed/2018/31277b2d-bddd-4c5a-8cf4-d98255a7fd69.txt
# DRIAMS-B/preprocessed/2018/ee11e794-e290-4997-93cf-bf62c592e637.txt
# DRIAMS-B/preprocessed/2018/3e379d9d-8020-4f01-b70c-7a0a9995f752.txt
# DRIAMS-B/preprocessed/2018/9735a07c-3371-4e60-b701-fff6278be6e1.txt
# DRIAMS-B/preprocessed/2018/af15fc74-22ed-4cc8-b47e-df52e9c9cc27.txt
# DRIAMS-B/preprocessed/2018/d535b722-797c-4779-981a-ba3d7ca3b5b5.txt
# DRIAMS-B/preprocessed/2018/122a4e8f-7741-478d-843c-cb897e8f0b9e.txt
# DRIAMS-B/preprocessed/2018/d9251f3f-3a5c-4278-9c33-b2f19b104b0e.txt
# DRIAMS-B/preprocessed/2018/d427d4b4-0bdf-4415-bd05-d4eee48dbcc1.txt
# DRIAMS-B/preprocessed/2018/0bd29362-679e-4d1e-ad6e-692710b2dfb8.txt
# DRIAMS-B/preprocessed/2018/3dc19841-33b2-4fe3-ba98-bba28ec3f6e2.txt
# DRIAMS-B/preprocessed/2018/28a5cab8-8807-4d89-9cd9-c4dcfe775f26.txt
# DRIAMS-B/preprocessed/2018/9a79b182-2af2-4498-8c40-b29217abe4ad.txt
# DRIAMS-B/preprocessed/2018/60d3109b-d3d1-4267-9f0f-922120f0f454.txt
# DRIAMS-B/preprocessed/2018/a4fd46c8-819b-4fd9-8ec6-3be9716832b8.txt
# DRIAMS-B/preprocessed/2018/e3c3097f-3148-4b9f-9a63-8f10759a6a34.txt
# DRIAMS-B/preprocessed/2018/8762c1f3-25da-4818-954f-9b22741ca32f.txt
# DRIAMS-B/preprocessed/2018/394361bc-dd1a-4ef5-954f-1e8520237911.txt
# DRIAMS-B/preprocessed/2018/fea75e50-2732-46a1-8104-d7cf23c034c3.txt
# DRIAMS-B/preprocessed/2018/a4652fa9-f38f-467a-9c7b-b317694509e1.txt
# DRIAMS-B/preprocessed/2018/ae8e5d0c-2837-4102-94d2-63b0c9d4e794.txt
# DRIAMS-B/preprocessed/2018/76454a49-9e47-4558-a3da-a89a25c076cd.txt
# DRIAMS-B/preprocessed/2018/98b5c94a-b4b5-4fcc-8734-1c9eb0c1b21f.txt
# DRIAMS-B/preprocessed/2018/79b06741-1398-40a3-96e8-d13bd6b38a7f.txt
# DRIAMS-B/preprocessed/2018/a41b996b-ffb5-4e2a-8310-41de2aa321de.txt
# DRIAMS-B/preprocessed/2018/dfe53fcd-6125-4fd4-8152-8c8e9c198f41.txt
# DRIAMS-B/preprocessed/2018/2550b644-31f4-42d5-a948-a4e4c7ca7faa.txt
# DRIAMS-B/preprocessed/2018/30f50dbf-dd4d-4c5a-8bc6-4e016fbaf710.txt
# DRIAMS-B/preprocessed/2018/09f44b18-76d8-49e5-b881-5b50b2d77e3d.txt
# DRIAMS-B/preprocessed/2018/cd858920-8a16-4eee-bda1-9a904b87d809.txt
# DRIAMS-B/preprocessed/2018/441e2988-95cb-4dfc-a3b2-c405c31e7958.txt
# DRIAMS-B/preprocessed/2018/f7b3e2b7-7511-4fb3-b2ff-739ca19fb467.txt
# DRIAMS-B/preprocessed/2018/60d6ba37-22f7-4d72-b613-426030f44790.txt
# DRIAMS-B/preprocessed/2018/700d8b8e-07e3-448f-9b33-a024aa6aa84b.txt
# DRIAMS-B/preprocessed/2018/7333f313-fc4e-489b-a40a-ddd99878fa22.txt
# DRIAMS-B/preprocessed/2018/f82c0959-221b-4bba-9dc5-9f61e521037e.txt
# DRIAMS-B/preprocessed/2018/0661f3a4-b6ec-49b0-a2ee-0a9bf72c7ae0.txt
# DRIAMS-B/preprocessed/2018/3a39ff80-2b77-4276-af09-dc42212246f2.txt
# DRIAMS-B/preprocessed/2018/c480f828-ce32-4c80-a075-859af5b96ac3.txt
# DRIAMS-B/preprocessed/2018/70d7450e-3a46-4b1e-8d1f-5af10e9fa48e.txt
# DRIAMS-B/preprocessed/2018/eebfd6df-7919-4e4a-a077-8678bc752caa.txt
# DRIAMS-B/preprocessed/2018/98bf1891-3735-46e1-80d4-418f14f2e93f.txt
# DRIAMS-B/preprocessed/2018/66f98fed-9953-4688-962b-3b6047b27db9.txt
# DRIAMS-B/preprocessed/2018/f6603211-fbd8-40b1-b71d-1cac18d532f1.txt
# DRIAMS-B/preprocessed/2018/e78a1cbc-a2be-4d5d-9f0a-3338822ce24d.txt
# DRIAMS-B/preprocessed/2018/668f1057-9382-4ea4-bfaa-b211d465470b.txt
# DRIAMS-B/preprocessed/2018/a8d02bfd-3f61-4442-821a-ba81e9e39a65.txt
# DRIAMS-B/preprocessed/2018/67243389-cd2e-4fff-a528-b5e655c8b14b.txt
# DRIAMS-B/preprocessed/2018/b3ecb09e-0f90-4e89-923d-d07951fe98a7.txt
# DRIAMS-B/preprocessed/2018/d29ef254-85c4-45e2-b915-9f3eb4afddf7.txt
# DRIAMS-B/preprocessed/2018/4cdecf0e-075c-4956-a754-ba6a5d6b52cf.txt
# DRIAMS-B/preprocessed/2018/b067bb5c-ec50-4fd9-ae6a-9cb7c8099895.txt
# DRIAMS-B/preprocessed/2018/d7371662-d442-44fa-bdc1-875e1aa6c294.txt
# DRIAMS-B/preprocessed/2018/44a99ab3-f074-4172-8c2d-cc84cac5c8bc.txt
# DRIAMS-B/preprocessed/2018/cd042740-e173-40c5-9995-06977921c857.txt
# DRIAMS-B/preprocessed/2018/da743071-015d-479e-b138-2eaa4006171f.txt
# DRIAMS-B/preprocessed/2018/32078509-0661-4dc3-8310-f43798942b13.txt
# DRIAMS-B/preprocessed/2018/07edaf8d-7ada-4289-8cfb-bdd91bcfc87e.txt
# DRIAMS-B/preprocessed/2018/3021c602-c7b0-41d1-a06e-5d7dc4721733.txt
# DRIAMS-B/preprocessed/2018/878a93b4-dfb2-40d4-9582-0855ce262fbe.txt
# DRIAMS-B/preprocessed/2018/c85f81a8-28f8-49d4-9812-6bdca83a6b83.txt
# DRIAMS-B/preprocessed/2018/2183f165-74d8-442f-bfbd-0768a73a051d.txt
# DRIAMS-B/preprocessed/2018/1ddbcb12-da1d-4506-8228-09e0d1643c46.txt
# DRIAMS-B/preprocessed/2018/1cd1e4a6-7d43-4ad6-aa0d-c0bbf610c5d7.txt
# DRIAMS-B/preprocessed/2018/5e6cd6db-4f9b-4e92-a5b4-ff1706d1a658.txt
# DRIAMS-B/preprocessed/2018/4e5cc86a-1628-4e14-ae22-a8b2f055adab.txt
# DRIAMS-B/preprocessed/2018/e8d92dea-7fdf-497b-a336-1498e61756a8.txt
# DRIAMS-B/preprocessed/2018/007e7785-8721-4806-9cd6-e875b585bbc0.txt
# DRIAMS-B/preprocessed/2018/fec25792-864c-4ea1-9aac-4474e19cf228.txt
# DRIAMS-B/preprocessed/2018/e2df57b3-a829-4a8c-8b50-19e6b6876b5e.txt
# DRIAMS-B/preprocessed/2018/117c7d59-2bf0-4351-9b2d-5532e543dce0.txt
# DRIAMS-B/preprocessed/2018/79374135-2aef-4538-8c9f-3ba053e82a29.txt
# DRIAMS-B/preprocessed/2018/0863fde1-8e48-4ab3-9ef9-538dd0952bc3.txt
# DRIAMS-B/preprocessed/2018/2154d822-6166-458f-be1f-3d7e59665e23.txt
# DRIAMS-B/preprocessed/2018/86dd32fc-6526-4898-bca9-50ecf4c9689d.txt
# DRIAMS-B/preprocessed/2018/dc8f8e75-1457-4a70-b6e4-e6f4803cbd91.txt
# DRIAMS-B/preprocessed/2018/454d9875-9d39-4a2c-9cdb-86ba764ab2d3.txt
# DRIAMS-B/preprocessed/2018/cec91562-4f4f-4558-a04e-632e464c789e.txt
# DRIAMS-B/preprocessed/2018/a4df29d0-c43c-4e64-a057-2efb223516fd.txt
# DRIAMS-B/preprocessed/2018/79202e9b-9a5d-48d5-ab45-01f77451b63b.txt
# DRIAMS-B/preprocessed/2018/530a3111-32f9-4a46-994f-1309918817c1.txt
# DRIAMS-B/preprocessed/2018/42b3339b-d6b7-4d78-ae79-2c5eddd72df0.txt
# DRIAMS-B/preprocessed/2018/5757c70d-b92c-4e0c-8e55-0819334192e9.txt
# DRIAMS-B/preprocessed/2018/c692afc7-f6d8-4ded-b1df-ba4643b80c7b.txt
# DRIAMS-B/preprocessed/2018/fbdae45e-2e98-4225-a892-7f170f277628.txt
# DRIAMS-B/preprocessed/2018/b7827c22-e568-4b9f-a283-1b31fa9decf8.txt
# DRIAMS-B/preprocessed/2018/836be193-01ca-4fb5-8847-d4eb42525115.txt
# DRIAMS-B/preprocessed/2018/941b8ef9-40b9-459c-9b3c-9425806baf20.txt
# DRIAMS-B/preprocessed/2018/f5e2573a-929d-40ad-acbe-23eb01409941.txt
# DRIAMS-B/preprocessed/2018/1bf9947f-9163-4efb-98f3-b37aaf94a3d3.txt
# DRIAMS-B/preprocessed/2018/0c3d8336-4e3b-4911-8222-e0cdc2c62d51.txt
# DRIAMS-B/preprocessed/2018/8295460d-a8fe-4e3f-bb4a-d518ba1c76aa.txt
# DRIAMS-B/preprocessed/2018/84311f89-9d4a-4483-8796-e03b6164a734.txt
# DRIAMS-B/preprocessed/2018/7a4d214d-cdbd-4c68-a604-0bf4f2e7ecc5.txt
# DRIAMS-B/preprocessed/2018/8b8e7f22-bef2-4511-b368-0abdb072b8b9.txt
# DRIAMS-B/preprocessed/2018/f961ebc3-508a-4351-a2ec-a88698bd8f61.txt
# DRIAMS-B/preprocessed/2018/5bf16194-1ae9-4bc9-835a-bcf7f4f107be.txt
# DRIAMS-B/preprocessed/2018/e07215a7-e5ca-4615-8c68-bc7eed25c672.txt
# DRIAMS-B/preprocessed/2018/393f0b0f-27c7-4374-90f3-e337b022b5fb.txt
# DRIAMS-B/preprocessed/2018/d637c522-84bf-4b12-8c55-edf0585285c3.txt
# DRIAMS-B/preprocessed/2018/c319261f-db34-42aa-b984-a342b1a412ef.txt
# DRIAMS-B/preprocessed/2018/79084973-e590-44f7-8486-0ad94ba14f9f.txt
# DRIAMS-B/preprocessed/2018/cc9f02be-7e78-45c3-be06-1b7ff763a3f6.txt
# DRIAMS-B/preprocessed/2018/04d661ab-3aac-4aee-82d9-325b84189ec4.txt
# DRIAMS-B/preprocessed/2018/f1c0863c-8d12-4304-8773-cff345e55d87.txt
# DRIAMS-B/preprocessed/2018/cef6a4ae-7f09-4ac8-92e8-779d79df4df1.txt
# DRIAMS-B/preprocessed/2018/84cda926-d4d8-41a0-bab3-b47b3842ef9e.txt
# DRIAMS-B/preprocessed/2018/e21f8589-0c14-4fc9-85ac-d4878c2da551.txt
# DRIAMS-B/id/2018/2018_clean.csv

# %%
import maldi_nn.utils.data
import pandas as pd
import os
import numpy as np
from importlib.resources import files
import maldi_nn.spectrum  as maldi_spectrum

# %%
#DRIAMS_B_ROOT = '/content/drive/MyDrive/ESCMID-AI-Data-Advances-Techniques/DRIAMS/DRIAMS-B/'
DRIAMS_B_ROOT = '/content/drive/MyDrive/DRIAMS/DRIAMS-B/DRIAMS-B/'

# %% [markdown]
# ---

# %% [markdown]
# ## Loading MALDI-TOF Spectra
#
# For this session, we will use a well-established, community-validated codebase adapted from the popular **maldi-nn** GitHub repository, which is widely used in MALDI-TOF data analysis.
#
# If you are not a data scientist, don’t worry about the implementation details — the important part is to understand that this code **reads and processes MALDI-TOF spectra** from the DRIAMS B dataset in a format that we can use for machine learning.
#
# We will focus on using the processed data for downstream analysis, so you can safely treat this step as a “black box” that prepares the data for us.

# %%
# @title
import os
import pandas as pd
import numpy as np
from maldi_nn.spectrum import SpectrumObject

def load_spectra_with_species(DRIAMS_ROOT, spectra_type="raw"):
    """
    Loads all spectrum .txt files and pairs them with species info,
    filtering to only include specific microorganisms (genus + species).

    Args:
        DRIAMS_ROOT (str): Path to the root directory of the DRIAMS dataset.

    Returns:
        - spectra_list: list of SpectrumObject (with .species and .code attributes)
        - df: DataFrame with columns ['species', 'code']
    """

    # List of allowed species (genus + species), exact match required
    allowed_species = {
        "Escherichia coli",
        "Staphylococcus aureus",
        "Staphylococcus epidermidis",
        "Enterococcus faecalis",
        "Pseudomonas aeruginosa",
        "Klebsiella pneumoniae",
        "Streptococcus agalactiae",
        "Candida albicans",
        "Candida glabrata",
        "Staphylococcus haemolyticus",
        "Staphylococcus hominis",
        "Streptococcus pyogenes",
        "Citrobacter koseri",
        "Staphylococcus lugdunensis",
        "Streptococcus anginosus",
        "Enterobacter cloacae"
    }

    print("Step 1: Collecting all .txt spectrum file paths...")
    spectrum_paths = []

    # Walk through all directories under the root to find spectrum .txt files
    for root, dirs, files in os.walk(DRIAMS_ROOT):
        if spectra_type in root:
            for f in files:
                if f.endswith(".txt"):
                    full_path = os.path.join(root, f)
                    rel_path = "/".join(full_path.split("/")[-4:])
                    spectrum_paths.append((rel_path, full_path))

    print("Step 2: Parsing species data from _clean.csv files...")
    species_lookup = {}

    for root, dirs, files in os.walk(DRIAMS_ROOT):
        if "id" in root:
            for f in files:
                if f.endswith("_clean.csv"):
                    path = os.path.join(root, f)
                    try:
                        df = pd.read_csv(path)
                        dataset = root.split("/")[-3]
                        year = root.split("/")[-1]
                        df["code"] = f"{dataset}/{spectra_type}/{year}/" + df["code"] + ".txt"
                        for _, row in df.iterrows():
                            code = row["code"]
                            species = row["species"]
                            species_lookup[code] = species
                    except Exception as e:
                        print(f"Error reading {path}: {e}")

    print("Step 3: Loading spectra and attaching metadata with filtering...")
    spectra_list = []
    records = []

    for rel_path, full_path in spectrum_paths:
        try:
            species = species_lookup.get(rel_path, None)
            # Filter: skip if species not in allowed_species or None
            if species is None or species not in allowed_species:
                continue

            spec_obj = SpectrumObject.from_tsv(full_path)
            spec_obj.intensity = np.array(spec_obj.intensity[1:], dtype=float)
            spec_obj.mz = np.array(spec_obj.mz[1:], dtype=float)

            code = os.path.splitext(os.path.basename(rel_path))[0]

            spectra_list.append(spec_obj)
            records.append({
                "species": species,
                "code": code
            })
        except Exception as e:
            print(f"Error loading spectrum {rel_path}: {e}")

    df = pd.DataFrame(records)

    print(f"Loaded {len(spectra_list)} spectra filtered by selected species.")
    return spectra_list, df

# %%
spectra, metadata = load_spectra_with_species(DRIAMS_B_ROOT)
# Out:
# Step 1: Collecting all .txt spectrum file paths...
# Step 2: Parsing species data from _clean.csv files...
# Step 3: Loading spectra and attaching metadata with filtering...
# Loaded 3456 spectra filtered by selected species.

# %% [markdown]
# ## Preprocessing Steps Explained
#
# Before we can train any machine learning model on MALDI-TOF spectra, it is essential to preprocess the raw data to reduce noise, correct artifacts, and standardize the measurements. The preprocessing steps we use are **well-established in the MALDI-TOF literature** and help improve model performance and reliability.
#
# Here are the steps we apply sequentially using the `maldi_spectrum.SequentialPreprocessor`:
#
# 1. **Variance Stabilization (`VarStabilizer` with method="sqrt")**
#    - Applies a square root transformation to stabilize the variance across intensity values, reducing heteroscedasticity common in spectral data.
#
# 2. **Smoothing (`Smoother` with halfwindow=10)**
#    - Applies a smoothing filter to reduce random noise while preserving peak shapes, improving signal clarity.
#
# 3. **Baseline Correction (`BaselineCorrecter` with method="SNIP", iterations=20)**
#    - Removes the slowly varying background signal (baseline) from spectra, which can obscure true peaks.
#
# 4. **Normalization (`Normalizer` with sum=1)**
#    - Scales the spectra so that the total intensity sums to one, making spectra comparable across samples.
#
# 5. **Binning (`Binner` with step=3)**
#    - Aggregates adjacent m/z values into bins, reducing dimensionality and compensating for small shifts in peak positions.
#
# Together, these steps produce clean, comparable spectral data ready for downstream machine learning analysis.

# %%
# Define preprocessor and its steps
preprocessor = maldi_spectrum.SequentialPreprocessor(
    maldi_spectrum.VarStabilizer(method="sqrt"),
    maldi_spectrum.Smoother(halfwindow=10),
    maldi_spectrum.BaselineCorrecter(method="SNIP", snip_n_iter=20),
    maldi_spectrum.Normalizer(sum=1),
    maldi_spectrum.Binner(step=3)
)

#Apply preprocessing steps
spectra_preprocessed = [preprocessor(spectrum) for spectrum in spectra]

# %%
spectra_preprocessed
# Out:
# [SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.78617e-04 6.33772e-04 ... 1.57768e-05 9.42160e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.96074e-04 7.07358e-05 ... 1.12038e-05 8.06093e-08]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.03730e-04 2.95891e-04 ... 3.13571e-05 2.85237e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.16686e-04 5.94465e-04 ... 6.27255e-05 5.24163e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [6.18736e-04 8.05238e-04 ... 4.35234e-05 4.45109e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.48603e-04 6.54591e-04 ... 3.70184e-05 4.07421e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.63125e-04 4.40843e-04 ... 6.63315e-05 4.44040e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.28606e-04 7.39428e-04 ... 8.00849e-05 1.34801e-04]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.33400e-04 1.43994e-04 ... 1.43882e-05 2.13037e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.22574e-05 4.74099e-05 ... 3.77895e-05 2.65951e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [9.45315e-04 8.27570e-05 ... 2.83988e-05 3.68364e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.04115e-05 1.42136e-04 ... 0.00000e+00 1.03572e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.13976e-04 2.37358e-04 ... 4.99421e-05 5.24921e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.70322e-06 5.79411e-05 ... 2.88244e-06 1.24970e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.47239e-04 6.62815e-04 ... 5.67934e-05 5.40519e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.79147e-04 2.02653e-04 ... 2.94636e-05 3.31693e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.83196e-04 1.33662e-04 ... 1.39292e-05 2.36387e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.16234e-04 5.96911e-04 ... 2.90739e-05 2.88859e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.89897e-04 6.97299e-04 ... 1.40957e-06 1.56057e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.50306e-04 4.82639e-04 ... 1.22529e-05 4.47722e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.44624e-04 1.27941e-03 ... 1.30528e-05 9.72342e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.89555e-05 3.11031e-04 ... 7.47707e-06 1.54629e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.44298e-04 5.92184e-04 ... 5.91684e-06 1.38292e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.69094e-04 6.50475e-04 ... 4.53137e-05 5.82121e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.24084e-04 1.01991e-04 ... 1.82273e-05 2.39794e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.30411e-04 2.00563e-04 ... 4.54629e-06 8.11493e-08]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.91710e-04 5.73246e-05 ... 2.32222e-05 1.47182e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [9.99111e-06 3.57734e-04 ... 2.81273e-05 2.72014e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.10090e-04 2.96509e-04 ... 2.76755e-05 5.85263e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.57538e-04 2.10787e-04 ... 5.30380e-05 2.10393e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.66760e-04 5.46665e-04 ... 4.29043e-05 3.60954e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.04928e-04 3.89874e-04 ... 2.83623e-06 8.79459e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.19332e-04 3.91066e-04 ... 3.45059e-05 3.63808e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.04288e-03 4.81298e-04 ... 4.99987e-05 7.38314e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.31021e-04 2.57244e-04 ... 5.34224e-05 3.38640e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.40851e-04 2.02093e-04 ... 2.58990e-05 3.59136e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.07232e-04 6.99309e-04 ... 2.07763e-05 2.02126e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.00349e-04 6.75173e-04 ... 1.48835e-05 9.80955e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.62211e-05 3.30475e-04 ... 1.18294e-05 1.33541e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.19212e-05 3.79398e-04 ... 3.53017e-05 2.01627e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.44939e-04 9.94194e-04 ... 2.04855e-05 2.03369e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.04070e-03 1.21894e-03 ... 1.06121e-04 8.27890e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.63213e-04 1.06217e-04 ... 1.06539e-05 2.71680e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.27833e-05 6.14278e-04 ... 1.25135e-05 2.05617e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.59952e-05 1.06514e-04 ... 2.88717e-05 2.17546e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [6.58731e-04 4.45011e-04 ... 1.40766e-04 1.22019e-04]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.65581e-04 1.00394e-04 ... 8.15336e-05 4.68468e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.92764e-04 2.94781e-04 ... 2.08590e-05 8.02768e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.89709e-04 3.94505e-04 ... 7.50462e-05 2.48762e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.35383e-04 5.54654e-04 ... 1.67665e-06 4.95474e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.49337e-03 2.78940e-04 ... 4.83327e-07 1.88715e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.48467e-04 3.64868e-05 ... 2.13967e-05 2.68458e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [6.13420e-04 6.38634e-04 ... 4.87176e-05 5.69533e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.75887e-04 1.39975e-04 ... 8.18414e-06 1.52376e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.35744e-04 4.03142e-04 ... 3.03278e-05 3.90204e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.90503e-04 5.80094e-04 ... 2.97058e-05 3.07682e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.55438e-04 3.60002e-04 ... 3.90368e-05 4.74482e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.54386e-04 3.47353e-05 ... 3.92503e-05 3.21052e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.13656e-04 2.47702e-04 ... 1.58832e-05 1.03414e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.49181e-04 7.65979e-04 ... 2.57367e-05 2.98361e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.46694e-04 1.07358e-03 ... 5.64234e-05 5.17888e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.88781e-04 3.50530e-04 ... 5.52108e-05 2.96371e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.23829e-04 5.07966e-04 ... 5.85486e-05 3.69500e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.03698e-04 1.23135e-04 ... 1.54260e-05 1.61904e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.27987e-05 2.15960e-04 ... 1.12106e-05 2.02055e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.27729e-04 4.95317e-04 ... 2.85752e-05 4.73774e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.69302e-05 1.69665e-04 ... 6.20541e-05 3.73033e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.72759e-05 6.17764e-04 ... 2.81883e-05 3.45700e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.12585e-04 3.96607e-04 ... 4.88305e-05 3.89566e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.91908e-04 9.86937e-04 ... 1.23203e-05 9.72379e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.21750e-04 8.92132e-04 ... 5.26174e-05 5.62280e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.25903e-04 2.52875e-04 ... 2.13129e-05 1.18172e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.81282e-04 8.22225e-05 ... 1.84375e-05 1.21764e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.35110e-04 1.81553e-04 ... 3.08969e-05 1.20007e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.27402e-04 9.55979e-04 ... 1.54641e-05 1.97554e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [6.87817e-04 6.21762e-04 ... 3.25905e-05 4.59630e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.86468e-04 1.29591e-03 ... 1.46327e-05 4.51263e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.55371e-04 7.04104e-04 ... 6.99970e-05 3.96719e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.53007e-04 1.96186e-04 ... 3.48824e-05 4.43850e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.71895e-04 1.72688e-04 ... 5.46960e-06 9.36811e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.24039e-04 3.39087e-04 ... 1.21626e-05 2.25437e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.02940e-04 1.43868e-04 ... 1.71801e-05 2.93418e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.13172e-04 3.81473e-04 ... 5.68818e-05 2.57660e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.29406e-04 6.83935e-04 ... 1.51193e-05 1.35526e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.06339e-04 5.22476e-04 ... 1.12403e-05 1.22428e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [9.11075e-04 1.61346e-04 ... 4.15305e-05 3.53229e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.39976e-04 4.16636e-04 ... 1.74330e-05 1.59253e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.88970e-04 1.50549e-04 ... 1.34308e-05 1.06234e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.72149e-04 6.23960e-04 ... 2.52785e-05 1.49267e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [6.41208e-04 3.40843e-04 ... 4.91761e-05 3.13617e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.17485e-05 7.10875e-04 ... 2.42575e-05 1.97442e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.47442e-04 2.15968e-04 ... 1.44687e-05 1.00643e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.33033e-04 3.59961e-04 ... 0.00000e+00 0.00000e+00]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.89503e-03 1.15297e-03 ... 4.65882e-05 4.19416e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.09163e-04 8.16946e-04 ... 5.39221e-05 3.86555e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.53944e-04 1.15607e-03 ... 3.58671e-05 4.05082e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.74814e-05 5.09092e-04 ... 7.21367e-05 6.74427e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.06152e-07 3.72933e-04 ... 2.02884e-05 3.31929e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [6.33543e-04 3.49165e-04 ... 3.52517e-05 6.08745e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.33711e-03 6.42574e-04 ... 2.53724e-05 1.36225e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.75714e-04 6.72953e-04 ... 4.63805e-05 5.80752e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.18033e-05 2.43702e-05 ... 4.26650e-05 5.63914e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.31445e-04 5.78523e-04 ... 7.51221e-05 6.55744e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.04047e-04 1.01989e-04 ... 4.44200e-05 4.56423e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [9.26299e-05 6.33012e-04 ... 2.10458e-05 3.20593e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.29955e-04 6.52781e-04 ... 8.61128e-06 1.70540e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.88959e-04 2.95958e-04 ... 4.99126e-05 6.39716e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.12248e-04 5.37355e-04 ... 8.65933e-05 1.43113e-04]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.92014e-04 1.27618e-04 ... 3.38756e-05 2.85407e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.43741e-04 2.88080e-04 ... 1.72367e-05 1.15729e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.68920e-04 4.08755e-05 ... 2.21664e-05 1.77994e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [6.40276e-04 2.11607e-04 ... 2.38213e-05 4.64408e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.19468e-04 1.25619e-04 ... 3.85339e-05 4.38244e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.60976e-04 2.18668e-04 ... 3.76885e-05 2.98965e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.06436e-04 5.85867e-04 ... 9.81285e-06 1.12627e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.76486e-04 1.62835e-03 ... 1.97063e-05 1.83007e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.20710e-04 3.16577e-04 ... 5.00655e-05 8.86844e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.76522e-04 6.55872e-05 ... 3.81308e-05 4.72681e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.04990e-04 1.02511e-04 ... 7.37798e-06 1.55340e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.48240e-04 8.85319e-04 ... 3.68713e-05 3.79156e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.35265e-04 2.70009e-04 ... 4.22798e-05 3.94781e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.80057e-04 7.49490e-05 ... 3.92443e-05 4.85330e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.99750e-04 2.47070e-03 ... 5.52824e-05 6.69503e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.54909e-04 3.02436e-04 ... 2.32936e-05 1.58214e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.03600e-03 7.71039e-04 ... 8.48088e-05 5.43137e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.01314e-04 9.89644e-05 ... 2.20419e-05 1.98491e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.65259e-04 8.08605e-04 ... 2.90396e-05 1.39523e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.04750e-04 3.10122e-05 ... 1.53721e-05 5.21758e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.08697e-04 2.80175e-04 ... 2.98582e-05 3.75984e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.81818e-04 6.74687e-04 ... 4.53334e-05 5.84566e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.53759e-05 1.01303e-05 ... 2.34214e-06 0.00000e+00]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.57716e-04 3.39562e-04 ... 2.80512e-05 2.67567e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.21050e-04 3.11704e-04 ... 1.90840e-05 4.21719e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.52473e-04 1.84966e-04 ... 2.96451e-05 6.96600e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.20909e-05 6.91014e-05 ... 6.90372e-06 3.26558e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.86063e-04 5.15465e-04 ... 8.76592e-05 1.13603e-04]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.28067e-04 3.64843e-04 ... 5.84562e-05 7.13257e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.32473e-03 9.71264e-04 ... 2.77692e-05 2.60716e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.91837e-05 2.48321e-05 ... 8.41627e-07 9.03196e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.44709e-04 9.68229e-04 ... 2.81132e-05 2.41292e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.97069e-04 6.26758e-04 ... 3.32709e-05 2.72976e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.56376e-04 5.48415e-04 ... 3.39490e-05 4.45151e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.39606e-05 8.78875e-04 ... 6.25508e-05 7.23500e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.23186e-04 4.98784e-04 ... 2.59780e-05 2.18535e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.13961e-04 6.66207e-04 ... 4.93948e-06 0.00000e+00]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.92958e-04 7.36387e-04 ... 8.13902e-05 4.88379e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.64712e-04 1.68018e-04 ... 2.09621e-05 1.77107e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.99506e-04 7.36881e-04 ... 3.44216e-05 2.03086e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.22761e-04 5.13856e-05 ... 4.18109e-05 7.25043e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.56172e-04 5.63302e-04 ... 2.54392e-05 4.31953e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.71165e-04 1.13584e-04 ... 3.06083e-05 5.98925e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.47651e-04 1.88288e-04 ... 1.98959e-05 1.00057e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.19184e-04 1.74402e-04 ... 5.16036e-05 7.35416e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.27998e-03 1.37687e-03 ... 4.79603e-05 5.79788e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.50711e-04 8.91608e-05 ... 2.08589e-05 2.96040e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.75251e-04 1.26316e-03 ... 2.69350e-05 2.05020e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.31381e-04 6.37684e-04 ... 4.28015e-05 3.82682e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.48716e-04 3.19787e-04 ... 6.14226e-05 5.56238e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.57851e-04 1.85146e-04 ... 4.69407e-05 2.21189e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.18909e-04 5.49864e-04 ... 2.48256e-07 1.29743e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.00725e-03 1.04370e-03 ... 4.68990e-05 7.63398e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.21422e-05 5.59315e-04 ... 3.29925e-05 4.43472e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.29137e-05 2.22352e-04 ... 8.97962e-06 8.18923e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.41054e-04 3.26918e-05 ... 2.99720e-05 5.79736e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.06960e-04 2.81021e-04 ... 5.09019e-05 2.64352e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.10165e-04 9.83508e-05 ... 5.23176e-06 5.55869e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.39844e-05 1.97420e-04 ... 3.85434e-05 3.55018e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.65724e-06 2.97839e-04 ... 8.28302e-06 1.11584e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.09546e-05 1.69709e-04 ... 0.00000e+00 8.52860e-07]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.75284e-04 4.70748e-04 ... 4.36184e-05 6.41149e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.04564e-04 1.13509e-04 ... 2.24793e-05 1.88573e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.65174e-04 8.69335e-04 ... 2.78114e-05 1.71578e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.14405e-04 2.73333e-04 ... 3.77356e-05 4.97374e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.51198e-05 5.94154e-05 ... 6.19249e-06 5.30797e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.87745e-04 5.85316e-04 ... 5.62135e-05 4.80728e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.45214e-03 2.09373e-04 ... 3.29663e-05 3.78081e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.48029e-05 3.91348e-04 ... 1.36102e-05 4.01419e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.89084e-05 1.45967e-04 ... 3.21115e-05 3.48900e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.47532e-04 2.41728e-04 ... 5.43169e-05 5.80842e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.37444e-04 8.68685e-05 ... 2.46715e-05 3.08148e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.98302e-05 3.74038e-05 ... 7.59876e-05 3.29468e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.11946e-04 4.62688e-04 ... 1.77775e-06 5.68608e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.20032e-03 5.99533e-04 ... 3.58893e-06 2.23387e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.03444e-04 5.82359e-04 ... 5.91601e-05 7.02219e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.08206e-04 1.44710e-03 ... 1.34253e-05 1.27938e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.02381e-05 2.23518e-04 ... 5.62572e-07 3.83193e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.91987e-04 1.97337e-04 ... 2.88743e-05 2.48278e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.18771e-04 2.56686e-04 ... 7.34463e-05 4.84484e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.35868e-04 9.25396e-04 ... 3.60773e-06 7.02818e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.35663e-04 4.84479e-04 ... 3.54339e-05 8.10952e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.66819e-04 6.35545e-04 ... 8.84815e-07 2.79151e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.47217e-04 5.76156e-04 ... 3.67749e-05 3.86540e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.00136e-05 1.68756e-05 ... 3.37600e-05 6.64039e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.12146e-04 2.23035e-04 ... 3.67074e-05 4.23822e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.28670e-04 4.51354e-04 ... 3.20241e-05 3.10256e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [6.14675e-04 5.66427e-04 ... 6.89359e-07 5.81363e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.88999e-04 4.89187e-04 ... 5.43306e-05 4.59689e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.48087e-04 6.60299e-04 ... 5.41272e-05 9.99755e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.99223e-04 4.01291e-05 ... 3.97622e-05 3.69724e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.05750e-04 2.17793e-04 ... 3.89521e-05 3.53713e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [9.68779e-04 5.92547e-04 ... 5.23925e-05 4.76149e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.78344e-04 7.99843e-04 ... 4.74757e-05 3.38372e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.66881e-04 4.13829e-04 ... 1.91597e-05 1.77298e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.97421e-05 4.32314e-04 ... 3.68821e-05 6.30504e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.17950e-04 6.56099e-04 ... 2.81433e-05 5.38125e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.90043e-04 2.42538e-05 ... 5.72087e-05 5.65008e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [6.21364e-04 3.57939e-04 ... 2.97861e-05 4.23380e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.33770e-04 5.04945e-04 ... 1.01969e-05 2.46146e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.82777e-04 4.94928e-04 ... 3.69046e-05 5.44426e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.08949e-05 1.49695e-04 ... 2.70911e-06 4.53712e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.23416e-04 1.93617e-04 ... 2.62392e-05 2.95110e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.20168e-05 6.69460e-05 ... 7.52054e-07 1.50924e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.82473e-05 3.15473e-04 ... 3.01859e-05 2.95591e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [9.18745e-04 6.26493e-04 ... 2.77327e-05 8.67196e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.34947e-04 2.58560e-04 ... 3.91076e-05 3.83775e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.30744e-04 2.13778e-04 ... 1.81032e-05 2.07972e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.17233e-05 5.60455e-04 ... 2.79544e-06 1.43531e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.25660e-04 3.15434e-04 ... 7.22534e-06 4.86923e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.57698e-04 6.54797e-04 ... 9.61743e-05 4.48553e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.18194e-03 5.52899e-04 ... 6.02052e-08 3.55861e-07]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.77504e-04 8.21575e-05 ... 2.02978e-05 1.57636e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.27530e-05 3.31275e-04 ... 1.56728e-05 4.64934e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.12868e-04 9.12779e-05 ... 5.10488e-05 4.85599e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.79968e-05 3.87794e-04 ... 8.71796e-06 8.17662e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.14846e-04 9.29014e-04 ... 5.28029e-05 4.24362e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [9.75629e-05 6.36162e-04 ... 2.95936e-05 1.88524e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.72020e-04 6.00721e-04 ... 1.13180e-04 1.05254e-04]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [9.38761e-05 2.72679e-04 ... 1.47035e-05 1.49213e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.68502e-04 6.37325e-04 ... 4.33421e-05 4.22153e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.82619e-04 5.66759e-04 ... 2.01678e-05 8.43847e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.40058e-05 2.90632e-04 ... 8.20076e-05 3.92705e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.64740e-04 1.21700e-04 ... 2.71401e-05 1.04315e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.24704e-04 2.72936e-04 ... 3.52139e-06 5.19891e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.57002e-03 3.53154e-04 ... 8.24829e-05 4.14357e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.62807e-04 7.74734e-04 ... 3.21860e-05 1.34602e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.40919e-04 6.28397e-05 ... 4.07189e-05 5.10056e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.25113e-04 8.02651e-04 ... 3.84536e-05 3.33891e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.59466e-04 5.44521e-04 ... 4.29213e-05 2.83304e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.15418e-04 3.08549e-04 ... 4.23526e-05 6.31188e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.59317e-05 1.00995e-04 ... 3.17825e-05 1.92659e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.33841e-04 2.16802e-07 ... 5.85800e-05 3.89715e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.08835e-04 3.74952e-04 ... 3.25907e-05 2.31531e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.97977e-05 6.81079e-05 ... 2.57448e-05 1.50050e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.04840e-04 8.52605e-05 ... 1.46198e-05 3.75936e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.90285e-04 1.16813e-04 ... 4.74398e-05 4.71059e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.11567e-03 1.20526e-03 ... 5.23685e-06 3.28215e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.16538e-04 2.23134e-04 ... 3.54072e-06 1.13998e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.55966e-04 2.48803e-05 ... 4.48596e-05 4.24157e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.44100e-05 1.51414e-04 ... 1.89988e-05 1.77743e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.02603e-04 1.48081e-04 ... 5.75414e-05 3.77307e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.96488e-04 3.60769e-04 ... 5.83815e-06 3.08001e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.89590e-04 5.97162e-04 ... 8.79162e-05 5.91568e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.25245e-04 4.28733e-04 ... 3.68763e-05 4.52122e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.55210e-04 1.87600e-04 ... 5.48208e-05 3.37165e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.32394e-04 1.09773e-03 ... 1.42882e-05 1.33612e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.56041e-04 4.45085e-04 ... 2.03652e-05 9.30612e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.54675e-04 5.70066e-04 ... 3.69027e-05 3.72668e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.32623e-04 3.43207e-04 ... 2.52000e-05 2.13605e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.06646e-04 4.48935e-04 ... 4.95789e-05 4.24461e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.62191e-04 6.80837e-04 ... 3.66042e-05 2.50723e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.42895e-04 4.83797e-05 ... 2.58823e-05 2.07436e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.97512e-05 3.54441e-04 ... 8.14080e-05 8.65573e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.68845e-05 4.76954e-04 ... 2.48673e-05 2.43746e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.75073e-04 2.86383e-05 ... 2.49158e-05 2.52664e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.93653e-04 6.75763e-04 ... 4.33111e-06 6.85838e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.09398e-05 3.03461e-04 ... 1.82132e-05 2.28325e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [9.63677e-04 6.32381e-04 ... 0.00000e+00 2.48647e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.47573e-04 3.84712e-04 ... 6.63293e-06 1.47915e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.98505e-04 8.75129e-04 ... 2.14382e-06 1.57349e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.12705e-04 4.84009e-04 ... 1.09225e-04 1.22280e-04]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.80576e-04 1.50023e-03 ... 3.45848e-05 2.13864e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.24648e-04 4.19999e-04 ... 3.63896e-05 5.25501e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [6.29411e-05 1.29417e-04 ... 2.16509e-05 2.38869e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.90107e-04 5.08012e-04 ... 5.87114e-05 4.11686e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.96122e-04 7.43776e-04 ... 5.01756e-05 8.95414e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.42071e-04 8.60197e-04 ... 3.71405e-05 2.46674e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.71764e-06 1.99480e-04 ... 1.45671e-05 2.01945e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.44261e-03 2.46108e-04 ... 0.00000e+00 8.70817e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.78633e-04 7.90604e-04 ... 1.29552e-05 1.82621e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.24707e-04 7.40479e-04 ... 3.96074e-06 0.00000e+00]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.67950e-04 4.54078e-04 ... 3.02559e-05 2.72818e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.39323e-04 9.38928e-04 ... 2.23074e-05 2.99255e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.32131e-03 2.16629e-03 ... 5.93222e-05 5.27924e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.53877e-06 1.16600e-04 ... 3.02495e-05 1.74098e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.18026e-04 6.12881e-04 ... 1.21810e-05 1.60707e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.44881e-04 3.95089e-04 ... 1.55797e-05 6.16040e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.89769e-04 7.93736e-05 ... 5.66739e-05 4.96711e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.45746e-04 3.37365e-04 ... 2.70236e-05 4.57521e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.05285e-04 1.42989e-04 ... 4.02226e-05 5.77539e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.08435e-03 1.05349e-03 ... 1.49041e-05 2.20805e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.72629e-04 9.11418e-04 ... 1.07082e-05 5.17472e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.36689e-04 7.54626e-04 ... 2.32698e-05 1.86502e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.72969e-05 1.41010e-04 ... 2.23652e-05 2.72107e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.49439e-04 3.81426e-04 ... 1.28650e-05 1.17164e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.17660e-05 6.60366e-05 ... 2.45068e-05 2.03182e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [6.55273e-04 6.19585e-04 ... 3.94321e-05 3.16776e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.78298e-04 1.72358e-04 ... 4.90353e-05 3.45485e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.76822e-04 3.43397e-04 ... 5.13466e-05 5.02701e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.17045e-05 4.96430e-04 ... 3.96991e-06 1.70157e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.37206e-04 2.33688e-04 ... 7.75563e-06 8.72463e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.04197e-04 2.85232e-05 ... 5.89423e-05 3.59727e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.86556e-03 4.15099e-04 ... 4.10793e-05 2.09917e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.09572e-04 4.62775e-04 ... 2.22822e-05 1.68031e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.02545e-04 5.45279e-05 ... 9.37394e-06 1.03882e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.76051e-04 6.50294e-05 ... 4.37201e-05 3.79238e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.71391e-04 8.07649e-04 ... 1.71349e-07 2.01188e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.05167e-04 5.17381e-04 ... 6.12705e-06 1.16398e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.81885e-04 1.00251e-03 ... 3.70127e-05 4.38764e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.04525e-04 7.63170e-04 ... 6.81591e-05 4.55502e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.13864e-04 4.33714e-04 ... 1.37494e-05 1.28308e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.97759e-04 3.88888e-04 ... 2.70969e-05 3.16555e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [6.14092e-04 5.32414e-03 ... 2.70068e-05 3.97376e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.57492e-04 1.35707e-04 ... 2.77623e-05 2.52428e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [9.28074e-05 2.15266e-04 ... 1.47266e-05 8.70536e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.52648e-03 1.14394e-04 ... 2.48545e-05 3.58890e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.79799e-04 1.87906e-04 ... 2.86571e-05 1.18264e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.38870e-04 3.12680e-04 ... 2.84049e-05 8.17599e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.48791e-04 4.53466e-04 ... 3.50124e-05 3.91637e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.46841e-04 5.06688e-04 ... 7.43986e-05 6.93056e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.14167e-03 1.05053e-03 ... 2.92743e-05 4.75997e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.12491e-04 3.42997e-04 ... 3.11365e-05 4.19815e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.75029e-04 4.71766e-04 ... 2.05655e-05 2.34252e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.82958e-04 1.75880e-04 ... 2.61657e-06 0.00000e+00]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [9.65338e-05 6.55992e-05 ... 6.75053e-05 6.35406e-05]
#  ]),
#  SpectrumObject([
# ...
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.48501e-04 4.00100e-04 ... 2.59894e-05 2.27453e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.90576e-05 2.95293e-04 ... 3.46957e-05 4.14593e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.63370e-04 7.89784e-04 ... 2.57246e-05 2.25771e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [9.12600e-05 4.69870e-05 ... 3.45421e-05 6.30564e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.61078e-04 2.45189e-04 ... 4.04623e-06 1.16838e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.17168e-04 2.62120e-04 ... 3.27481e-05 3.35216e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.00824e-04 2.63427e-04 ... 1.81927e-05 2.46325e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.87820e-04 5.94300e-04 ... 4.03128e-05 2.66946e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.58259e-06 2.98739e-04 ... 1.29539e-05 8.03959e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.58081e-04 8.51800e-04 ... 2.96311e-05 4.29092e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.13059e-04 8.80287e-04 ... 3.54011e-05 3.53589e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.16113e-04 6.00355e-04 ... 2.25661e-05 8.74614e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.04272e-04 3.24703e-05 ... 6.11721e-05 4.62670e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.88706e-04 4.97818e-04 ... 2.07148e-05 2.04175e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.05733e-04 7.59263e-04 ... 2.85740e-05 1.56601e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.39470e-04 6.27790e-04 ... 2.15355e-06 3.30478e-08]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.66740e-04 1.15993e-03 ... 7.43454e-05 6.91103e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.67090e-04 3.50845e-04 ... 5.09465e-05 4.68384e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.56368e-04 6.40151e-04 ... 5.46507e-05 4.15287e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.20031e-04 3.43910e-04 ... 1.22754e-05 1.77161e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.16762e-04 4.01400e-04 ... 1.96958e-05 1.72124e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.44860e-05 6.22735e-04 ... 4.26172e-05 5.62049e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.45552e-04 5.72714e-04 ... 3.91461e-05 4.43487e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.69590e-04 4.30090e-04 ... 4.23165e-05 4.14705e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.42938e-04 2.04668e-04 ... 1.06807e-05 1.34358e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.23579e-04 8.43424e-04 ... 2.55597e-05 3.90554e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.74562e-04 7.36662e-06 ... 3.29782e-06 8.49490e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.26365e-03 2.15771e-04 ... 1.31685e-06 6.83533e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [9.23650e-05 2.36696e-04 ... 4.89371e-05 4.78195e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.89630e-03 8.86824e-04 ... 6.41698e-06 2.09182e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.81333e-04 3.62619e-04 ... 1.62700e-05 2.19491e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.16077e-03 1.60560e-04 ... 6.97234e-05 4.66312e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.71157e-04 3.11707e-04 ... 4.09135e-05 2.12087e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.02365e-04 5.15304e-04 ... 2.07659e-05 2.08060e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.94930e-05 5.61804e-04 ... 1.97670e-05 1.07958e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.21361e-04 6.53630e-05 ... 2.51568e-05 2.76634e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.34788e-04 8.29769e-04 ... 4.44477e-05 7.21086e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [6.42785e-04 2.41718e-04 ... 3.74924e-05 5.45243e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [6.62621e-04 7.61242e-04 ... 7.61560e-05 4.08601e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.82777e-04 5.05704e-04 ... 2.22224e-05 2.06767e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.55120e-05 7.00912e-05 ... 1.84134e-06 4.91564e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.63378e-04 4.07874e-04 ... 1.87141e-06 7.03636e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.05224e-04 5.40042e-04 ... 1.52502e-05 1.07143e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.20280e-04 1.97942e-04 ... 3.29947e-05 6.01560e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.33324e-04 1.50250e-04 ... 1.42551e-05 4.37397e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.44837e-04 1.61259e-04 ... 3.47670e-05 3.96566e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.77462e-04 2.37321e-03 ... 5.74134e-05 5.24815e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.18026e-04 2.49384e-04 ... 4.19075e-05 4.10380e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.03119e-05 1.75810e-04 ... 4.76926e-05 5.00892e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.59445e-04 7.04023e-04 ... 2.27514e-05 3.29425e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.14150e-04 9.70013e-06 ... 8.32667e-05 1.39273e-04]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [9.11237e-04 6.67860e-04 ... 9.34567e-06 0.00000e+00]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.53440e-04 4.70846e-04 ... 3.17213e-05 6.88408e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [9.64358e-05 9.31983e-05 ... 1.04489e-05 1.90529e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.57852e-05 9.70364e-05 ... 3.56539e-05 1.45414e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.50319e-04 5.82116e-05 ... 1.46898e-05 1.73294e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.99330e-04 3.53399e-04 ... 5.94937e-05 3.34500e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.68616e-04 3.00019e-05 ... 3.44711e-05 4.89135e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.13325e-05 9.56155e-04 ... 0.00000e+00 9.01346e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.41179e-03 7.24735e-04 ... 3.83872e-05 7.76105e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.16494e-04 7.28031e-04 ... 6.48448e-05 4.38079e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.71159e-04 4.00595e-04 ... 2.86115e-05 3.06851e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.64148e-04 4.70937e-04 ... 2.63293e-05 1.66485e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.06755e-04 6.37921e-05 ... 3.76644e-05 3.90833e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [6.90776e-05 4.74874e-04 ... 3.53245e-05 4.98743e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.59089e-04 1.00268e-03 ... 3.16497e-05 3.02383e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.12463e-05 1.90612e-04 ... 2.89393e-05 3.30010e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.04235e-04 1.79564e-04 ... 1.79568e-05 2.16236e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.66265e-04 2.18990e-04 ... 1.73052e-05 4.93758e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.03663e-04 2.10828e-04 ... 5.91539e-05 5.06041e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.97060e-05 2.05772e-04 ... 2.90704e-05 1.26365e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.66310e-04 3.72681e-04 ... 8.90247e-06 1.44689e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.16980e-04 1.87122e-04 ... 2.70454e-05 3.38644e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.90585e-04 9.34112e-04 ... 4.02928e-05 3.96902e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.54729e-04 6.67428e-04 ... 2.76624e-06 1.58130e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.50482e-04 2.72063e-04 ... 1.05506e-05 2.63056e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.01206e-04 2.46286e-04 ... 5.84874e-07 1.75578e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.77018e-04 6.05209e-04 ... 2.29716e-05 2.00986e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.31065e-04 5.55530e-04 ... 1.44232e-05 1.74703e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.80471e-04 6.55754e-05 ... 3.11153e-05 6.00825e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.54475e-04 1.79406e-04 ... 1.52093e-05 1.65834e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.90259e-04 1.99142e-04 ... 4.99762e-05 5.96061e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.18816e-04 1.47719e-03 ... 1.13953e-05 9.72140e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [5.11304e-04 1.41481e-03 ... 5.24409e-05 6.36608e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.44363e-04 2.93508e-04 ... 8.13662e-06 2.41367e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.02501e-04 2.16250e-05 ... 2.03333e-05 5.50652e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.12553e-04 1.43692e-05 ... 5.66757e-06 1.06696e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [6.30748e-04 1.80031e-04 ... 8.09614e-06 4.08382e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.98339e-04 4.49391e-04 ... 2.26185e-06 1.75713e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.50286e-04 4.35877e-04 ... 1.78461e-05 4.75802e-07]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.51578e-04 2.32675e-04 ... 4.42017e-05 4.37278e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.84811e-04 1.07002e-04 ... 2.08976e-05 8.58746e-06]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.00522e-04 5.74896e-05 ... 3.34356e-05 2.01374e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.30518e-04 7.39415e-04 ... 3.53567e-05 4.88752e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.11353e-03 1.55114e-04 ... 3.05473e-05 3.15491e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.74199e-04 5.69252e-04 ... 5.74623e-05 2.55099e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.08020e-04 2.47127e-04 ... 5.06939e-05 4.48760e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [2.54409e-04 6.63058e-05 ... 7.68323e-06 1.73684e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [6.88818e-05 1.47957e-05 ... 7.04182e-06 0.00000e+00]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.27145e-04 3.73679e-04 ... 5.22025e-05 7.42028e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [7.50759e-04 7.34550e-04 ... 4.57109e-05 6.91959e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.57115e-05 2.28394e-04 ... 4.18843e-06 1.02939e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [4.82569e-04 6.52622e-04 ... 3.93288e-05 2.26378e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [8.80787e-04 7.09758e-04 ... 2.44975e-05 8.49722e-07]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [1.42015e-04 6.07575e-04 ... 3.20800e-05 2.53428e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.37107e-04 2.35103e-04 ... 4.89855e-05 4.02527e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.57579e-05 7.26328e-04 ... 2.49961e-05 2.68200e-05]
#  ]),
#  SpectrumObject([
#  	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
#  	int = [3.47259e-04 3.58011e-05 ... 1.17159e-05 8.98110e-06]
#  ]),
#  ...]

# %%
species_counts = metadata['species']
print(species_counts)
print(len(spectra_preprocessed))
# Out:
# 0                 Escherichia coli
# 1            Enterococcus faecalis
# 2                 Escherichia coli
# 3                 Escherichia coli
# 4            Staphylococcus aureus
#                    ...
# 3451         Enterococcus faecalis
# 3452              Candida albicans
# 3453    Staphylococcus epidermidis
# 3454         Enterococcus faecalis
# 3455    Staphylococcus epidermidis
# Name: species, Length: 3456, dtype: object
# 3456

# %%
print(spectra_preprocessed[1])
print(metadata.loc[1])
# Out:
# SpectrumObject([
# 	mz  = [2.00150e+03 2.00450e+03 ... 1.99955e+04 1.99985e+04],
# 	int = [8.96074e-04 7.07358e-05 ... 1.12038e-05 8.06093e-08]
# ])
# species                   Enterococcus faecalis
# code       82d1d76f-f9e5-412e-b6d5-4def4fe0c1e2
# Name: 1, dtype: object

# %% [markdown]
# # What is a MALDI-TOF MS spectra?
#
# **1. What does this spectrum show?**
#
# The MALDI-TOF spectrum is essentially a molecular fingerprint. It displays ionized molecules from a sample—commonly proteins or peptides—detected by their mass-to-charge ratio (m/z). Each peak in the spectrum corresponds to a different ionized molecule. So, when you see a sharp rise on the graph, you're actually seeing the presence of a specific molecule, like a small protein or peptide.
#
# **2. Why is this useful for identifying microorganisms?**
#
# Every microorganism—bacteria, fungi, and others—has a unique set of proteins. These proteins generate patterns in the MALDI-TOF spectrum, much like a biological barcode. By comparing these patterns to a other spectra or a spectral reference database, microbiologists can quickly and accurately identify the microorganism.
#
# **3. What does the x-axis represent?**
#
# The horizontal axis in a MALDI-TOF spectrum is the mass-to-charge ratio (m/z). This ratio reflects how heavy a molecule is, relative to its charge. In the MALDI process, most ions are singly charged (charge = +1), so the m/z usually just reflects the actual mass of the molecule. Lighter ions—or those with higher charges—reach the detector faster and appear earlier (lower m/z).
#
# **4. What does the y-axis show?**
#
# The vertical axis represents intensity, or more specifically, the number of ions detected at each m/z value. A higher peak means more ions of that specific mass were detected. While it doesn’t give an exact concentration, it gives a rough sense of how abundant each molecule is in the sample.

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Select one spectrum index to visualize
idx = 1

# Preprocessed spectrum
mz_pre = spectra_preprocessed[idx].mz
intensity_pre = spectra_preprocessed[idx].intensity

# Raw (unprocessed) spectrum
mz_raw = spectra[idx].mz
intensity_raw = spectra[idx].intensity

# Create subplot figure with 2 side-by-side plots
fig = make_subplots(rows=1, cols=2, subplot_titles=("Preprocessed Spectrum", "Raw Spectrum"))

# Add preprocessed spectrum trace
fig.add_trace(
    go.Scatter(x=mz_pre, y=intensity_pre, mode='lines', name='Preprocessed'),
    row=1, col=1
)

# Add raw spectrum trace
fig.add_trace(
    go.Scatter(x=mz_raw, y=intensity_raw, mode='lines', name='Raw', line=dict(color='orange')),
    row=1, col=2
)

# Update layout
fig.update_layout(
    height=400, width=1000,
    title_text="Comparison of Preprocessed vs Raw MALDI-TOF Spectra",
    xaxis_title="m/z",
    yaxis_title="Intensity",
    xaxis2_title="m/z",
    yaxis2_title="Intensity"
)

fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="35c8c139-db57-4099-9902-96754fdac917" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35c8c139-db57-4099-9902-96754fdac917")) {                    Plotly.newPlot(                        "35c8c139-db57-4099-9902-96754fdac917",                        [{"mode":"lines","name":"Preprocessed","x":[2001.5,2004.5,2007.5,2010.5,2013.5,2016.5,2019.5,2022.5,2025.5,2028.5,2031.5,2034.5,2037.5,2040.5,2043.5,2046.5,2049.5,2052.5,2055.5,2058.5,2061.5,2064.5,2067.5,2070.5,2073.5,2076.5,2079.5,2082.5,2085.5,2088.5,2091.5,2094.5,2097.5,2100.5,2103.5,2106.5,2109.5,2112.5,2115.5,2118.5,2121.5,2124.5,2127.5,2130.5,2133.5,2136.5,2139.5,2142.5,2145.5,2148.5,2151.5,2154.5,2157.5,2160.5,2163.5,2166.5,2169.5,2172.5,2175.5,2178.5,2181.5,2184.5,2187.5,2190.5,2193.5,2196.5,2199.5,2202.5,2205.5,2208.5,2211.5,2214.5,2217.5,2220.5,2223.5,2226.5,2229.5,2232.5,2235.5,2238.5,2241.5,2244.5,2247.5,2250.5,2253.5,2256.5,2259.5,2262.5,2265.5,2268.5,2271.5,2274.5,2277.5,2280.5,2283.5,2286.5,2289.5,2292.5,2295.5,2298.5,2301.5,2304.5,2307.5,2310.5,2313.5,2316.5,2319.5,2322.5,2325.5,2328.5,2331.5,2334.5,2337.5,2340.5,2343.5,2346.5,2349.5,2352.5,2355.5,2358.5,2361.5,2364.5,2367.5,2370.5,2373.5,2376.5,2379.5,2382.5,2385.5,2388.5,2391.5,2394.5,2397.5,2400.5,2403.5,2406.5,2409.5,2412.5,2415.5,2418.5,2421.5,2424.5,2427.5,2430.5,2433.5,2436.5,2439.5,2442.5,2445.5,2448.5,2451.5,2454.5,2457.5,2460.5,2463.5,2466.5,2469.5,2472.5,2475.5,2478.5,2481.5,2484.5,2487.5,2490.5,2493.5,2496.5,2499.5,2502.5,2505.5,2508.5,2511.5,2514.5,2517.5,2520.5,2523.5,2526.5,2529.5,2532.5,2535.5,2538.5,2541.5,2544.5,2547.5,2550.5,2553.5,2556.5,2559.5,2562.5,2565.5,2568.5,2571.5,2574.5,2577.5,2580.5,2583.5,2586.5,2589.5,2592.5,2595.5,2598.5,2601.5,2604.5,2607.5,2610.5,2613.5,2616.5,2619.5,2622.5,2625.5,2628.5,2631.5,2634.5,2637.5,2640.5,2643.5,2646.5,2649.5,2652.5,2655.5,2658.5,2661.5,2664.5,2667.5,2670.5,2673.5,2676.5,2679.5,2682.5,2685.5,2688.5,2691.5,2694.5,2697.5,2700.5,2703.5,2706.5,2709.5,2712.5,2715.5,2718.5,2721.5,2724.5,2727.5,2730.5,2733.5,2736.5,2739.5,2742.5,2745.5,2748.5,2751.5,2754.5,2757.5,2760.5,2763.5,2766.5,2769.5,2772.5,2775.5,2778.5,2781.5,2784.5,2787.5,2790.5,2793.5,2796.5,2799.5,2802.5,2805.5,2808.5,2811.5,2814.5,2817.5,2820.5,2823.5,2826.5,2829.5,2832.5,2835.5,2838.5,2841.5,2844.5,2847.5,2850.5,2853.5,2856.5,2859.5,2862.5,2865.5,2868.5,2871.5,2874.5,2877.5,2880.5,2883.5,2886.5,2889.5,2892.5,2895.5,2898.5,2901.5,2904.5,2907.5,2910.5,2913.5,2916.5,2919.5,2922.5,2925.5,2928.5,2931.5,2934.5,2937.5,2940.5,2943.5,2946.5,2949.5,2952.5,2955.5,2958.5,2961.5,2964.5,2967.5,2970.5,2973.5,2976.5,2979.5,2982.5,2985.5,2988.5,2991.5,2994.5,2997.5,3000.5,3003.5,3006.5,3009.5,3012.5,3015.5,3018.5,3021.5,3024.5,3027.5,3030.5,3033.5,3036.5,3039.5,3042.5,3045.5,3048.5,3051.5,3054.5,3057.5,3060.5,3063.5,3066.5,3069.5,3072.5,3075.5,3078.5,3081.5,3084.5,3087.5,3090.5,3093.5,3096.5,3099.5,3102.5,3105.5,3108.5,3111.5,3114.5,3117.5,3120.5,3123.5,3126.5,3129.5,3132.5,3135.5,3138.5,3141.5,3144.5,3147.5,3150.5,3153.5,3156.5,3159.5,3162.5,3165.5,3168.5,3171.5,3174.5,3177.5,3180.5,3183.5,3186.5,3189.5,3192.5,3195.5,3198.5,3201.5,3204.5,3207.5,3210.5,3213.5,3216.5,3219.5,3222.5,3225.5,3228.5,3231.5,3234.5,3237.5,3240.5,3243.5,3246.5,3249.5,3252.5,3255.5,3258.5,3261.5,3264.5,3267.5,3270.5,3273.5,3276.5,3279.5,3282.5,3285.5,3288.5,3291.5,3294.5,3297.5,3300.5,3303.5,3306.5,3309.5,3312.5,3315.5,3318.5,3321.5,3324.5,3327.5,3330.5,3333.5,3336.5,3339.5,3342.5,3345.5,3348.5,3351.5,3354.5,3357.5,3360.5,3363.5,3366.5,3369.5,3372.5,3375.5,3378.5,3381.5,3384.5,3387.5,3390.5,3393.5,3396.5,3399.5,3402.5,3405.5,3408.5,3411.5,3414.5,3417.5,3420.5,3423.5,3426.5,3429.5,3432.5,3435.5,3438.5,3441.5,3444.5,3447.5,3450.5,345 ...

# %% [markdown]
# # Harmonizing effect of preprocessing
#
# Raw MALDI-TOF spectra often contain noise, baseline drifts, and intensity variations that make it difficult to identify meaningful patterns or clusters directly from the data. When visualized with dimensionality reduction techniques like t-SNE, the raw spectra tend to appear scattered and mixed, showing poor separation between different sample groups or species.
#
# By applying our carefully chosen preprocessing steps—variance stabilization, smoothing, baseline correction, normalization, and binning—we effectively **harmonize the spectral data**. This process reduces technical variability and emphasizes biologically relevant signals.
#
# As a result, when we apply t-SNE to the preprocessed spectra, we observe **clearer clustering and better separation** of sample groups. This improved cluster structure reflects that preprocessing helps highlight the underlying biological differences and makes downstream machine learning tasks, such as classification, more accurate and reliable.
#
# In summary, preprocessing acts as a crucial harmonizing step, transforming noisy raw data into a structured format that reveals meaningful patterns.

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np
import matplotlib.cm as cm
from matplotlib.colors import ListedColormap, to_hex

# Define preprocessor and its steps
preprocessor = maldi_spectrum.SequentialPreprocessor(
    maldi_spectrum.Binner(step=3)
)

# To do a t-SNE we must ensure that, at least, all of them are same shape, so we msut do binning at least.
raw_spec = [preprocessor(spectrum) for spectrum in spectra]


# Convert both things into a numpy arrays to work with tSNE
raw_spec = np.vstack([spectrum.intensity for spectrum in raw_spec])
preprocessed_spec = np.vstack([spectrum.intensity for spectrum in spectra_preprocessed])


######## ====================== Maybe this part can be removed in the student version ==================
# Example t-SNE parameters
tsne = TSNE(n_components=2, random_state=42, perplexity=30, n_iter=1000)


# Compute t-SNE embeddings
raw_emb = tsne.fit_transform(raw_spec)
preprocessed_emb = tsne.fit_transform(preprocessed_spec)

# Assume metadata["species"] is a list or array of species labels for each spectrum
species_labels = metadata["species"]

# Create a color map for unique species
unique_species = list(set(species_labels))

# Map species to integers
species_to_int = {species: i for i, species in enumerate(unique_species)}
species_ints = [species_to_int[sp] for sp in species_labels]

# Choose a colormap with enough distinct colors
cmap = cm.get_cmap('tab20', len(unique_species))  # tab20 has up to 20 distinct colors

# Plotting
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

scatter1 = axs[0].scatter(raw_emb[:, 0], raw_emb[:, 1], c=species_ints, cmap=cmap, s=10, alpha=0.7)
axs[0].set_title("t-SNE of Raw Spectra")
axs[0].set_xticks([])
axs[0].set_yticks([])

scatter2 = axs[1].scatter(preprocessed_emb[:, 0], preprocessed_emb[:, 1], c=species_ints, cmap=cmap, s=10, alpha=0.7)
axs[1].set_title("t-SNE of Preprocessed Spectra")
axs[1].set_xticks([])
axs[1].set_yticks([])

from collections import Counter

# Count species frequencies
species_counts = Counter(species_labels)

# Get top 5 species sorted by count descending
top5_species = [sp for sp, count in species_counts.most_common(5)]

# Prepare legend handles only for top 5 species
handles = []
for i, sp in enumerate(unique_species):
    if sp in top5_species:
        handles.append(
            plt.Line2D([0], [0], marker='o', color='w',
                       markerfacecolor=cmap(i), markersize=8, label=sp)
        )

fig.legend(handles=handles, loc='upper center', ncol=5, bbox_to_anchor=(0.5, 1.05))

plt.suptitle("Effect of Preprocessing on Spectra Visualization with t-SNE", fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning:
#
# 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning:
#
# 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#
# <ipython-input-14-8b2fc3678214>:41: MatplotlibDeprecationWarning:
#
# The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.

# %%
from sklearn.manifold import TSNE

# Re-run t-SNE with 3 components for true 3D embeddings
tsne_3d = TSNE(n_components=3, random_state=42, perplexity=30, n_iter=1000)

raw_emb_3d = tsne_3d.fit_transform(raw_spec)
preprocessed_emb_3d = tsne_3d.fit_transform(preprocessed_spec)

# Prepare DataFrames for Plotly 3D t-SNE plots
df_raw_tsne3d = pd.DataFrame({
    'TSNE1': raw_emb_3d[:, 0],
    'TSNE2': raw_emb_3d[:, 1],
    'TSNE3': raw_emb_3d[:, 2],
    'Species': metadata['species']
})

df_preprocessed_tsne3d = pd.DataFrame({
    'TSNE1': preprocessed_emb_3d[:, 0],
    'TSNE2': preprocessed_emb_3d[:, 1],
    'TSNE3': preprocessed_emb_3d[:, 2],
    'Species': metadata['species']
})

import plotly.express as px

def plot_tsne_3d(df, title):
    fig = px.scatter_3d(
        df,
        x='TSNE1', y='TSNE2', z='TSNE3',
        color='Species',
        title=title,
        opacity=0.7,
        width=700,
        height=600,
        labels={'TSNE1': 't-SNE Dim 1', 'TSNE2': 't-SNE Dim 2', 'TSNE3': 't-SNE Dim 3'}
    )
    fig.update_traces(marker=dict(size=4))
    fig.update_layout(legend_title_text='Species')
    fig.show()

# Plot interactive 3D t-SNE visualizations
plot_tsne_3d(df_raw_tsne3d, "3D t-SNE of Raw Spectra")
plot_tsne_3d(df_preprocessed_tsne3d, "3D t-SNE of Preprocessed Spectra")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning:
#
# 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning:
#
# 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f702838e-b7d6-452a-890e-e4f16dc692ec" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f702838e-b7d6-452a-890e-e4f16dc692ec")) {                    Plotly.newPlot(                        "f702838e-b7d6-452a-890e-e4f16dc692ec",                        [{"hovertemplate":"Species=Escherichia coli\u003cbr\u003et-SNE Dim 1=%{x}\u003cbr\u003et-SNE Dim 2=%{y}\u003cbr\u003et-SNE Dim 3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Escherichia coli","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle","size":4},"mode":"markers","name":"Escherichia coli","scene":"scene","showlegend":true,"x":[4.262034,-16.991526,-16.719027,-16.950129,6.139043,-2.1433048,-13.951865,-17.197977,-14.089187,-7.5472393,-4.950956,-1.5014197,-8.6390085,-5.6860275,-16.563847,-17.282871,-15.043574,-8.162717,-18.028343,1.0819544,-4.3980904,-11.176581,-14.259124,-4.6349053,-18.228697,-13.083913,-18.267286,-12.492065,-8.434269,-12.08399,-12.820199,-13.576956,-2.071284,-10.421377,-12.555233,13.365361,-16.467106,-8.6794815,2.8028347,5.9696293,-8.489775,-3.9242117,0.47333246,-3.4549718,-7.63661,-19.046799,-11.004549,-11.775661,-10.07434,-1.9364796,-8.799801,-7.9602404,-16.110872,-8.48766,-12.228287,-17.381239,-19.30586,-5.848081,-5.6309776,-12.892184,-8.2067375,-17.632042,-19.401522,1.559974,-18.045025,-15.16729,1.0621033,1.1610322,-10.45314,-19.215115,-18.834528,-9.195126,-7.3121567,-6.274077,-1.9783337,-17.283405,6.042827,-6.1877046,-12.766162,0.05467198,-20.464794,-3.44695,-9.572696,-13.547618,-5.716053,-12.843133,-13.582675,-18.255716,-4.0576196,-21.069504,1.4190705,-19.39415,-18.265764,-3.5475414,-12.260691,-9.929647,-12.314078,-19.83262,-16.84057,-18.023252,-1.1202663,-19.90143,-5.403185,-12.15648,-12.428172,-14.842138,4.1021576,-17.361696,7.427103,-18.981812,-10.288926,3.9694731,-15.899291,-14.317884,-15.801164,-10.027456,-6.1832495,-18.814857,-5.631624,-12.845742,-8.351649,-13.089996,-16.29624,-10.133373,-4.999325,-16.634722,-11.891684,-18.820934,-16.143917,-17.137901,12.547467,-19.869007,-17.20544,-1.1635909,-4.050446,-20.436483,-16.777586,-18.392088,-10.969951,-16.060741,-7.84839,-10.95884,7.4581647,-8.924616,-16.985182,-14.150948,-5.028832,-7.6728554,-4.5798845,-12.576733,-7.971595,-13.2922325,-14.518741,-8.741842,-5.9596004,-1.8481321,-16.338776,-14.082969,1.6592102,-11.513714,-15.155575,-15.187236,-4.0261602,-16.178118,-3.345021,-5.145345,-4.8746495,-12.391322,-3.5377166,-14.497185,1.6760426,-8.558989,-1.013388,-1.9243822,-4.5772004,-7.487737,-4.466485,-15.906447,-16.87195,-7.352668,-14.3583765,-2.3278213,-19.960495,-10.459111,1.7163093,-17.921467,-20.528465,-4.0705943,-17.049067,-12.088644,-12.948458,-17.58338,-11.303042,-16.431484,-6.527953,-13.58914,-17.45298,-14.142993,6.5621634,13.312598,-19.273005,-2.4059706,-13.801894,-13.123318,-2.0574818,-8.236939,-20.47804,-13.605251,-13.28206,-18.462687,-11.793926,-11.270232,-15.451272,7.0926633,-0.4674011,-19.313187,-12.894666,-13.0842,12.250019,-18.046057,-16.814453,-9.66567,-13.803828,-12.281979,-3.668955,-17.472464,-8.376273,-5.015858,-5.9682455,-14.616561,-18.208677,-19.374802,-20.024542,-8.033242,-16.141254,-12.156651,-19.92766,-14.2813835,-20.20309,-8.83166,-11.466898,1.2034367,-11.171571,-16.350168,-12.907999,-9.182021,1.1448494,-16.181854,-16.116827,-5.947276,-7.555099,-6.5399513,-5.574508,-13.838802,-12.982725,-17.376566,-8.083631,-19.56745,-16.282927,-10.236733,-3.045043,-6.0099893,-6.4294095,-3.0708067,-9.725219,-5.8446918,-16.177774,-4.803106,-15.981675,-18.264355,-14.46583,-11.164911,-10.959003,-19.6363,-15.513652,-19.039831,-17.47678,-19.285948,-2.7175899,-16.425777,-8.797582,-14.749308,-18.484774,-14.972217,-18.815277,-13.653424,-20.199564,-10.775805,-13.130111,-5.3037 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e7418946-e713-4255-bacf-321f5cb9b34d" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7418946-e713-4255-bacf-321f5cb9b34d")) {                    Plotly.newPlot(                        "e7418946-e713-4255-bacf-321f5cb9b34d",                        [{"hovertemplate":"Species=Escherichia coli\u003cbr\u003et-SNE Dim 1=%{x}\u003cbr\u003et-SNE Dim 2=%{y}\u003cbr\u003et-SNE Dim 3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Escherichia coli","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle","size":4},"mode":"markers","name":"Escherichia coli","scene":"scene","showlegend":true,"x":[9.743062,12.468883,16.754774,14.460901,4.3473797,9.090631,8.099461,17.740538,4.6964254,12.091261,6.7515063,9.929961,12.174722,5.9701004,8.941069,19.672142,10.380577,13.907226,18.086987,14.490606,5.236683,5.2391486,18.150131,7.37133,14.211242,10.506729,14.8151865,9.422358,13.78853,15.076114,10.681006,7.327878,7.4136987,6.4956117,10.5391445,6.2948117,14.490804,12.551579,4.675974,12.7846365,13.908563,10.418785,16.911077,7.223061,14.846671,14.106008,8.942318,21.169434,6.87498,6.315685,10.648711,15.085372,18.94543,6.6864805,12.229259,5.116506,13.493138,10.189054,10.311741,7.6148124,13.651057,11.368123,15.735503,11.103211,18.588112,11.775112,10.651422,12.862601,15.323569,12.513594,17.119774,11.175145,6.2292,7.968869,6.2917776,18.638231,7.5120554,10.371094,7.6040115,14.630305,15.828497,12.651886,11.374422,10.224896,6.724193,6.882587,7.0028276,7.546026,9.989209,15.04783,12.321226,17.370565,19.550594,13.622357,8.299457,13.218674,8.286938,18.247581,14.617802,7.814311,8.983102,16.010418,10.132685,8.000834,7.3045197,11.166245,13.937761,19.508692,11.438654,15.569484,11.70109,12.52344,13.840264,9.323907,15.09759,10.172559,11.323358,14.714472,10.733939,8.41379,14.494785,8.168616,11.892833,14.854894,9.338806,18.73599,5.37968,9.147783,15.1343775,15.055618,8.967576,14.612406,21.139236,14.510988,9.518316,13.767352,12.498274,7.978353,7.989332,4.0586367,11.63296,16.31253,11.344976,13.611245,18.607977,10.028203,9.047151,12.211663,7.3133707,12.883704,15.260197,8.221612,8.565443,13.438705,10.688077,5.585329,12.4634495,6.3271832,7.7966223,5.8570685,12.0784445,16.420292,7.368923,17.8713,8.78184,6.0204635,10.872157,9.123893,13.415358,9.794334,5.7456403,12.346671,16.916618,8.4635935,6.3674374,11.0662,9.088982,7.127969,12.561976,11.064091,9.587833,10.125513,17.602707,4.952122,7.2934303,14.254116,16.873913,5.9147315,19.03626,10.9708,7.8026514,11.393283,10.887335,12.503012,7.137537,11.6532755,19.021835,7.699277,10.821642,12.679246,16.476439,7.210091,7.4299803,7.221844,6.3390718,13.80543,15.47934,11.578869,7.2190237,7.587311,7.9505124,5.464343,7.478917,11.200285,9.655304,17.556791,12.990077,6.528676,9.830352,19.706312,14.841067,9.6152725,11.431708,10.263425,10.408536,14.940014,12.589817,10.104467,5.6813855,8.531824,18.789139,14.552745,13.923893,13.581279,8.393473,5.2706633,17.016943,8.433031,14.686693,12.706452,5.8162427,6.71315,5.518887,6.796579,9.263395,12.054641,14.551832,13.761761,10.467194,14.207658,13.478969,11.339468,8.036603,4.92151,6.951211,15.631593,16.348526,15.819555,14.824756,14.374828,10.219865,12.14506,7.705522,10.582797,13.798212,13.310179,4.096522,13.087099,4.3782396,12.062873,8.95915,15.706717,16.79832,13.924597,12.116606,9.776054,17.280657,17.313997,6.686887,15.050731,12.983186,14.348532,15.953443,7.595051,17.635899,16.10828,15.104194,5.386435,8.112929,10.167908,14.313411,10.649947,14.372014,6.8965173,15.429877,11.580179,6.510559,12.003017,20.101414,7.821643,5.773454,10.561896,14.776576,21.155828,14.898726,10.221243,13.109813,9.721839,12.2050085,16.1195,4.7943654,17.139181,11.079506,15.558583,7.4318447,13.231235,14.702912,7.8664503,9 ...

# %% [markdown]
# # Split stratified dataset into training/validation/test set

# %%
min_species_count = 5

# Step 1: Remove species with only one sample
species_counts = metadata['species'].value_counts()
species_to_keep = species_counts[species_counts > min_species_count].index
metadata_filtered = metadata[metadata['species'].isin(species_to_keep)].copy()

# Get the indices of the spectra to keep
indices_to_keep = metadata_filtered.index.tolist()

# Filter the preprocessed spectra based on the filtered metadata
spectra_preprocessed_filtered = [spectra_preprocessed[i] for i in indices_to_keep]

# Step 2: Remove spectra with species containing '!MIX'
metadata_filtered = metadata_filtered[~metadata_filtered['species'].str.contains('MIX!')].copy()

# Update the indices to keep based on the newly filtered metadata
indices_to_keep_no_mix = metadata_filtered.index.tolist()

# Filter the preprocessed spectra again based on the 'no !MIX' criteria
spectra_preprocessed_final = [spectra_preprocessed_filtered[i] for i in range(len(spectra_preprocessed_filtered)) if indices_to_keep[i] in indices_to_keep_no_mix]


print(f"Number of spectra after removing single-sample species and MIX!: {len(spectra_preprocessed_final)}")
print(f"Number of entries in metadata after filtering: {len(metadata_filtered)}")


# Step 3: Create training, validation, and test sets
from sklearn.model_selection import train_test_split

# Ensure the filtered metadata and spectra are aligned
assert len(metadata_filtered) == len(spectra_preprocessed_final)

# Reset index of filtered metadata to align with filtered spectra list
metadata_filtered = metadata_filtered.reset_index(drop=True)

# Split the indices for consistent splitting of metadata and spectra
indices = np.arange(len(metadata_filtered))

# First split: 80% training + validation, 20% test
train_val_indices, test_indices = train_test_split(
    indices,
    test_size=0.2,
    stratify=metadata_filtered['species'],
    random_state=42
)

# Second split: Split the 80% into 60% training and 20% validation
# Calculate the proportion of the original dataset that is validation
# Validation size relative to the combined train+val set: 20% / 80% = 0.25
train_indices, val_indices = train_test_split(
    train_val_indices,
    test_size=0.25, # 0.25 of the 80% is 20% of the total
    stratify=metadata_filtered.loc[train_val_indices, 'species'],
    random_state=42
)

# Get the corresponding metadata and spectra subsets
metadata_train = metadata_filtered.loc[train_indices].reset_index(drop=True)
spectra_train = [spectra_preprocessed_final[i] for i in train_indices]

metadata_val = metadata_filtered.loc[val_indices].reset_index(drop=True)
spectra_val = [spectra_preprocessed_final[i] for i in val_indices]

metadata_test = metadata_filtered.loc[test_indices].reset_index(drop=True)
spectra_test = [spectra_preprocessed_final[i] for i in test_indices]

print(f"\nTraining set size: {len(spectra_train)}")
print(f"Validation set size: {len(spectra_val)}")
print(f"Test set size: {len(spectra_test)}")

print("\nTraining set species distribution:")
print(metadata_train['species'].value_counts())

print("\nValidation set species distribution:")
print(metadata_val['species'].value_counts())

print("\nTest set species distribution:")
print(metadata_test['species'].value_counts())
# Out:
# Number of spectra after removing single-sample species and MIX!: 3456
# Number of entries in metadata after filtering: 3456
#
# Training set size: 2073
# Validation set size: 691
# Test set size: 692
#
# Training set species distribution:
# species
# Escherichia coli               503
# Staphylococcus aureus          316
# Staphylococcus epidermidis     271
# Enterococcus faecalis          183
# Pseudomonas aeruginosa         114
# Klebsiella pneumoniae          113
# Streptococcus agalactiae        99
# Candida albicans                75
# Staphylococcus haemolyticus     64
# Streptococcus anginosus         62
# Enterobacter cloacae            61
# Candida glabrata                56
# Streptococcus pyogenes          49
# Staphylococcus hominis          44
# Citrobacter koseri              32
# Staphylococcus lugdunensis      31
# Name: count, dtype: int64
#
# Validation set species distribution:
# species
# Escherichia coli               167
# Staphylococcus aureus          106
# Staphylococcus epidermidis      91
# Enterococcus faecalis           61
# Pseudomonas aeruginosa          38
# Klebsiella pneumoniae           38
# Streptococcus agalactiae        33
# Candida albicans                25
# Staphylococcus haemolyticus     22
# Streptococcus anginosus         20
# Enterobacter cloacae            20
# Candida glabrata                19
# Streptococcus pyogenes          16
# Staphylococcus hominis          14
# Staphylococcus lugdunensis      11
# Citrobacter koseri              10
# Name: count, dtype: int64
#
# Test set species distribution:
# species
# Escherichia coli               168
# Staphylococcus aureus          106
# Staphylococcus epidermidis      90
# Enterococcus faecalis           61
# Pseudomonas aeruginosa          38
# Klebsiella pneumoniae           38
# Streptococcus agalactiae        33
# Candida albicans                25
# Staphylococcus haemolyticus     21
# Streptococcus anginosus         21
# Enterobacter cloacae            20
# Candida glabrata                19
# Streptococcus pyogenes          16
# Staphylococcus hominis          15
# Staphylococcus lugdunensis      11
# Citrobacter koseri              10
# Name: count, dtype: int64

# %% [markdown]
# ## Dimensionality Reduction: PCA
#
# When working with high-dimensional MALDI-TOF spectra, reducing dimensionality is crucial to simplify the data, improve visualization, and sometimes enhance machine learning performance. Here, we introduce two common techniques: **Principal Component Analysis (PCA)**.
#
# These techniques are commonly used to understand, quick and simply, how is the latent distribution of my data:
#
# <img align="center" src="http://www.tsc.uc3m.es/~emipar/NOTEBOOKS/PCA_ML_health/pca1.png" width="70%" >
#
# In this sense, **feature extraction** methods exploit the data structure to reduce the dimensionality of the input space
#
#
#   <img align="center" src="http://www.tsc.uc3m.es/~vanessa/Figs_notebooks/ML/PCA/FE_intro.jpg" width="40%" >
#
# ---

# %% [markdown]
# # Principal Component Analysis (PCA)
#
# **Intuition:**
# PCA finds new orthogonal axes (principal components) in the feature space that capture the maximum variance in the data. The first principal component explains the largest possible variance, the second the next largest (uncorrelated to the first), and so on.
#
# - **Mathematically:** PCA performs an eigen-decomposition of the covariance matrix of the data.
# - The eigenvectors correspond to principal components, and eigenvalues indicate the variance explained by each component.
# - By selecting the top **k** components that explain a desired percentage (e.g., 95%) of variance, we reduce dimensionality while retaining most information.
#
# You can skip the math if you want, but understanding that PCA compresses your data by capturing the main patterns is key.
#
# Here it comes the maths that you can completely skip:

# %% [markdown]
# <details>
# <summary><b>Mathematical formulation (click to if you are interested in the math behind!)</b></summary>
#
#
# PCA goal is to obtain a new, reduced  set of $K<D$ orthogonal variables, the so-called principal components. The principal components are linear combinations of the input variables, but sorted in decreasing order of variance.
#
# <img src="http://www.tsc.uc3m.es/~vanessa/Figs_notebooks/ML/PCA/PCA_1.png" width="40%" >
#
# In matrix notation, the purpose of PCA can be written as finding a projection matrix ${\bf U}$ and transform the $D\times N$ data matrix ${\bf X}$ into the $K \times N$ matrix ${\bf X'}$:
#
# $$ {\bf X'} = {\bf U}^\top {\bf X}^\top$$
#
# Each column of the matrix ${\bf U}$ is a **principal component**, and it will provide a new dimension of the data in the projected space: the principal components act as a vector basis in the projected space.
#
# PCA is **unsupervised**, one does not need targets to compute PCA!!
#
#
# The PCA algorithm finds the components that maximize the variance contained in the data in a **recursive** way:
# * Find the first principal component, ${\bf u}_1$, that maximizes the variance of the mapped data:  ${\bf u}_1^\top {\bf x} $ is of maximum variance.
#
# * Deflate the first principal component from the data ${\bf x^1} = {\bf x} - {\bf u}_1^\top {\bf x} {\bf u}_1$.
#
# * Next, find ${\bf u}_2$ so that ${\bf u}_2^\top {\bf x^1} $ is of maximum variance
#
# * Repeat the deflation of the new principal component from the data and the determination of the projection $\bf u_j$that maximizes the variance of the residual $\bf x^{j-1}$ until obtaining the desired $K < D$ principal components.
#
# $$ {\bf U} = \underset{\bf U} {\mathrm{argmax}} ~{\rm Tr} \left\lbrace {\bf U}^T {\bf X}^T {\bf X} {\bf U}\right\rbrace  = \underset{\bf U} {\mathrm{argmax}} ~{\rm Tr}\left\lbrace {\bf U}^T {\bf C_{XX}} {\bf U}\right\rbrace $$
# $$ {\rm s.t.} ~~{\bf U}^T {\bf U}={\bf I}$$

# %% [markdown]
# ### Partial Least Squares Discriminant Analysis (PLS-DA)
#
# **Intuition:**
# PLS-DA is a supervised dimensionality reduction technique. Unlike PCA, which looks only at the data features, PLS-DA also considers the outcome labels (e.g., species class) while projecting data onto latent components.
#
# - It finds components that maximize covariance between predictors (spectra) and response variables (class labels).
# - This makes PLS-DA particularly useful for classification tasks, as it seeks directions that best separate classes.
#
# <img align="right" src="http://www.tsc.uc3m.es/~vanessa/Figs_notebooks/ML/PCA/PLS.png" width="30%" >
#
#
# **Goal**: Find the projections of the input and output data with maximum covariance:
#
# $$ \begin{array}{rl}{\bf U, V} = &  \underset{\bf U, V} {\mathrm{argmax}} ~{\rm Tr} \left\lbrace{\bf U}^T {\bf X}^T {\bf Y} {\bf V} \right\rbrace \\
# = & \underset{\bf U, V} {\mathrm{argmax}} ~{\rm Tr} \left\lbrace {\bf U}^T{\bf C_{XY}} {\bf V} \right\rbrace\\
# & {\rm s.t.} ~~{\bf U}^T{\bf U}= {\bf V}^T{\bf V}={\bf I}
# \end{array}$$
# Which leads to
# $$ {\bf U},{\bf V} = {\rm svd}({\bf C_{XY}}) $$
#
# The maximum number of projections is limited by the number of output classes minus one.
#
#
# ---
#
#
# PCA and PLS-DA are **both dimensionality reduction methods**, but they have different goals and ways of working:
#
# - PCA looks only at the input data (e.g., **MALDI-TOF spectra**) and finds new axes (principal components) that capture the **most variation in the data without considering any extra information** about the bacterial species or sample labels. **It’s an unsupervised method**. This helps visualize overall patterns and variance but may not separate bacterial groups clearly if those groups don’t correspond exactly to the biggest sources of variation.
#
# - PLS-DA, on the other hand, **is a supervised method.** It uses the species labels during the dimensionality reduction to find **components that maximize the separation between bacterial groups**. Instead of just capturing variance, PLS-DA finds directions in the data that are most relevant to distinguishing species.
#
# In simple terms:
#
# * PCA shows you how your samples vary overall, good for exploring the data structure without any prior knowledge.
#
# * PLS-DA shows you how your samples differ based on known groups (species), making it more powerful for classification and biomarker discovery.
#
# So, if your goal is to visualize or discover overall patterns, PCA is great. But if you want to focus on differences that matter biologically — like identifying species-specific signals — PLS-DA often gives clearer, more interpretable results.

# %% [markdown]
# # Practical Implementation
#
# We will:
#
# 1. Apply PCA to reduce the dimensionality of MALDI-TOF spectra to:
#    - The number of components explaining **95% of the variance**
#    - A fixed **3 components** for easy 3D visualization
#
# 2. Visualize the data in 3D PCA space with species colored
#
# 3. Train and compare a **Random Forest classifier** on:
#    - Raw preprocessed spectra
#    - PCA-reduced spectra (95% variance)
#    - PCA with 3 components
#    - PLS-DA transformed data
#
# This will show the trade-offs between dimensionality reduction and classification performance.
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.cross_decomposition import PLSRegression
import plotly.express as px
import pandas as pd

# Prepare numpy arrays from spectra list of SpectrumObjects (assuming .intensity attribute)
X_train = np.vstack([s.intensity for s in spectra_train])
X_val = np.vstack([s.intensity for s in spectra_val])
X_test = np.vstack([s.intensity for s in spectra_test])

# Encode species labels to integers
le = LabelEncoder()
y_train = le.fit_transform(metadata_train['species'])
y_val = le.transform(metadata_val['species'])
y_test = le.transform(metadata_test['species'])

# 1. PCA dimensionality reduction
# a) PCA explaining 95% variance
pca_95 = PCA(n_components=0.95, svd_solver='full', random_state=42)
X_train_pca95 = pca_95.fit_transform(X_train)
X_val_pca95 = pca_95.transform(X_val)
X_test_pca95 = pca_95.transform(X_test)
print(f"PCA 95% variance number of components: {pca_95.n_components_}")

# b) PCA fixed to 3 components for visualization
pca_3 = PCA(n_components=3, random_state=42)
X_train_pca3 = pca_3.fit_transform(X_train)
X_val_pca3 = pca_3.transform(X_val)
X_test_pca3 = pca_3.transform(X_test)
# Out:
# PCA 95% variance number of components: 221

# %%
# 2. 3D Visualization of PCA with 3 components


# Prepare a DataFrame for Plotly
df_pca3 = pd.DataFrame({
    'PC1': X_train_pca3[:, 0],
    'PC2': X_train_pca3[:, 1],
    'PC3': X_train_pca3[:, 2],
    'species': metadata_train['species']
})

# Create 3D scatter plot with Plotly Express
fig = px.scatter_3d(
    df_pca3,
    x='PC1', y='PC2', z='PC3',
    color='species',
    title='3D PCA of Training Spectra',
    opacity=0.7,
    width=800,
    height=600,
    labels={'PC1': 'PC1', 'PC2': 'PC2', 'PC3': 'PC3'}
)

# Customize layout for better interactivity
fig.update_traces(marker=dict(size=5))
fig.update_layout(
    legend_title_text='Species',
    legend=dict(itemsizing='constant')
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1e9d9b2b-39e5-47ed-8542-1c718b9c4568" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e9d9b2b-39e5-47ed-8542-1c718b9c4568")) {                    Plotly.newPlot(                        "1e9d9b2b-39e5-47ed-8542-1c718b9c4568",                        [{"hovertemplate":"species=Enterococcus faecalis\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enterococcus faecalis","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle","size":5},"mode":"markers","name":"Enterococcus faecalis","scene":"scene","showlegend":true,"x":[-0.005235265576319297,-0.003892273977690221,-0.0048478634966318615,0.0002587289390974001,-0.0032876475965253893,-0.0029495238871812403,-0.004051089062698196,-0.003178809750741191,-0.004278713908548813,-0.004505395134095522,-0.004854340039814297,-0.0037522342118552513,-0.004523612514652607,-0.0049605803921277305,-0.00424800377839293,-0.004228871148773521,-0.005169283606098004,-0.004380539660679975,-0.004439367077381752,-0.005217996160882977,-0.003998184707769001,-0.005096674770022423,-0.004044296536714413,-0.004439388082243872,-0.005159988865807372,-0.003633989323127961,-0.004329479865118259,-0.004754087794092316,-0.007248138140532876,-0.00392055538108746,-0.0038481488613242563,-0.005096939428932184,-0.0041475587455693744,-0.0027775316272136,-0.002976777030975186,-0.005174674997129609,-0.004885278888039524,-0.004329732330208984,-0.004292113277283195,-0.005076856105531328,-0.004255958330562118,-0.0046683982827879075,-0.000918289552912548,-0.004520913852084663,-0.0020755335923182184,-0.005422548317896203,-0.003953221201349412,-0.004558982051466209,-0.003978326044370676,-0.003251154583239437,-0.0027955027785096028,-0.004387191965747837,-0.004809132210352988,-0.0039273087206829396,-0.005542366026920935,-0.003495026022385324,-0.0051180534554543045,-0.005541333973451575,-0.0032668848262250743,-0.004248861939689656,-0.004736384837671029,-0.00464379455031209,-0.005084673715690112,-0.0035726111428722495,-0.006134020262684312,-0.004445352276169329,-0.004145418470589876,-0.004961985264366322,-0.004086989871646246,-0.004496181510595237,-0.004885650753827038,-0.005134729996287995,-0.004827456612641298,-0.0042295727485312466,-0.004241512096723708,-0.0021332231385079677,-0.005523524986145339,-0.002967587655766712,-0.00424222902134871,-0.004920263315344359,-0.004554087746704575,-0.0023833150654410658,-0.004217896453050689,-0.005287887913260527,-0.004202521383712892,-0.004800354694340464,-0.0037449337964024104,-0.00044693471337705655,-0.004476490233719643,-0.005544272567355196,-0.004653387573999391,-0.005001914887729949,-0.0034535271753589358,-0.0009138009262981059,-0.00411887148644412,-0.005264572244754864,-0.004073119066793463,-0.003722163664721569,-0.004824389796040208,-0.004961297009128058,-0.006011398811572577,-0.00194116576818932,-0.004011088508870835,-0.0019146268279343537,-0.004367645390395983,-0.005598939587999001,-0.004977713534543092,-0.005240437842994681,-0.004913676533596414,-0.00497526025592549,-0.004095293540266424,-0.004778279080108112,-0.0016192210843171864,-0.0030699239785201395,-0.005395053147564123,-0.004883910238857399,-0.0038957159492779936,-0.0038692754328263595,-0.004287214441708757,-0.005090406203498098,-0.0036952794944990117,-0.003114613968195336,-0.0044938021067407515,-0.0031066469050363503,-0.00463053074776593,-0.0021424602891793516,-0.0042022371785698405,-0.0045785701421960645,-0.004950849289489924,-0.004048790415458305,-0.001011197183912613,-0.004382032663442767,-0.003366219817930271,-0.005522852493657941,-0.0042706231606979275,-0.003772481070057336,-0.004891879133657557,-0.005157317019001151,-0.0038931518872250322,-0 ...

# %%
# 3. PLS-DA dimensionality reduction
# We use PLSRegression with number of components = 3
pls = PLSRegression(n_components=3)

# TODO: remove this also in the student versions
pls.fit(X_train, y_train)
X_train_pls = pls.transform(X_train)
X_val_pls = pls.transform(X_val)
X_test_pls = pls.transform(X_test)


import pandas as pd
import plotly.express as px

# Prepare DataFrame for Plotly 3D PLS-DA plot
df_train_pls = pd.DataFrame({
    'PLS1': X_train_pls[:, 0],
    'PLS2': X_train_pls[:, 1],
    'PLS3': X_train_pls[:, 2],
    'Species': metadata_train['species']  # Assuming this matches X_train indices
})

# Create interactive 3D scatter plot using Plotly
fig = px.scatter_3d(
    df_train_pls,
    x='PLS1', y='PLS2', z='PLS3',
    color='Species',
    title='3D PLS-DA of Training Spectra',
    opacity=0.7,
    width=800,
    height=600,
    labels={'PLS1': 'PLS Component 1', 'PLS2': 'PLS Component 2', 'PLS3': 'PLS Component 3'}
)

fig.update_traces(marker=dict(size=5))
fig.update_layout(legend_title_text='Species')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="af0c7fe6-58c8-4210-a07c-064545c6745c" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af0c7fe6-58c8-4210-a07c-064545c6745c")) {                    Plotly.newPlot(                        "af0c7fe6-58c8-4210-a07c-064545c6745c",                        [{"hovertemplate":"Species=Enterococcus faecalis\u003cbr\u003ePLS Component 1=%{x}\u003cbr\u003ePLS Component 2=%{y}\u003cbr\u003ePLS Component 3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enterococcus faecalis","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle","size":5},"mode":"markers","name":"Enterococcus faecalis","scene":"scene","showlegend":true,"x":[-2.2510831035676326,-3.6140239784215282,-2.1588209462468844,-11.195368408364903,-6.467097883949362,-12.897624535709921,-5.224225641901753,-8.991334950791899,-4.41402212045266,-5.304211871640305,-5.8101282593676915,-3.328238748607481,-3.6457615613071184,-8.747013207715742,-5.377245019416995,-1.3853381340181279,-3.0250600576299465,-6.787712050871486,-5.764676014663134,-4.764862525666527,-4.9415826299492185,-4.2950910066173495,-2.0393655918862863,-5.45749087634251,-0.061139614562054856,-2.3850690916624737,-3.171388715072327,-7.334448886707682,-1.3831407359102716,-7.092264582519724,-8.065861614244575,-3.681791956370983,-9.31358202514223,-7.541334985264911,-5.884616516369299,-6.494743477602158,-7.5739972177301365,-7.2480405342437875,-4.547419747093289,-3.166342933802429,-5.299012102198534,-5.279572551997324,-6.761045255741655,-5.3774745116375335,-13.890572567088743,-1.0660176831857142,-6.4094744702690765,-1.2596186580358548,-4.126296118609928,-4.059408942177682,-9.593994083603526,-9.361737308935053,-4.330107012480897,-6.463455244370738,-2.8414107975192358,-10.05620687206716,-7.767556046799071,-4.302076726215941,-4.1723129306614295,-8.941257565882795,-0.44194504980729865,-3.6688851703167003,-7.99094856586158,-2.4938016151052134,-0.3541296909782294,-6.07810077835042,-3.7860530786178757,-0.16094441076270366,-3.662233116819287,-7.422179147294736,0.336935396640418,-6.262326822387069,-2.861603131109312,-4.9226954249873085,-4.083653525025432,-0.9780832885951534,-5.5881002777367375,-9.705033653583016,1.7782673259745152,-1.1240761218796007,1.29348030476026,-11.761422477284059,-2.444823888763202,-4.9009527028035516,-3.6940462286329034,-3.9007166674620226,-4.699850308725723,-5.224240222961541,-3.843741961935944,-6.665195161046428,-2.7930094143199677,-4.619368662142845,-6.526192094734104,-6.41656983933594,-8.478233450131135,-7.043562348545201,-4.7321511691510665,-2.6911203227438754,-5.064049792414484,-0.5942867642812614,-2.331883688774003,-12.659300019980344,-3.3501266147718027,-14.390679627589707,-5.005664789533494,-2.837118531236283,-2.359767724647566,-4.548557633612777,0.4553421142639263,-6.743740048032405,-0.0772995236502424,-2.232077470051371,-9.875874282647418,-9.220218409132801,-6.172220928761428,-5.860901535505137,-3.617536418718809,-6.8269949612945995,-5.179047679401737,-6.517744429852578,-9.869370067245281,-5.418247199617541,-6.527762180921855,-8.041102272143092,-2.692011939162287,-6.6742669837153725,-4.984132454017233,-5.767779605211173,-4.231747134538046,-6.3403309513558535,-15.207843838818798,-3.5903379853705193,-3.6906130082571567,-0.46938750082925507,-11.414136654852967,-8.082004077623239,-9.134801861689738,-3.2180597617295867,-5.606937006509068,-2.1401591473207175,-4.266883521241237,-6.729952842666715,-5.774401225461406,-5.387019447355774,-2.1303241611662833,0.6342751122948412,-1.6646863441153605,-7.124681409865752,-2.282822074188675,-4.922241268298732,-3.8020804406447875,-2.9123101719205056,-8.202973219749412,-5.59411700042968,-12.129732820111226,-4.566722918468142,-5.99759454923996,-5.49404818 ...

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np

def train_evaluate_rf_roc(X_train, y_train, X_val, y_val, description="", top_n=5):
    clf = RandomForestClassifier(n_estimators=100, random_state=42)
    clf.fit(X_train, y_train)

    # Predict probabilities for ROC
    y_proba = clf.predict_proba(X_val)

    # Compute ROC-AUC with 'ovr' average (one-vs-rest) for multiclass
    roc_auc = roc_auc_score(y_val, y_proba, multi_class='ovr', average='weighted')
    print(f"Random Forest ROC-AUC on validation set ({description}): {roc_auc:.4f}")

    # Identify top_n most common classes in y_val for plotting
    unique, counts = np.unique(y_val, return_counts=True)
    top_classes_idx = unique[np.argsort(counts)[-top_n:]][::-1]  # top N by frequency descending
    top_classes_names = [le.classes_[i] for i in top_classes_idx]

    # Plot ROC curves for top_n classes
    plt.figure(figsize=(8, 6))
    colors = plt.cm.get_cmap('tab10', top_n)

    for i, class_idx in enumerate(top_classes_idx):
        # Binarize y_val for current class
        y_val_bin = (y_val == class_idx).astype(int)
        y_score = y_proba[:, class_idx]

        fpr, tpr, _ = roc_curve(y_val_bin, y_score)
        roc_auc_class = auc(fpr, tpr)

        plt.plot(fpr, tpr, color=colors(i),
                 label=f"{top_classes_names[i]} (AUC = {roc_auc_class:.2f})")

    plt.plot([0, 1], [0, 1], 'k--', lw=1)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curves for Top {top_n} Species ({description})')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

    return roc_auc

print("\nTraining Random Forest classifiers on different data representations:\n")

acc_raw = train_evaluate_rf_roc(X_train, y_train, X_val, y_val, "Raw preprocessed spectra")
acc_pca95 = train_evaluate_rf_roc(X_train_pca95, y_train, X_val_pca95, y_val, "PCA (95% variance)")
acc_pca3 = train_evaluate_rf_roc(X_train_pca3, y_train, X_val_pca3, y_val, "PCA (3 components)")
acc_pls = train_evaluate_rf_roc(X_train_pls, y_train, X_val_pls, y_val, "PLS-DA (3 components)")

# %% [markdown]
# # Comparing 3D Visualizations: PCA vs t-SNE vs UMAP vs PLS-DA
#
# Before applying dimensionality reduction for classification, it is helpful to explore how different techniques represent the data in 3D space. Visualization allows us to intuitively assess how well the data separates by species and reveals underlying structure.
#
# In this section, we will apply four common dimensionality reduction methods to the **training set** spectra:
#
# - **PCA (3 components)** — a linear method preserving maximum variance
# - **t-SNE (3 components)** — a nonlinear method optimized for local neighborhood preservation
# - **UMAP (3 components)** — a nonlinear method balancing local and global structure preservation
# - **PLS-DA (3 components)** — a supervised linear method maximizing covariance with species labels
#
# For each method, we will create an **interactive 3D scatter plot using Plotly**, coloring points by bacterial species. This interactive visualization enables zooming, rotating, and toggling species visibility to better understand clustering patterns.

# %%
import plotly.express as px
import pandas as pd

# Helper function to create plotly 3D scatter plot
def plot_3d_interactive(X, species_labels, title):
    df = pd.DataFrame({
        'Dim1': X[:, 0],
        'Dim2': X[:, 1],
        'Dim3': X[:, 2],
        'Species': species_labels
    })
    fig = px.scatter_3d(
        df,
        x='Dim1', y='Dim2', z='Dim3',
        color='Species',
        title=title,
        opacity=0.7,
        width=800,
        height=600,
        labels={'Dim1': 'Component 1', 'Dim2': 'Component 2', 'Dim3': 'Component 3'}
    )
    fig.update_traces(marker=dict(size=5))
    fig.update_layout(legend_title_text='Species')
    fig.show()

# PCA 3 components (already computed as X_train_pca3)
plot_3d_interactive(X_train_pca3, metadata_train['species'], '3D PCA of Training Spectra')

# t-SNE 3 components (compute now)
from sklearn.manifold import TSNE
tsne = TSNE(n_components=3, random_state=42, perplexity=30, max_iter=1000)
X_train_tsne3 = tsne.fit_transform(X_train)
plot_3d_interactive(X_train_tsne3, metadata_train['species'], '3D t-SNE of Training Spectra')

# UMAP 3 components (compute now)
import umap
umap_model = umap.UMAP(n_components=3, random_state=42)
X_train_umap3 = umap_model.fit_transform(X_train)
plot_3d_interactive(X_train_umap3, metadata_train['species'], '3D UMAP of Training Spectra')

# PLS-DA 3 components (already computed as X_train_pls)
plot_3d_interactive(X_train_pls, metadata_train['species'], '3D PLS-DA of Training Spectra')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a6728ae0-93dd-44ee-b8ec-b598c53df9e4" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6728ae0-93dd-44ee-b8ec-b598c53df9e4")) {                    Plotly.newPlot(                        "a6728ae0-93dd-44ee-b8ec-b598c53df9e4",                        [{"hovertemplate":"Species=Enterococcus faecalis\u003cbr\u003eComponent 1=%{x}\u003cbr\u003eComponent 2=%{y}\u003cbr\u003eComponent 3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enterococcus faecalis","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle","size":5},"mode":"markers","name":"Enterococcus faecalis","scene":"scene","showlegend":true,"x":[-0.005235265576319297,-0.003892273977690221,-0.0048478634966318615,0.0002587289390974001,-0.0032876475965253893,-0.0029495238871812403,-0.004051089062698196,-0.003178809750741191,-0.004278713908548813,-0.004505395134095522,-0.004854340039814297,-0.0037522342118552513,-0.004523612514652607,-0.0049605803921277305,-0.00424800377839293,-0.004228871148773521,-0.005169283606098004,-0.004380539660679975,-0.004439367077381752,-0.005217996160882977,-0.003998184707769001,-0.005096674770022423,-0.004044296536714413,-0.004439388082243872,-0.005159988865807372,-0.003633989323127961,-0.004329479865118259,-0.004754087794092316,-0.007248138140532876,-0.00392055538108746,-0.0038481488613242563,-0.005096939428932184,-0.0041475587455693744,-0.0027775316272136,-0.002976777030975186,-0.005174674997129609,-0.004885278888039524,-0.004329732330208984,-0.004292113277283195,-0.005076856105531328,-0.004255958330562118,-0.0046683982827879075,-0.000918289552912548,-0.004520913852084663,-0.0020755335923182184,-0.005422548317896203,-0.003953221201349412,-0.004558982051466209,-0.003978326044370676,-0.003251154583239437,-0.0027955027785096028,-0.004387191965747837,-0.004809132210352988,-0.0039273087206829396,-0.005542366026920935,-0.003495026022385324,-0.0051180534554543045,-0.005541333973451575,-0.0032668848262250743,-0.004248861939689656,-0.004736384837671029,-0.00464379455031209,-0.005084673715690112,-0.0035726111428722495,-0.006134020262684312,-0.004445352276169329,-0.004145418470589876,-0.004961985264366322,-0.004086989871646246,-0.004496181510595237,-0.004885650753827038,-0.005134729996287995,-0.004827456612641298,-0.0042295727485312466,-0.004241512096723708,-0.0021332231385079677,-0.005523524986145339,-0.002967587655766712,-0.00424222902134871,-0.004920263315344359,-0.004554087746704575,-0.0023833150654410658,-0.004217896453050689,-0.005287887913260527,-0.004202521383712892,-0.004800354694340464,-0.0037449337964024104,-0.00044693471337705655,-0.004476490233719643,-0.005544272567355196,-0.004653387573999391,-0.005001914887729949,-0.0034535271753589358,-0.0009138009262981059,-0.00411887148644412,-0.005264572244754864,-0.004073119066793463,-0.003722163664721569,-0.004824389796040208,-0.004961297009128058,-0.006011398811572577,-0.00194116576818932,-0.004011088508870835,-0.0019146268279343537,-0.004367645390395983,-0.005598939587999001,-0.004977713534543092,-0.005240437842994681,-0.004913676533596414,-0.00497526025592549,-0.004095293540266424,-0.004778279080108112,-0.0016192210843171864,-0.0030699239785201395,-0.005395053147564123,-0.004883910238857399,-0.0038957159492779936,-0.0038692754328263595,-0.004287214441708757,-0.005090406203498098,-0.0036952794944990117,-0.003114613968195336,-0.0044938021067407515,-0.0031066469050363503,-0.00463053074776593,-0.0021424602891793516,-0.0042022371785698405,-0.0045785701421960645,-0.004950849289489924,-0.004048790415458305,-0.001011197183912613,-0.004382032663442767,-0.003366219817930271,-0.005522852493657941,-0.0042706231606979275,-0.003772481070057336,-0.004891879133657557,-0.005157317019001151,- ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9364f096-213d-4a83-9a72-ecb1950e52dc" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9364f096-213d-4a83-9a72-ecb1950e52dc")) {                    Plotly.newPlot(                        "9364f096-213d-4a83-9a72-ecb1950e52dc",                        [{"hovertemplate":"Species=Enterococcus faecalis\u003cbr\u003eComponent 1=%{x}\u003cbr\u003eComponent 2=%{y}\u003cbr\u003eComponent 3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enterococcus faecalis","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle","size":5},"mode":"markers","name":"Enterococcus faecalis","scene":"scene","showlegend":true,"x":[3.903863,-1.7830113,4.6791916,-0.19105683,1.9828422,-0.38601598,3.21549,-1.9348032,-3.0585668,-3.2220862,3.44203,-1.4365035,-3.7546415,-2.0043464,-1.438011,4.5353084,-2.8792214,-4.7256837,-1.577883,2.2259963,2.8886132,-2.3488445,2.9993784,-2.128349,4.9062505,2.1967363,2.1198575,3.101482,1.718802,0.62852705,1.4265721,-3.5929437,-0.47406355,-2.1714115,-2.922944,-1.6817768,-3.64909,1.2903515,-2.1591713,5.3735085,4.281205,-0.30468532,2.183145,-3.5212662,-2.8341498,-4.1890616,-1.9105197,-0.6182248,3.5249515,-4.4318275,-0.8883892,4.5488067,-2.9583135,2.8625891,-3.9799614,-2.7220635,-3.6777716,0.2183566,1.4795735,-3.4353094,3.9115844,-1.4234854,1.4605566,2.7272878,2.5652685,-0.6336351,-1.8827271,4.792722,-1.8708622,2.7619777,1.1523892,-1.9390413,4.47535,-4.757409,-0.70103735,2.7557385,-2.9332745,-4.5870013,1.017324,4.1387715,4.6198297,-0.72060525,3.0253134,1.9341273,-3.4493003,-1.9640493,1.5939564,-0.6686393,-0.21262082,-4.6072817,-1.857659,-2.908719,1.793151,2.1801581,4.1819363,-0.9074938,3.5692725,-3.7794974,3.7176886,-4.0445414,-2.0515065,-1.1469822,-3.8946738,-1.1260356,-3.4147341,2.127783,2.9035544,1.9555839,0.95496994,4.0456753,2.792489,-3.725421,-0.107867025,3.653059,4.9413786,-2.7299514,4.1300535,-2.5411656,-2.9015071,-2.4053497,-0.46517834,2.8703196,3.2688541,1.4386325,2.6528196,2.1085935,-0.80784744,0.22555555,-1.3475051,-3.0895767,1.975448,-2.9170077,3.9741273,1.4884814,-2.6937315,-2.0565004,-2.991804,-2.5398922,-1.624557,-5.131738,4.9573703,-4.4098763,-3.1341043,1.3048092,5.245549,2.6495237,-2.3193333,2.7782712,-0.31789833,3.4243891,-1.8178209,3.087191,-4.071064,-3.1882384,-2.0000653,0.55090976,-1.3709337,3.0650616,3.5112312,3.3908443,3.302785,1.6756617,-2.9456122,3.6693704,0.34309164,4.701456,1.1830153,5.0804214,2.184729,3.0746338,-1.1486976,4.492663,2.2800512,0.693203,-2.347363,2.2719615,3.1488445,-1.5218538,-0.15997869,-0.342213,0.96563286,4.592613,2.7892787],"y":[-16.243574,-13.400787,-12.149556,-11.2226095,-11.605272,-10.739226,-11.628708,-12.998527,-14.503882,-16.562271,-12.903445,-13.891429,-14.278312,-18.21875,-16.05088,-12.1934595,-13.776293,-15.054804,-16.428513,-14.329344,-10.580877,-15.948275,-13.583887,-13.827521,-14.459957,-12.179726,-15.2697315,-14.122559,-16.037537,-12.244856,-14.939539,-15.426075,-12.916589,-12.806336,-18.129894,-16.124126,-16.535093,-14.42763,-13.192552,-11.989458,-12.165676,-13.875081,-8.632649,-15.43946,-11.973346,-12.959048,-12.74877,-16.198435,-12.338973,-14.271143,-11.806424,-11.122417,-16.021065,-13.148205,-12.995556,-12.754427,-16.363348,-15.636603,-14.875236,-14.064193,-15.25381,-13.870989,-14.294021,-11.690485,-14.882091,-13.4759445,-14.780383,-12.1849375,-12.828713,-13.1184635,-17.771961,-17.899845,-12.782153,-13.320832,-13.4244175,-9.96768,-17.073774,-13.112937,-17.68554,-12.360363,-14.725528,-11.992625,-12.39668,-14.933163,-14.802581,-14.308401,-13.90351,-14.543468,-16.434437,-15.502946,-15.061155,-15.14115,-12.429048,-8.60758,-12.76714,-16.259722,-13.512474,-14.329792,-15.543931,-17.539179,-18.185343,-11.842056,-15.803458,-11.860743,-15.371786,-14.248711 ...
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0ce1c8c6-e5e4-4325-980c-50eb753a28ba" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ce1c8c6-e5e4-4325-980c-50eb753a28ba")) {                    Plotly.newPlot(                        "0ce1c8c6-e5e4-4325-980c-50eb753a28ba",                        [{"hovertemplate":"Species=Enterococcus faecalis\u003cbr\u003eComponent 1=%{x}\u003cbr\u003eComponent 2=%{y}\u003cbr\u003eComponent 3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enterococcus faecalis","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle","size":5},"mode":"markers","name":"Enterococcus faecalis","scene":"scene","showlegend":true,"x":[-1.8476661,-2.3270266,-1.4070661,-2.0475295,-1.7648408,-2.0501409,-1.4676485,-2.3176286,-2.5059223,-2.5950236,-1.4601314,-2.35723,-2.4948266,-2.2392967,-2.267683,-1.3966291,-2.4371533,-2.5266573,-2.3570318,-1.6832657,-1.6657614,-2.4028232,-1.5224304,-2.4108026,-1.8232455,-1.4269999,-1.756786,-1.5467346,-1.7849786,-2.0651414,-1.8448952,-2.5730054,-2.1614375,-2.3164742,-2.5208044,-2.375569,-2.6114335,-1.7819864,-2.3030658,-1.370997,-1.4332224,-2.1174192,-1.7805448,-2.5408287,-2.3116636,-2.3819025,-2.151241,-2.271903,-1.640476,-2.5007277,-2.0706928,-1.4532158,-2.5876849,-1.4805037,-2.25872,-2.2911325,-2.62157,-1.5909363,-1.8481903,-2.447156,-1.9200379,-2.2821386,-1.8213508,-1.6506723,-1.701073,-2.223079,-2.5126865,-1.3644394,-2.2229705,-1.5368567,-2.3648674,-2.5281894,-1.2820576,-2.4505837,-2.2150104,-1.6992742,-2.5534022,-2.4507172,-2.3357031,-1.4354616,-1.87227,-2.1521368,-1.6311151,-1.7601421,-2.4820418,-2.4807117,-1.7419778,-2.2673614,-2.312164,-2.5721414,-2.465752,-2.5428736,-1.501564,-1.754974,-1.5092784,-2.4474423,-1.7061534,-2.4605117,-1.9089597,-2.6086771,-2.5121942,-2.3544104,-2.4760876,-2.2524128,-2.549527,-1.6980654,-1.6904513,-1.6414772,-2.3198855,-1.5081877,-1.6319171,-2.6082737,-1.8430966,-1.579882,-1.4363651,-2.6161554,-1.4297456,-2.4198565,-2.5641403,-2.4648368,-2.2864757,-1.6289287,-1.4366429,-1.7774913,-2.0719242,-1.7233582,-2.1322322,-1.4820361,-2.2663255,-2.498812,-1.8081176,-2.483036,-1.8914287,-2.2975059,-2.4972408,-2.2910504,-2.5125675,-2.5073757,-2.2386215,-2.4861946,-1.4530448,-2.549354,-2.5397487,-1.856431,-1.6212643,-1.6224701,-2.4264455,-1.6937908,-2.2124755,-1.5830345,-2.1845791,-1.7539594,-2.4676607,-2.5493977,-2.13213,-1.953579,-2.2259202,-1.5241143,-1.565701,-1.4689778,-1.560045,-1.6557099,-2.505619,-1.5390221,-2.3292615,-1.3384562,-1.799643,-1.8101788,-1.7686689,-1.7690994,-2.2446847,-1.4353672,-1.7344371,-1.9932643,-2.5447252,-1.4948803,-1.9387038,-2.3131647,-1.9036372,-2.162758,-2.0106246,-1.4221925,-1.6703023],"y":[6.343133,5.487284,6.4235954,5.6686287,6.172856,5.727894,6.1902404,5.44321,5.427329,5.784426,6.2048063,5.3863554,5.4179626,5.9702854,6.000261,6.4246616,5.6164303,5.46173,5.995417,6.435539,6.27758,5.945089,6.250774,5.556845,6.4590087,6.159505,6.433622,6.1812057,6.414096,6.0059896,6.035159,5.7122154,5.673613,5.4093356,5.886553,5.982038,5.7828293,6.13643,5.448925,6.4005904,6.3976364,6.1467752,6.1304207,5.7846313,5.4173083,5.631901,5.9143076,5.912985,6.3410482,5.4038825,5.514784,6.420334,5.70144,6.2279587,5.7185335,5.4237065,5.7539864,6.06458,6.0609593,5.494277,6.458867,5.5061584,6.2405496,6.22427,6.3681655,5.7019067,5.5767937,6.4368973,5.786499,6.2198935,6.238587,5.798337,6.5230775,5.4040728,5.7354193,6.233507,5.875475,5.29111,6.2057595,6.3850403,6.5042634,5.5929594,6.297983,6.423361,5.645685,5.5805297,6.2470646,5.694368,6.0798154,5.758611,5.5845504,5.693326,6.1632714,6.1562796,6.173806,5.879057,6.4153647,5.3849664,6.3522453,5.8075356,5.8537674,5.349254,5.821754,5.386189,5.6422296,6.4397445,6.3813987,6.533207,6.21948,6.1699767,6.282738,5.7603154,5.8796167,6.335914,6 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="da41f3a1-8a65-45c6-aba7-2bd558de7654" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da41f3a1-8a65-45c6-aba7-2bd558de7654")) {                    Plotly.newPlot(                        "da41f3a1-8a65-45c6-aba7-2bd558de7654",                        [{"hovertemplate":"Species=Enterococcus faecalis\u003cbr\u003eComponent 1=%{x}\u003cbr\u003eComponent 2=%{y}\u003cbr\u003eComponent 3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enterococcus faecalis","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle","size":5},"mode":"markers","name":"Enterococcus faecalis","scene":"scene","showlegend":true,"x":[-2.2510831035676326,-3.6140239784215282,-2.1588209462468844,-11.195368408364903,-6.467097883949362,-12.897624535709921,-5.224225641901753,-8.991334950791899,-4.41402212045266,-5.304211871640305,-5.8101282593676915,-3.328238748607481,-3.6457615613071184,-8.747013207715742,-5.377245019416995,-1.3853381340181279,-3.0250600576299465,-6.787712050871486,-5.764676014663134,-4.764862525666527,-4.9415826299492185,-4.2950910066173495,-2.0393655918862863,-5.45749087634251,-0.061139614562054856,-2.3850690916624737,-3.171388715072327,-7.334448886707682,-1.3831407359102716,-7.092264582519724,-8.065861614244575,-3.681791956370983,-9.31358202514223,-7.541334985264911,-5.884616516369299,-6.494743477602158,-7.5739972177301365,-7.2480405342437875,-4.547419747093289,-3.166342933802429,-5.299012102198534,-5.279572551997324,-6.761045255741655,-5.3774745116375335,-13.890572567088743,-1.0660176831857142,-6.4094744702690765,-1.2596186580358548,-4.126296118609928,-4.059408942177682,-9.593994083603526,-9.361737308935053,-4.330107012480897,-6.463455244370738,-2.8414107975192358,-10.05620687206716,-7.767556046799071,-4.302076726215941,-4.1723129306614295,-8.941257565882795,-0.44194504980729865,-3.6688851703167003,-7.99094856586158,-2.4938016151052134,-0.3541296909782294,-6.07810077835042,-3.7860530786178757,-0.16094441076270366,-3.662233116819287,-7.422179147294736,0.336935396640418,-6.262326822387069,-2.861603131109312,-4.9226954249873085,-4.083653525025432,-0.9780832885951534,-5.5881002777367375,-9.705033653583016,1.7782673259745152,-1.1240761218796007,1.29348030476026,-11.761422477284059,-2.444823888763202,-4.9009527028035516,-3.6940462286329034,-3.9007166674620226,-4.699850308725723,-5.224240222961541,-3.843741961935944,-6.665195161046428,-2.7930094143199677,-4.619368662142845,-6.526192094734104,-6.41656983933594,-8.478233450131135,-7.043562348545201,-4.7321511691510665,-2.6911203227438754,-5.064049792414484,-0.5942867642812614,-2.331883688774003,-12.659300019980344,-3.3501266147718027,-14.390679627589707,-5.005664789533494,-2.837118531236283,-2.359767724647566,-4.548557633612777,0.4553421142639263,-6.743740048032405,-0.0772995236502424,-2.232077470051371,-9.875874282647418,-9.220218409132801,-6.172220928761428,-5.860901535505137,-3.617536418718809,-6.8269949612945995,-5.179047679401737,-6.517744429852578,-9.869370067245281,-5.418247199617541,-6.527762180921855,-8.041102272143092,-2.692011939162287,-6.6742669837153725,-4.984132454017233,-5.767779605211173,-4.231747134538046,-6.3403309513558535,-15.207843838818798,-3.5903379853705193,-3.6906130082571567,-0.46938750082925507,-11.414136654852967,-8.082004077623239,-9.134801861689738,-3.2180597617295867,-5.606937006509068,-2.1401591473207175,-4.266883521241237,-6.729952842666715,-5.774401225461406,-5.387019447355774,-2.1303241611662833,0.6342751122948412,-1.6646863441153605,-7.124681409865752,-2.282822074188675,-4.922241268298732,-3.8020804406447875,-2.9123101719205056,-8.202973219749412,-5.59411700042968,-12.129732820111226,-4.566722918468142,-5.99759454923996,-5.494048187630945,-2.1 ...

# %% [markdown]
# ## Why t-SNE and UMAP are not suitable for Dimensionality Reduction in Supervised Tasks
#
# When performing supervised machine learning tasks—such as classifying bacterial species from MALDI-TOF spectra—it is crucial that the dimensionality reduction technique used **learns a fixed transformation** during training. This allows any **new, unseen test samples** to be projected into the **same low-dimensional space** as the training data, enabling consistent and reliable predictions.
#
# ### Limitations of t-SNE
#
# **t-Distributed Stochastic Neighbor Embedding (t-SNE)** is a popular nonlinear dimensionality reduction method primarily designed for **visualization**. It works by modeling the pairwise similarities between all samples in the high-dimensional space and tries to preserve those relationships in a low-dimensional embedding.
#
# - **Key issue:** t-SNE requires access to **all data points simultaneously** to compute this embedding.
# - This means that if you get new test samples, you must **recompute the entire t-SNE embedding with both training and new test data combined**.
# - Since t-SNE optimizes the embedding globally, the new low-dimensional coordinates will **change** whenever new samples are added.
# - Consequently, a classifier trained on t-SNE coordinates from the training data **cannot reliably predict** new samples projected with a different embedding.
#
# Thus, t-SNE **cannot be used as a dimensionality reduction step for supervised learning** in the conventional sense. It is instead an excellent tool for:
#
# - Visualizing complex data structures
# - Interpreting model behavior by projecting learned latent spaces
# - Understanding clusters and relationships in the data
#
# ---
# ### Limitations of UMAP
#
# **Uniform Manifold Approximation and Projection (UMAP)** shares conceptual similarities with t-SNE, aiming to preserve the topological structure of data in lower dimensions.
#
# - Like t-SNE, UMAP traditionally computes embeddings using **all samples together**, so new samples require **recomputing or approximating the embedding**.
# - While UMAP developers and the community are actively working on methods to **transform new data points into an existing embedding space** (sometimes called “transform” or “embedding projection”), this feature is still **experimental and under development**.
# - For more details and ongoing discussions, see [UMAP GitHub issue #40](https://github.com/lmcinnes/umap/issues/40#issuecomment-362306762).
#
# Until these capabilities mature, UMAP faces similar practical challenges as t-SNE when used for supervised prediction tasks.
#
# ---
# ### How PCA and PLS-DA Differ
#
# Both **Principal Component Analysis (PCA)** and **Partial Least Squares Discriminant Analysis (PLS-DA)** learn a **fixed linear transformation matrix** (commonly denoted as **W**) from the training data.
#
# - This matrix **projects any new sample**—including test samples—into the **same low-dimensional space** used for training.
# - This property makes PCA and PLS-DA suitable for supervised tasks where consistent feature extraction is essential.
# - Models trained on these projections can thus be confidently applied to new, unseen samples without retraining the dimensionality reduction step.
#
# ---
#
#
#
# ### Summary
#
# - **t-SNE and UMAP** are **best used as visualization tools** to explore and interpret data or model latent spaces, not as fixed feature extractors for prediction.
# - **PCA and PLS-DA** provide **fixed, learnable transformations** that allow consistent projection of new samples, making them appropriate for supervised learning pipelines.
# - Understanding these differences is essential for designing robust ML workflows in microbiology and biomedical applications.

# %% [markdown]
# # Implementing Classical Machine Learning models and biomarker discovery
#
# Now that we have explored dimensionality reduction and visualized our MALDI-TOF data, we will implement classical machine learning (ML) models. These models inherently incorporate biomarker detection through their structure and learned parameters.
#
# Following the principles from the **Model Selection** talk, we begin with **Occam’s Razor**: start simple before moving to complex models. Since PCA with 3 components is a **linear projection** that already revealed some clustering of bacterial species, we will first try **Logistic Regression (LR)** on both:
#
# - The PCA-reduced data capturing **95% of the variance**
# - The PCA-reduced data with **3 components**
#
# ---
#
# ### What is Logistic Regression?
#
# Logistic Regression is a **linear classifier** that models the probability of each class as a logistic (sigmoid) function of a linear combination of input features. Formally, for a sample with feature vector ($\mathbf{x}$), LR estimates the probability of class \(k\) as:
#
# $$
# P(y = k \mid \mathbf{x}) = \frac{\exp(\mathbf{w}_k^\top \mathbf{x} + b_k)}{\sum_{j=1}^K \exp(\mathbf{w}_j^\top \mathbf{x} + b_j)}
# $$
#
# where \($\mathbf{w}_k$\) is the weight vector and \($b_k$\) is the bias for class \(k\), and \(K\) is the number of classes.
#
# - The model learns **weights** that indicate the contribution of each feature (e.g., m/z peak intensity) to predicting each bacterial species.
# - Since LR is **directly interpretable**, we can identify the most important peaks by examining the weights with the largest absolute values.
# - For simplicity, we will focus on the **top 5 most abundant bacteria** in our dataset for biomarker analysis.
# ---
#
# ### Moving to more complex models: XGBoost
#
# From the **t-SNE** and **UMAP** visualizations, we observed better separation and clustering than PCA, suggesting that the relationship between MALDI-TOF peak intensities and bacterial species may be **non-linear and complex**.
#
# Following the decision tree introduced in the theory session
#
# (see placeholder image here: `![Decision Tree Placeholder](LINK_TO_IMAGE)`),
#
#  our MALDI-TOF dataset is:
#
# - **Sequencial data**
# - Sample size \(N=1259\)
# - Number of features \(D=6000\)
#
# Since \($N \ll D$\) is not true, kernel-based methods (like SVM with kernels) are less suitable due to computational complexity and interpretability issues. Instead, we opt for **tree-based methods**, which handle high-dimensional data well and capture non-linear interactions.
#
# ---
#
# ### What is XGBoost?
#
# **XGBoost** (Extreme Gradient Boosting) is a powerful, scalable gradient boosting framework that builds an ensemble of decision trees sequentially. Each new tree focuses on correcting the errors of the previous ensemble, resulting in a strong predictive model.
#
# - It automatically models complex, non-linear relationships between features and the target.
# - It provides **feature importance metrics** indicating how much each feature contributes to the model’s decisions.
# - By analyzing feature importance, we can identify the most discriminative m/z peaks for classifying each bacterial species.
#
# We will train an XGBoost classifier on the MALDI-TOF spectra and use the learned feature importances to discover potential biomarkers.
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from collections import Counter

# Filter function to select samples of top species
def filter_data(X, y, species_list, metadata):
    idxs = metadata[metadata['species'].isin(species_list)].index
    return X[idxs], y[idxs]

# Get top 5 species by frequency in training set
top5_species = [sp for sp, _ in Counter(metadata_train['species']).most_common(5)]

# Filter train and validation data for top 5 species
X_train_pca3_top5, y_train_top5 = filter_data(X_train_pca3, y_train, top5_species, metadata_train)
X_val_pca3_top5, y_val_top5 = filter_data(X_val_pca3, y_val, top5_species, metadata_val)

X_train_pca95_top5, _ = filter_data(X_train_pca95, y_train, top5_species, metadata_train)
X_val_pca95_top5, _ = filter_data(X_val_pca95, y_val, top5_species, metadata_val)

class_names_top5 = top5_species

def train_lr_and_plot_roc(X_train, y_train, X_val, y_val, class_names, description):
    # Train Logistic Regression with One-vs-Rest setting
    lr = LogisticRegression(max_iter=1000, multi_class='ovr', solver='liblinear', random_state=42)
    lr.fit(X_train, y_train)

    # Binarize validation labels for ROC curve calculation
    unique_classes = np.unique(y_train)
    y_val_bin = label_binarize(y_val, classes=unique_classes)

    y_score = lr.predict_proba(X_val)

    plt.figure(figsize=(8,6))
    for i, class_name in enumerate(class_names):
        fpr, tpr, _ = roc_curve(y_val_bin[:, i], y_score[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f"{class_name} (AUC = {roc_auc:.2f})")

    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curves - {description}')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.show()

    return lr

print("Training Logistic Regression on PCA 3 Components...")
lr_pca3 = train_lr_and_plot_roc(X_train_pca3_top5, y_train_top5, X_val_pca3_top5, y_val_top5, class_names_top5, "PCA 3 Components")

print("Training Logistic Regression on PCA 95% Variance...")
lr_pca95 = train_lr_and_plot_roc(X_train_pca95_top5, y_train_top5, X_val_pca95_top5, y_val_top5, class_names_top5, "PCA 95% Variance")

# Choose best model based on average ROC AUC across classes on validation set
def mean_roc_auc(lr, X_val, y_val, unique_classes):
    y_score = lr.predict_proba(X_val)
    y_val_bin = label_binarize(y_val, classes=unique_classes)
    aucs = []
    for i in range(len(unique_classes)):
        fpr, tpr, _ = roc_curve(y_val_bin[:, i], y_score[:, i])
        aucs.append(auc(fpr, tpr))
    return np.mean(aucs)

mean_auc_pca3 = mean_roc_auc(lr_pca3, X_val_pca3_top5, y_val_top5, np.unique(y_train_top5))
mean_auc_pca95 = mean_roc_auc(lr_pca95, X_val_pca95_top5, y_val_top5, np.unique(y_train_top5))

print(f"Mean ROC AUC PCA 3 components: {mean_auc_pca3:.4f}")
print(f"Mean ROC AUC PCA 95% variance: {mean_auc_pca95:.4f}")

best_model = lr_pca95 if mean_auc_pca95 >= mean_auc_pca3 else lr_pca3
best_desc = "PCA 95% Variance" if mean_auc_pca95 >= mean_auc_pca3 else "PCA 3 Components"

print(f"\nBest model selected: {best_desc}")

# Map coefficients back to original feature space

# Select PCA used in best model
pca_used = pca_95 if best_desc == "PCA 95% Variance" else pca_3

# LR coefficients in PCA space (num_classes, n_components)
coef_pca_space = best_model.coef_

# Transform coefficients to original feature space:
coef_original_space = coef_pca_space @ pca_used.components_

n_top_features = 5
feature_names = [f"m/z bin {i}" for i in range(X_train.shape[1])]  # Replace with actual m/z names if available

n_top_features = 5
# coef_original_space shape: (num_classes, n_features)
# class_names_top5 defined earlier

for i, class_name in enumerate(class_names_top5):
    coefs = coef_original_space[i]
    top_indices = np.argsort(np.abs(coefs))[-n_top_features:][::-1]

    true_mz_values = [(idx * 3) + 2000 for idx in top_indices]
    feature_labels = [f"{mz:.1f} m/z" for mz in true_mz_values]

    print(f"\nTop {n_top_features} features for {class_name} ({best_desc}) with true m/z values:")
    for idx, mz in zip(top_indices, true_mz_values):
        print(f"  Bin: {idx}, m/z: {mz:.1f}, Coefficient: {coefs[idx]:.4f}")

    plt.figure(figsize=(6,4))
    plt.bar(feature_labels, coefs[top_indices], color='b')
    plt.title(f"Top {n_top_features} Features for {class_name} ({best_desc})")
    plt.ylabel("LR Coefficient")
    plt.xticks(rotation=45)
    plt.grid(True, axis='y')
    plt.show()
# Out:
# Training Logistic Regression on PCA 3 Components...
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning:
#
# 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
# Training Logistic Regression on PCA 95% Variance...
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning:
#
# 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
# Mean ROC AUC PCA 3 components: 0.9751
# Mean ROC AUC PCA 95% variance: 1.0000
#
# Best model selected: PCA 95% Variance
#
# Top 5 features for Escherichia coli (PCA 95% Variance) with true m/z values:
#   Bin: 808, m/z: 4424.0, Coefficient: 1.0234
#   Bin: 809, m/z: 4427.0, Coefficient: 0.9920
#   Bin: 803, m/z: 4409.0, Coefficient: 0.9170
#   Bin: 802, m/z: 4406.0, Coefficient: 0.7405
#   Bin: 920, m/z: 4760.0, Coefficient: 0.6951
# Top 5 features for Staphylococcus aureus (PCA 95% Variance) with true m/z values:
#   Bin: 787, m/z: 4361.0, Coefficient: 1.8361
#   Bin: 1418, m/z: 6254.0, Coefficient: 1.7149
#   Bin: 788, m/z: 4364.0, Coefficient: 1.5485
#   Bin: 1127, m/z: 5381.0, Coefficient: 1.5040
#   Bin: 1126, m/z: 5378.0, Coefficient: 1.4563
# Top 5 features for Staphylococcus epidermidis (PCA 95% Variance) with true m/z values:
#   Bin: 811, m/z: 4433.0, Coefficient: 0.5643
#   Bin: 1069, m/z: 5207.0, Coefficient: 0.5437
#   Bin: 1348, m/z: 6044.0, Coefficient: 0.5028
#   Bin: 1070, m/z: 5210.0, Coefficient: 0.4897
#   Bin: 810, m/z: 4430.0, Coefficient: 0.4880
# Top 5 features for Enterococcus faecalis (PCA 95% Variance) with true m/z values:
#   Bin: 768, m/z: 4304.0, Coefficient: 1.6526
#   Bin: 767, m/z: 4301.0, Coefficient: 1.4480
#   Bin: 1629, m/z: 6887.0, Coefficient: 1.1799
#   Bin: 769, m/z: 4307.0, Coefficient: 1.1318
#   Bin: 1630, m/z: 6890.0, Coefficient: 1.0942
# Top 5 features for Pseudomonas aeruginosa (PCA 95% Variance) with true m/z values:
#   Bin: 763, m/z: 4289.0, Coefficient: 1.2904
#   Bin: 1560, m/z: 6680.0, Coefficient: 1.1557
#   Bin: 1561, m/z: 6683.0, Coefficient: 1.0487
#   Bin: 764, m/z: 4292.0, Coefficient: 1.0221
#   Bin: 762, m/z: 4286.0, Coefficient: 0.8585

# %% [markdown]
# ## Logistic Regression with PCA (95%) — A naïve but powerful baseline
#
# As we have observed, Logistic Regression trained on PCA-reduced data that explains 95% of the variance already achieves nearly **100% accuracy** on our validation set of the top 5 bacterial species from a single hospital.
#
# This confirms the principle of **Occam’s Razor**: often, simple models can solve the problem effectively when the data is well-structured and limited in complexity. In this case, the LR model identifies clear biomarkers and decision boundaries, demonstrating that much of the information needed for classification is captured in a few principal components.
#
# ---
#
# ### However...
#
# This scenario is somewhat **naïve and limited**:
#
# - We focused only on the **top 5 most common bacteria** in the dataset.
# - Data originates from **a single hospital**, with relatively homogeneous conditions and sample preparation.
# - Real-world clinical microbiology involves **many more species**, samples from **multiple hospitals** with different acquisition protocols, and greater biological variability.
#
# In such complex, heterogeneous environments, **more sophisticated models** capable of capturing non-linear interactions and adapting to varied data distributions are often necessary.
#
# ---
#
# ### Next Steps
#
# To address these challenges, we will now implement and evaluate **more advanced models**, including:
#
# - **XGBoost**, a powerful gradient-boosted tree ensemble method that can capture complex, non-linear relationships and interactions between MALDI-TOF peaks.
# - Additional models that provide complementary strengths in robustness, interpretability, and predictive performance.
#
# This progression aligns with the model selection strategy discussed earlier—start simple, then move towards complexity as needed based on data characteristics and problem difficulty.

# %%
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter

# Filter data to top 5 species
top5_species = [sp for sp, _ in Counter(metadata_train['species']).most_common(5)]

def filter_data(X, y, species_list, metadata):
    idxs = metadata[metadata['species'].isin(species_list)].index
    return X[idxs], y[idxs]

# Filter training and validation data for top 5 species
X_train_top5, y_train_top5 = filter_data(X_train, y_train, top5_species, metadata_train)
X_val_top5, y_val_top5 = filter_data(X_val, y_val, top5_species, metadata_val)

# Map label integers to species names for top5
class_names_top5 = top5_species
le_top5 = LabelEncoder()
y_train_top5_enc = le_top5.fit_transform(metadata_train.loc[metadata_train['species'].isin(top5_species), 'species'])
y_val_top5_enc = le_top5.transform(metadata_val.loc[metadata_val['species'].isin(top5_species), 'species'])

# Train XGBoost classifier
xgb_clf = xgb.XGBClassifier(
    objective='multi:softprob',
    eval_metric='mlogloss',
    use_label_encoder=False,
    n_estimators=100,
    random_state=42
)
xgb_clf.fit(X_train_top5, y_train_top5_enc)

# Predict probabilities for ROC
y_val_proba = xgb_clf.predict_proba(X_val_top5)

# Binarize validation labels
y_val_bin = label_binarize(y_val_top5_enc, classes=range(len(class_names_top5)))

# Plot ROC curves for top 5 species
plt.figure(figsize=(8, 6))
colors = plt.cm.tab10.colors  # up to 10 colors

for i, class_name in enumerate(class_names_top5):
    fpr, tpr, _ = roc_curve(y_val_bin[:, i], y_val_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=colors[i], label=f"{class_name} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves - XGBoost on Raw Preprocessed Spectra')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# Extract feature importance from XGBoost
importance_dict = xgb_clf.get_booster().get_score(importance_type='weight')
# importance_type options: weight, gain, cover; 'weight' = number of times feature is used in trees

# Map feature names
feature_names = [f"m/z bin {i}" for i in range(X_train.shape[1])]  # Replace with real m/z names if available

# Convert importance dict keys (like 'f0', 'f1', ...) to integers and values to array
importance_arr = np.zeros(X_train.shape[1])
for k, v in importance_dict.items():
    idx = int(k[1:])  # strip 'f' prefix
    importance_arr[idx] = v

# For each top species, plot top 5 important features according to global importance
# (XGBoost feature importance is global, not per class)

top_n = 10
top_indices = np.argsort(importance_arr)[-top_n:][::-1]

true_mz_values = [(idx * 3) + 2000 for idx in top_indices]
feature_labels = [f"{mz:.1f} m/z" for mz in true_mz_values]

print(f"Top {top_n} features by XGBoost importance with true m/z values:")
for idx, mz in zip(top_indices, true_mz_values):
    print(f"  Feature bin: {idx}, m/z: {mz:.1f}, Importance (weight): {importance_arr[idx]}")

plt.figure(figsize=(6, 4))
plt.bar(feature_labels, importance_arr[top_indices], color='green')
plt.title("Top 5 Important Features from XGBoost (True m/z values)")
plt.ylabel("Feature Importance (weight)")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning:
#
# [13:19:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
# Top 10 features by XGBoost importance with true m/z values:
#   Feature bin: 1630, m/z: 6890.0, Importance (weight): 14.0
#   Feature bin: 763, m/z: 4289.0, Importance (weight): 12.0
#   Feature bin: 771, m/z: 4313.0, Importance (weight): 10.0
#   Feature bin: 3039, m/z: 11117.0, Importance (weight): 9.0
#   Feature bin: 3038, m/z: 11114.0, Importance (weight): 8.0
#   Feature bin: 2659, m/z: 9977.0, Importance (weight): 7.0
#   Feature bin: 2596, m/z: 9788.0, Importance (weight): 6.0
#   Feature bin: 769, m/z: 4307.0, Importance (weight): 6.0
#   Feature bin: 2517, m/z: 9551.0, Importance (weight): 5.0
#   Feature bin: 787, m/z: 4361.0, Importance (weight): 5.0

# %%
#Save model
import joblib

# joblib.dump(xgb_clf, "/content/drive/MyDrive/ESCMID-AI-Data-Advances-Techniques/Models/xgboost_top5_species_model.pkl")
joblib.dump(xgb_clf, "/content/drive/MyDrive/DRIAMS/xgboost_top5_species_model.pkl")
# Out:
# ['/content/drive/MyDrive/DRIAMS/xgboost_top5_species_model.pkl']

# %% [markdown]
# **MLP**
#
#
# **What is an MLP?**
# An MLP (Multilayer Perceptron) is a type of artificial neural network used to model relationships in data. It learns to map input data to output labels or values by adjusting internal parameters (called weights) during training.
#
# At its core, an MLP is made up of layers of neurons:
# *   Input Layer – where data enters the model.
# *   Hidden Layers – one or more layers where the actual computation happens
# *   Output Layer – where the result (such as a prediction) comes out.
#
# **How Does It Work?**
# When you feed data into an MLP, it goes through the following steps:
#
# Linear Transformation: Each neuron in a layer takes inputs from the previous layer, multiplies them by some weights, and adds a bias.
# Mathematically, this is expressed as:
#
# $$
# z = w_1x_1 + w_2x_2 + \cdots + w_nx_n + b
# $$
#
# Where:
#
# - $x_1, x_2, \ldots, x_n$ are the input features
# - $w_1, w_2, \ldots, w_n$ are the corresponding weights
# - $b$ is the bias term
# - $z$ is the linear output before activation
#
# Activation Function: The result 𝑧
# z is then passed through a nonlinear function (like ReLU or sigmoid), which introduces complexity so the network can learn things like curves or patterns—not just straight lines.
#
#
# Examples:
#
# - **ReLU** (Rectified Linear Unit):
#
#   $$
#   \text{ReLU}(z) = \max(0, z)
#   $$
#
# - **Sigmoid**:
#
#   $$
#   \text{Sigmoid}(z) = \frac{1}{1 + e^{-z}}
#   $$
#
#
#
# **How Does It Learn?**
#
# MLPs learn from data using a process called backpropagation and an optimization algorithm (like gradient descent):
#
# The model makes a guess (called a prediction) for the input.
#
# 1.   It compares the prediction to the actual answer using a loss function.
# 2.   It calculates how wrong it was and adjusts its weights to do better next time.
# 3.   This adjustment happens many times over many examples in the training data, gradually improving performance.

# %% [markdown]
# **MLP using SKlearn package**

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline


# Create a pipeline: Standardize features then fit MLP
mlp_clf = make_pipeline(
    StandardScaler(),
    MLPClassifier(hidden_layer_sizes=(10,),  # you can tune this
                  max_iter=500,
                  random_state=42,
                  early_stopping=True)
)

# Fit on training data
mlp_clf.fit(X_train_top5, y_train_top5_enc)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('mlpclassifier',
#                  MLPClassifier(early_stopping=True, hidden_layer_sizes=(10,),
#                                max_iter=500, random_state=42))])

# %%
# Predict probabilities
y_val_proba_mlp = mlp_clf.predict_proba(X_val_top5)

# Plot ROC for MLP
plt.figure(figsize=(8, 6))

for i, class_name in enumerate(class_names_top5):
    fpr, tpr, _ = roc_curve(y_val_bin[:, i], y_val_proba_mlp[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_name} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves - MLP on Raw Preprocessed Spectra')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# ## MLP using tensorflow Keras

# %%
import numpy as np
import shap
import tensorflow as tf
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler

# --- 1. Preprocessing (same as sklearn pipeline) ---
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_top5)
X_val_scaled = scaler.transform(X_val_top5)  # use same scaler for test

# --- 2. Define MLP model using Keras ---
n_features = X_train_scaled.shape[1]
n_classes = len(np.unique(y_train_top5_enc))  # multi-class

# Define model properly
mlp_keras = Sequential([
    Input(shape=(X_train_scaled.shape[1],)),
    Dense(10, activation='relu'),
    Dense(n_classes, activation='softmax')  # or Dense(1, activation='sigmoid') for binary
])

# 3. Train MLP model
mlp_keras.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
mlp_keras.fit(X_train_scaled, y_train_top5_enc, epochs=10, batch_size=16, verbose=0)

# %%
# Save model
# Save the model to a file (SavedModel format)
# mlp_keras.save("/content/drive/MyDrive/ESCMID-AI-Data-Advances-Techniques/Models/mlp_keras_model.h5")

mlp_keras.save("/content/drive/MyDrive/DRIAMS/mlp_keras_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# --- 1. Predict class probabilities on validation set
y_val_proba_mlp = mlp_keras.predict(X_val_scaled)  # shape: (n_samples, n_classes)

# --- 2. Plot ROC curves per class
plt.figure(figsize=(8, 6))

for i, class_name in enumerate(class_names_top5):
    fpr, tpr, _ = roc_curve(y_val_bin[:, i], y_val_proba_mlp[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_name} (AUC = {roc_auc:.2f})")

# --- 3. Plot diagonal line (random classifier baseline)
plt.plot([0, 1], [0, 1], 'k--', label='Random')

# --- 4. Format plot
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves - Keras MLP on Raw Preprocessed Spectra')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# # SHAP values

# %% [markdown]
# **Explainability: SHAP values (SHapley Additive exPlanations)**
#
# SHAP is a powerful library to explain predictions of any machine learning model, including neural networks.
#
# Shapley Values (SHAP)
#
# **What are they?**
#
# Shapley values come from cooperative game theory. They fairly distribute the “payout” (in machine learning, the prediction) among all the “players” (features) based on their contribution.
#
# **How does it work in ML?**
#
#
# Imagine each feature as a player in a team.
#
# The team’s “score” is the model’s prediction.
#
# Shapley values tell you how much each feature contributes to moving the prediction from the average prediction to the current output.
#
# They do this by averaging the feature’s contribution over all possible combinations of features.

# %%
# 4. SHAP DeepExplainer using NumPy (not tf.Tensor)
X_explain = X_val_scaled[:30]  # shape (5, 6000)
background = X_train_scaled[:100]

explainer = shap.DeepExplainer(mlp_keras, background)
shap_values = explainer.shap_values(X_explain)

# 5. Summary plot

# Rename features
feature_names = [f"{2000 + i*3}-{2000 + (i+1)*3} Da" for i in range(6000)]

shap.summary_plot(shap_values, X_explain, feature_names=feature_names, plot_type="bar")

# 6. Summary plot for one class
depicted_class = 0

shap.summary_plot(shap_values[:, :, 0], X_explain,feature_names=feature_names)
# Out:
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_deep/deep_tf.py:94: UserWarning:
#
# Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning:
#
# The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(100, 6000))']
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning:
#
# The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(200, 6000))']
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning:
#
# The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(30, 6000))']

# %%
background = X_train_scaled[:100]
#np.save("/content/drive/MyDrive/ESCMID-AI-Data-Advances-Techniques/Models/mlp_shap_background.npy", background)

np.save("/content/drive/MyDrive/DRIAMS/mlp_shap_background.npy", background)


print(f"[✔] Saved SHAP background with shape: {background.shape}")
# Out:
# [✔] Saved SHAP background with shape: (100, 6000)

# %%
os.listdir("/content/drive/MyDrive/DRIAMS/")
# Out:
# ['DRIAMS-B',
#  'xgboost_top5_species_model.pkl',
#  'mlp_keras_model.h5',
#  'mlp_shap_background.npy']
